# %% [markdown]
# # Setup & Data Preparation

# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: purple; font-size: 60px; margin-bottom: 30px;">NFLAI</h1>
#     <h3 style="color: black;">Created by Tyler Durette</h3>
#     <!-- <p style="font-size: 20px; font-style: italic;">Analyzing team and player trends, betting performances, and more using AI.</p> -->
#     <hr style="border: 2px solid purple; width: 55%;">
#     <img src="https://media.bleacherreport.com/image/upload/c_crop,h_0.90,w_0.90,x_0.01,y_0.05/w_650/v1693966577/wy9rjhloyplkvjq7ljgz.jpg" alt="NFL AI Logo" width="800"/>
# </div>

# %%
import sqlite3
from IPython.display import display
import pandas as pd
from tabulate import tabulate
import os
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import warnings
# warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)
# warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# !rm -rf data
# !cp -r ../Scrapers/data .
# !cp ../Scrapers/nfl.db data/

# %%
db_path = 'data/nfl.db'
conn = sqlite3.connect(db_path)
tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = conn.execute(tables_query).fetchall()
for table in tables:
    table_name = table[0]
    # Read the table into a pandas DataFrame
    df = pd.read_sql_query(f"SELECT * FROM {table_name}", conn)
    # Save the DataFrame to a CSV file
    csv_file_name = f"data/{table_name}.csv"
    df.to_csv(csv_file_name, index=False)
    print(f"Downloaded {table_name} to {csv_file_name}")
conn.close()
# Out:
# Downloaded Teams to data/Teams.csv
# Downloaded Games to data/Games.csv
# Downloaded PlayerStats to data/PlayerStats.csv
# Downloaded Rosters to data/Rosters.csv

# %%
# Cleaning 

file_path = 'data/all_passing_rushing_receiving.csv'  # Adjust this path as needed
df = pd.read_csv(file_path)
row_count_before = df.shape[0]
print(f"Row count before removing duplicates: {row_count_before}")
df_cleaned = df.drop_duplicates()
row_count_after = df_cleaned.shape[0]
print(f"Row count after removing duplicates: {row_count_after}")
df_cleaned.to_csv('data/all_passing_rushing_receiving.csv', index=False)
print("Cleaned file saved as 'all_passing_rushing_receiving.csv'")

# %%
# Downloading logos

import os
import requests

# Create a directory to store images
os.makedirs('images', exist_ok=True)

# List of URLs for team logos and their corresponding abbreviations
team_logos = {
    "https://cdn.fastassets.io/images/team-logos/New-Orleans-Saints.png": "NO",
    "https://cdn.fastassets.io/images/team-logos/Atlanta-Falcons.png": "ATL",
    "https://cdn.fastassets.io/images/team-logos/Pittsburgh-Steelers.png": "PIT",
    "https://cdn.fastassets.io/images/team-logos/Indianapolis-Colts.png": "IND",
    "https://cdn.fastassets.io/images/team-logos/Jacksonville-Jaguars.png": "JAX",
    "https://cdn.fastassets.io/images/team-logos/Houston-Texans.png": "HOU",
    "https://cdn.fastassets.io/images/team-logos/Minnesota-Vikings.png": "MIN",
    "https://cdn.fastassets.io/images/team-logos/Green-Bay-Packers.png": "GB",
    "https://cdn.fastassets.io/images/team-logos/Cincinnati-Bengals.png": "CIN",
    "https://cdn.fastassets.io/images/team-logos/Carolina-Panthers.png": "CAR",
    "https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/lar.png": "LAR",  # Corrected
    "https://cdn.fastassets.io/images/team-logos/Chicago-Bears.png": "CHI",
    "https://cdn.fastassets.io/images/team-logos/Denver-Broncos.png": "DEN",
    "https://cdn.fastassets.io/images/team-logos/Tampa-Bay-Buccaneers.png": "TB",
    "https://cdn.fastassets.io/images/team-logos/Seattle-Seahawks.png": "SEA",
    "https://cdn.fastassets.io/images/team-logos/San-Francisco-49ers.png": "SF",
    "https://cdn.fastassets.io/images/team-logos/Arizona-Cardinals.png": "ARI",
    "https://cdn.fastassets.io/images/team-logos/Dallas-Cowboys.png": "DAL",
    "https://cdn.fastassets.io/images/team-logos/Philadelphia-Eagles.png": "PHI",
    "https://cdn.fastassets.io/images/team-logos/Washington-Redskins.png": "WAS",  # Corrected
    "https://cdn.fastassets.io/images/team-logos/New-York-Giants.png": "NYG",
    "https://cdn.fastassets.io/images/team-logos/Kansas-City-Chiefs.png": "KC",
    "https://s.yimg.com/cv/apiv2/default/nfl/20200908/500x500/raiders_wbg.png": "LVR",  # Corrected
    "https://a.espncdn.com/combiner/i?img=/i/teamlogos/nfl/500/lac.png": "LAC",  # Corrected
    "https://cdn.fastassets.io/images/team-logos/Buffalo-Bills.png": "BUF",
    "https://cdn.fastassets.io/images/team-logos/Miami-Dolphins.png": "MIA",
    "https://cdn.fastassets.io/images/team-logos/New-York-Jets.png": "NYJ",
    "https://cdn.fastassets.io/images/team-logos/New-England-Patriots.png": "NE",
    "https://cdn.fastassets.io/images/team-logos/Cleveland-Browns.png": "CLE",
    "https://cdn.fastassets.io/images/team-logos/Baltimore-Ravens.png": "BAL",
    "https://cdn.fastassets.io/images/team-logos/Detroit-Lions.png": "DET",
    "https://cdn.fastassets.io/images/team-logos/Tennessee-Titans.png": "TEN"
}

# Download each logo and save it with the abbreviation as the file name
for url, abbreviation in team_logos.items():
    try:
        img_data = requests.get(url).content  # Download the image content
        with open(f'images/{abbreviation}.png', 'wb') as handler:
            handler.write(img_data)  # Save the image to the file
        print(f"Downloaded {abbreviation}.png")
    except Exception as e:
        print(f"Failed to download {abbreviation}: {e}")

print("All images have been downloaded.")
# Out:
# Downloaded NO.png
# Downloaded ATL.png
# Downloaded PIT.png
# Downloaded IND.png
# Downloaded JAX.png
# Downloaded HOU.png
# Downloaded MIN.png
# Downloaded GB.png
# Downloaded CIN.png
# Downloaded CAR.png
# Downloaded LAR.png
# Downloaded CHI.png
# Downloaded DEN.png
# Downloaded TB.png
# Downloaded SEA.png
# Downloaded SF.png
# Downloaded ARI.png
# Downloaded DAL.png
# Downloaded PHI.png
# Downloaded WAS.png
# Downloaded NYG.png
# Downloaded KC.png
# Downloaded LVR.png
# Downloaded LAC.png
# Downloaded BUF.png
# Downloaded MIA.png
# Downloaded NYJ.png
# Downloaded NE.png
# Downloaded CLE.png
# Downloaded BAL.png
# Downloaded DET.png
# Downloaded TEN.png
# All images have been downloaded.

# %%
# Downloading player headshots

import os
import pandas as pd
import requests

# Load the player_stats data from your file in the 'data/' directory
df_player_stats = pd.read_csv('data/player_stats.csv')

# Filter out QBs with valid headshot URLs and remove duplicates based on player_display_name
# unique_qbs_with_urls = df_player_stats[(df_player_stats['position'] == 'QB') & df_player_stats['headshot_url'].notna()] \
unique_qbs_with_urls = df_player_stats[df_player_stats['headshot_url'].notna()] \
                        .drop_duplicates(subset=['player_display_name'])

# Set up the directory to save images
image_folder = 'images'
os.makedirs(image_folder, exist_ok=True)

# Initialize a counter for downloaded images
downloaded_count = 0
total_qbs = len(unique_qbs_with_urls)

# Iterate through the unique QBs and download their headshots
for index, row in unique_qbs_with_urls.iterrows():
    player_name = row['player_display_name'].lower().replace(' ', '_')
    headshot_url = row['headshot_url']
    image_path = os.path.join(image_folder, f"{player_name}.png")
    
    # Download the image and save it
    try:
        response = requests.get(headshot_url)
        if response.status_code == 200:
            with open(image_path, 'wb') as file:
                file.write(response.content)
            downloaded_count += 1
            print(f"Downloaded {player_name}'s headshot ({downloaded_count}/{total_qbs}).")
        else:
            print(f"Failed to download {player_name}'s headshot (Status code: {response.status_code}).")
    except Exception as e:
        print(f"Error downloading {player_name}'s headshot: {e}")

# Print final result
print(f"Download complete: {downloaded_count}/{total_qbs} images successfully downloaded.")
# Out:
# Downloaded matt_hasselbeck's headshot (1/1628).
# Downloaded steve_heiden's headshot (2/1628).
# Downloaded peyton_manning's headshot (3/1628).
# Downloaded michael_pittman's headshot (4/1628).
# Downloaded bobby_brown's headshot (5/1628).
# Downloaded tom_brady's headshot (6/1628).
# Downloaded mike_vick's headshot (7/1628).
# Downloaded steve_smith's headshot (8/1628).
# Downloaded drew_brees's headshot (9/1628).
# Downloaded cedrick_wilson's headshot (10/1628).
# Downloaded josh_mccown's headshot (11/1628).
# Downloaded antonio_gates's headshot (12/1628).
# Downloaded anquan_boldin's headshot (13/1628).
# Downloaded jason_witten's headshot (14/1628).
# Downloaded carson_palmer's headshot (15/1628).
# Downloaded malcom_floyd's headshot (16/1628).
# Downloaded wes_welker's headshot (17/1628).
# Downloaded steven_jackson's headshot (18/1628).
# Downloaded matt_schaub's headshot (19/1628).
# Downloaded eli_manning's headshot (20/1628).
# Downloaded jerricho_cotchery's headshot (21/1628).
# Downloaded luke_mccown's headshot (22/1628).
# Downloaded larry_fitzgerald's headshot (23/1628).
# Downloaded ben_roethlisberger's headshot (24/1628).
# Downloaded philip_rivers's headshot (25/1628).
# Downloaded benjamin_watson's headshot (26/1628).
# Downloaded shaun_hill's headshot (27/1628).
# Downloaded tony_romo's headshot (28/1628).
# Downloaded alex_smith's headshot (29/1628).
# Downloaded aaron_rodgers's headshot (30/1628).
# Downloaded roddy_white's headshot (31/1628).
# Downloaded heath_miller's headshot (32/1628).
# Downloaded vincent_jackson's headshot (33/1628).
# Downloaded frank_gore's headshot (34/1628).
# Downloaded darren_sproles's headshot (35/1628).
# Downloaded dan_orlovsky's headshot (36/1628).
# Downloaded matt_cassel's headshot (37/1628).
# Downloaded ryan_fitzpatrick's headshot (38/1628).
# Downloaded john_kuhn's headshot (39/1628).
# Downloaded lance_moore's headshot (40/1628).
# Downloaded derek_anderson's headshot (41/1628).
# Downloaded miles_austin's headshot (42/1628).
# Downloaded reggie_bush's headshot (43/1628).
# Downloaded vernon_davis's headshot (44/1628).
# Downloaded jay_cutler's headshot (45/1628).
# Downloaded deangelo_williams's headshot (46/1628).
# Downloaded marcedes_lewis's headshot (47/1628).
# Downloaded kellen_clemens's headshot (48/1628).
# Downloaded greg_jennings's headshot (49/1628).
# Downloaded anthony_fasano's headshot (50/1628).
# Downloaded devin_hester's headshot (51/1628).
# Downloaded tarvaris_jackson's headshot (52/1628).
# Downloaded owen_daniels's headshot (53/1628).
# Downloaded jason_avant's headshot (54/1628).
# Downloaded brandon_marshall's headshot (55/1628).
# Downloaded delanie_walker's headshot (56/1628).
# Downloaded marques_colston's headshot (57/1628).
# Downloaded fred_jackson's headshot (58/1628).
# Downloaded pierre_thomas's headshot (59/1628).
# Downloaded calvin_johnson's headshot (60/1628).
# Downloaded adrian_peterson's headshot (61/1628).
# Downloaded ted_ginn's headshot (62/1628).
# Downloaded marshawn_lynch's headshot (63/1628).
# Downloaded dwayne_bowe's headshot (64/1628).
# Downloaded greg_olsen's headshot (65/1628).
# Downloaded jacoby_jones's headshot (66/1628).
# Downloaded matt_spaeth's headshot (67/1628).
# Downloaded brent_celek's headshot (68/1628).
# Downloaded ahmad_bradshaw's headshot (69/1628).
# Downloaded matt_moore's headshot (70/1628).
# Downloaded daniel_fells's headshot (71/1628).
# Downloaded eric_weems's headshot (72/1628).
# Downloaded drew_stanton's headshot (73/1628).
# Downloaded mike_tolbert's headshot (74/1628).
# Downloaded matt_ryan's headshot (75/1628).
# Downloaded darren_mcfadden's headshot (76/1628).
# Downloaded jonathan_stewart's headshot (77/1628).
# Downloaded joe_flacco's headshot (78/1628).
# Downloaded chris_johnson's headshot (79/1628).
# Downloaded jordy_nelson's headshot (80/1628).
# Downloaded eddie_royal's headshot (81/1628).
# Downloaded matt_forte's headshot (82/1628).
# Downloaded desean_jackson's headshot (83/1628).
# Downloaded chad_henne's headshot (84/1628).
# Downloaded martellus_bennett's headshot (85/1628).
# Downloaded jamaal_charles's headshot (86/1628).
# Downloaded harry_douglas's headshot (87/1628).
# Downloaded jacob_tamme's headshot (88/1628).
# Downloaded jerome_felton's headshot (89/1628).
# Downloaded tim_hightower's headshot (90/1628).
# Downloaded pierre_garcon's headshot (91/1628).
# Downloaded matt_flynn's headshot (92/1628).
# Downloaded steve_johnson's headshot (93/1628).
# Downloaded matthew_mulligan's headshot (94/1628).
# Downloaded danny_woodhead's headshot (95/1628).
# Downloaded danny_amendola's headshot (96/1628).
# Downloaded kenny_moore's headshot (97/1628).
# Downloaded gary_barnidge's headshot (98/1628).
# Downloaded matt_slater's headshot (99/1628).
# Downloaded kellen_davis's headshot (100/1628).
# Downloaded josh_johnson's headshot (101/1628).
# Downloaded justin_forsett's headshot (102/1628).
# Downloaded marcel_reece's headshot (103/1628).
# Downloaded matthew_stafford's headshot (104/1628).
# Downloaded brian_hoyer's headshot (105/1628).
# Downloaded mark_sanchez's headshot (106/1628).
# Downloaded mike_wallace's headshot (107/1628).
# Downloaded brandon_gibson's headshot (108/1628).
# Downloaded david_johnson's headshot (109/1628).
# Downloaded darrius_heyward-bey's headshot (110/1628).
# Downloaded michael_crabtree's headshot (111/1628).
# Downloaded josh_freeman's headshot (112/1628).
# Downloaded jeremy_maclin's headshot (113/1628).
# Downloaded percy_harvin's headshot (114/1628).
# Downloaded hakeem_nicks's headshot (115/1628).
# Downloaded kenny_britt's headshot (116/1628).
# Downloaded lesean_mccoy's headshot (117/1628).
# Downloaded brandon_tate's headshot (118/1628).
# Downloaded jared_cook's headshot (119/1628).
# Downloaded brian_hartline's headshot (120/1628).
# Downloaded louis_murphy's headshot (121/1628).
# Downloaded james_casey's headshot (122/1628).
# Downloaded zach_miller's headshot (123/1628).
# Downloaded brandon_myers's headshot (124/1628).
# Downloaded john_phillips's headshot (125/1628).
# Downloaded julian_edelman's headshot (126/1628).
# Downloaded rashad_jennings's headshot (127/1628).
# Downloaded scott_chandler's headshot (128/1628).
# Downloaded chase_daniel's headshot (129/1628).
# Downloaded darrel_young's headshot (130/1628).
# Downloaded antone_smith's headshot (131/1628).
# Downloaded cedric_peerman's headshot (132/1628).
# Downloaded logan_paulsen's headshot (133/1628).
# Downloaded jeff_cumberland's headshot (134/1628).
# Downloaded legarrette_blount's headshot (135/1628).
# Downloaded preston_parker's headshot (136/1628).
# Downloaded chris_ivory's headshot (137/1628).
# Downloaded seyi_ajirotutu's headshot (138/1628).
# Downloaded kyle_williams's headshot (139/1628).
# Downloaded dexter_mccluster's headshot (140/1628).
# Downloaded arrelious_benn's headshot (141/1628).
# Downloaded rob_gronkowski's headshot (142/1628).
# Downloaded jimmy_clausen's headshot (143/1628).
# Downloaded ed_dickson's headshot (144/1628).
# Downloaded brandon_lafell's headshot (145/1628).
# Downloaded emmanuel_sanders's headshot (146/1628).
# Downloaded colt_mccoy's headshot (147/1628).
# Downloaded eric_decker's headshot (148/1628).
# Downloaded andre_roberts's headshot (149/1628).
# Downloaded jimmy_graham's headshot (150/1628).
# Downloaded dennis_pitta's headshot (151/1628).
# Downloaded clay_harbor's headshot (152/1628).
# Downloaded michael_hoomanawanui's headshot (153/1628).
# Downloaded riley_cooper's headshot (154/1628).
# Downloaded anthony_dixon's headshot (155/1628).
# Downloaded james_starks's headshot (156/1628).
# Downloaded antonio_brown's headshot (157/1628).
# Downloaded joe_webb's headshot (158/1628).
# Downloaded mickey_shuler's headshot (159/1628).
# Downloaded marc_mariani's headshot (160/1628).
# Downloaded dorin_dickerson's headshot (161/1628).
# Downloaded jim_dray's headshot (162/1628).
# Downloaded sam_bradford's headshot (163/1628).
# Downloaded c.j._spiller's headshot (164/1628).
# Downloaded ryan_mathews's headshot (165/1628).
# Downloaded jermaine_gresham's headshot (166/1628).
# Downloaded demaryius_thomas's headshot (167/1628).
# Downloaded toby_gerhart's headshot (168/1628).
# Downloaded golden_tate's headshot (169/1628).
# Downloaded dez_bryant's headshot (170/1628).
# Downloaded jordan_norwood's headshot (171/1628).
# Downloaded victor_cruz's headshot (172/1628).
# Downloaded richie_brockel's headshot (173/1628).
# Downloaded mike_kafka's headshot (174/1628).
# Downloaded anthony_mccoy's headshot (175/1628).
# Downloaded tyler_clutts's headshot (176/1628).
# Downloaded cam_newton's headshot (177/1628).
# Downloaded a.j._green's headshot (178/1628).
# Downloaded julio_jones's headshot (179/1628).
# Downloaded blaine_gabbert's headshot (180/1628).
# Downloaded christian_ponder's headshot (181/1628).
# Downloaded mark_ingram's headshot (182/1628).
# Downloaded andy_dalton's headshot (183/1628).
# Downloaded colin_kaepernick's headshot (184/1628).
# Downloaded kyle_rudolph's headshot (185/1628).
# Downloaded lance_kendricks's headshot (186/1628).
# Downloaded shane_vereen's headshot (187/1628).
# Downloaded torrey_smith's headshot (188/1628).
# Downloaded greg_little's headshot (189/1628).
# Downloaded randall_cobb's headshot (190/1628).
# Downloaded rob_housler's headshot (191/1628).
# Downloaded demarco_murray's headshot (192/1628).
# Downloaded stevan_ridley's headshot (193/1628).
# Downloaded vincent_brown's headshot (194/1628).
# Downloaded jordan_cameron's headshot (195/1628).
# Downloaded luke_stocker's headshot (196/1628).
# Downloaded roy_helu's headshot (197/1628).
# Downloaded cecil_shorts's headshot (198/1628).
# Downloaded kendall_hunter's headshot (199/1628).
# Downloaded taiwan_jones's headshot (200/1628).
# Downloaded bilal_powell's headshot (201/1628).
# Downloaded julius_thomas's headshot (202/1628).
# Downloaded anthony_sherman's headshot (203/1628).
# Downloaded jacquizz_rodgers's headshot (204/1628).
# Downloaded denarius_moore's headshot (205/1628).
# Downloaded dion_lewis's headshot (206/1628).
# Downloaded t.j._yates's headshot (207/1628).
# Downloaded jeremy_kerley's headshot (208/1628).
# Downloaded niles_paul's headshot (209/1628).
# Downloaded lee_smith's headshot (210/1628).
# Downloaded charles_clay's headshot (211/1628).
# Downloaded tyrod_taylor's headshot (212/1628).
# Downloaded richard_gordon's headshot (213/1628).
# Downloaded virgil_green's headshot (214/1628).
# Downloaded bruce_miller's headshot (215/1628).
# Downloaded allen_reisner's headshot (216/1628).
# Downloaded dujuan_harris's headshot (217/1628).
# Downloaded doug_baldwin's headshot (218/1628).
# Downloaded ricardo_lockette's headshot (219/1628).
# Downloaded marcus_thigpen's headshot (220/1628).
# Downloaded joique_bell's headshot (221/1628).
# Downloaded thad_lewis's headshot (222/1628).
# Downloaded ryan_mallett's headshot (223/1628).
# Downloaded dwayne_harris's headshot (224/1628).
# Downloaded aldrick_robinson's headshot (225/1628).
# Downloaded jordan_todman's headshot (226/1628).
# Downloaded shaun_draughn's headshot (227/1628).
# Downloaded andre_holmes's headshot (228/1628).
# Downloaded joseph_morgan's headshot (229/1628).
# Downloaded patrick_dimarco's headshot (230/1628).
# Downloaded terrelle_pryor's headshot (231/1628).
# Downloaded will_johnson's headshot (232/1628).
# Downloaded garrett_celek's headshot (233/1628).
# Downloaded chris_owusu's headshot (234/1628).
# Downloaded cory_harkey's headshot (235/1628).
# Downloaded dominique_jones's headshot (236/1628).
# Downloaded cole_beasley's headshot (237/1628).
# Downloaded lance_dunbar's headshot (238/1628).
# Downloaded rod_streater's headshot (239/1628).
# Downloaded alshon_jeffery's headshot (240/1628).
# Downloaded alfred_morris's headshot (241/1628).
# Downloaded jermaine_kearse's headshot (242/1628).
# Downloaded travaris_cadet's headshot (243/1628).
# Downloaded brandon_bolden's headshot (244/1628).
# Downloaded lamichael_james's headshot (245/1628).
# Downloaded rueben_randle's headshot (246/1628).
# Downloaded russell_wilson's headshot (247/1628).
# Downloaded bernard_pierce's headshot (248/1628).
# Downloaded travis_benjamin's headshot (249/1628).
# Downloaded robert_turbin's headshot (250/1628).
# Downloaded ladarius_green's headshot (251/1628).
# Downloaded marvin_jones's headshot (252/1628).
# Downloaded deonte_thompson's headshot (253/1628).
# Downloaded orson_charles's headshot (254/1628).
# Downloaded keshawn_martin's headshot (255/1628).
# Downloaded bryce_brown's headshot (256/1628).
# Downloaded damaris_johnson's headshot (257/1628).
# Downloaded jonathan_grimes's headshot (258/1628).
# Downloaded ryan_lindley's headshot (259/1628).
# Downloaded vick_ballard's headshot (260/1628).
# Downloaded nick_foles's headshot (261/1628).
# Downloaded jarius_wright's headshot (262/1628).
# Downloaded rishard_matthews's headshot (263/1628).
# Downloaded rhett_ellison's headshot (264/1628).
# Downloaded kirk_cousins's headshot (265/1628).
# Downloaded t.y._hilton's headshot (266/1628).
# Downloaded daryl_richardson's headshot (267/1628).
# Downloaded doug_martin's headshot (268/1628).
# Downloaded lamar_miller's headshot (269/1628).
# Downloaded jorvorskie_lane's headshot (270/1628).
# Downloaded mohamed_sanu's headshot (271/1628).
# Downloaded james_hanna's headshot (272/1628).
# Downloaded michael_floyd's headshot (273/1628).
# Downloaded brian_quick's headshot (274/1628).
# Downloaded trevor_graham's headshot (275/1628).
# Downloaded josh_gordon's headshot (276/1628).
# Downloaded robert_griffin's headshot (277/1628).
# Downloaded andrew_luck's headshot (278/1628).
# Downloaded devier_posey's headshot (279/1628).
# Downloaded brandon_weeden's headshot (280/1628).
# Downloaded brock_osweiler's headshot (281/1628).
# Downloaded ronnie_hillman's headshot (282/1628).
# Downloaded dwayne_allen's headshot (283/1628).
# Downloaded coby_fleener's headshot (284/1628).
# Downloaded ryan_tannehill's headshot (285/1628).
# Downloaded justin_blackmon's headshot (286/1628).
# Downloaded kendall_wright's headshot (287/1628).
# Downloaded marcus_easley's headshot (288/1628).
# Downloaded will_tukuafu's headshot (289/1628).
# Downloaded james_develin's headshot (290/1628).
# Downloaded chris_hogan's headshot (291/1628).
# Downloaded jeremy_ross's headshot (292/1628).
# Downloaded scott_tolzien's headshot (293/1628).
# Downloaded larry_donnell's headshot (294/1628).
# Downloaded brian_tyms's headshot (295/1628).
# Downloaded case_keenum's headshot (296/1628).
# Downloaded saalim_hakim's headshot (297/1628).
# Downloaded griff_whalen's headshot (298/1628).
# Downloaded joe_banyard's headshot (299/1628).
# Downloaded derrick_coleman's headshot (300/1628).
# Downloaded matt_simms's headshot (301/1628).
# Downloaded brittan_golden's headshot (302/1628).
# Downloaded bobby_rainey's headshot (303/1628).
# Downloaded sean_mcgrath's headshot (304/1628).
# Downloaded chase_ford's headshot (305/1628).
# Downloaded chris_polk's headshot (306/1628).
# Downloaded jamize_olawale's headshot (307/1628).
# Downloaded brandon_bostick's headshot (308/1628).
# Downloaded nick_toon's headshot (309/1628).
# Downloaded fozzy_whittaker's headshot (310/1628).
# Downloaded benny_cunningham's headshot (311/1628).
# Downloaded nick_williams's headshot (312/1628).
# Downloaded c.j._anderson's headshot (313/1628).
# Downloaded marqueis_gray's headshot (314/1628).
# Downloaded joseph_fauria's headshot (315/1628).
# Downloaded kyle_juszczyk's headshot (316/1628).
# Downloaded timothy_wright's headshot (317/1628).
# Downloaded zach_line's headshot (318/1628).
# Downloaded kenbrell_thompkins's headshot (319/1628).
# Downloaded marquess_wilson's headshot (320/1628).
# Downloaded chris_gragg's headshot (321/1628).
# Downloaded zach_ertz's headshot (322/1628).
# Downloaded marquise_goodwin's headshot (323/1628).
# Downloaded kenny_stills's headshot (324/1628).
# Downloaded luke_willson's headshot (325/1628).
# Downloaded theo_riddick's headshot (326/1628).
# Downloaded ryan_griffin's headshot (327/1628).
# Downloaded tommy_bohanon's headshot (328/1628).
# Downloaded ryan_spadola's headshot (329/1628).
# Downloaded jack_doyle's headshot (330/1628).
# Downloaded josh_hill's headshot (331/1628).
# Downloaded cierre_wood's headshot (332/1628).
# Downloaded myles_white's headshot (333/1628).
# Downloaded keenan_allen's headshot (334/1628).
# Downloaded knile_davis's headshot (335/1628).
# Downloaded stepfan_taylor's headshot (336/1628).
# Downloaded andre_ellington's headshot (337/1628).
# Downloaded jaron_brown's headshot (338/1628).
# Downloaded khiry_robinson's headshot (339/1628).
# Downloaded joseph_randle's headshot (340/1628).
# Downloaded mike_james's headshot (341/1628).
# Downloaded marlon_brown's headshot (342/1628).
# Downloaded spencer_ware's headshot (343/1628).
# Downloaded matt_mcgloin's headshot (344/1628).
# Downloaded dion_sims's headshot (345/1628).
# Downloaded robert_woods's headshot (346/1628).
# Downloaded christine_michael's headshot (347/1628).
# Downloaded mike_gillislee's headshot (348/1628).
# Downloaded levine_toilolo's headshot (349/1628).
# Downloaded giovani_bernard's headshot (350/1628).
# Downloaded markus_wheaton's headshot (351/1628).
# Downloaded kenjon_barner's headshot (352/1628).
# Downloaded vance_mcdonald's headshot (353/1628).
# Downloaded jordan_reed's headshot (354/1628).
# Downloaded josh_boyce's headshot (355/1628).
# Downloaded eddie_lacy's headshot (356/1628).
# Downloaded le'veon_bell's headshot (357/1628).
# Downloaded mychal_rivera's headshot (358/1628).
# Downloaded brice_butler's headshot (359/1628).
# Downloaded mike_glennon's headshot (360/1628).
# Downloaded justin_hunter's headshot (361/1628).
# Downloaded tavon_austin's headshot (362/1628).
# Downloaded ej_manuel's headshot (363/1628).
# Downloaded matt_barkley's headshot (364/1628).
# Downloaded zac_stacy's headshot (365/1628).
# Downloaded aaron_dobson's headshot (366/1628).
# Downloaded terrance_williams's headshot (367/1628).
# Downloaded gavin_escobar's headshot (368/1628).
# Downloaded denard_robinson's headshot (369/1628).
# Downloaded tyler_eifert's headshot (370/1628).
# Downloaded deandre_hopkins's headshot (371/1628).
# Downloaded geno_smith's headshot (372/1628).
# Downloaded cordarrelle_patterson's headshot (373/1628).
# Downloaded chris_williams's headshot (374/1628).
# Downloaded dontrelle_inman's headshot (375/1628).
# Downloaded kamar_aiken's headshot (376/1628).
# Downloaded chris_matthews's headshot (377/1628).
# Downloaded austin_davis's headshot (378/1628).
# Downloaded phillip_supernaw's headshot (379/1628).
# Downloaded derek_carrier's headshot (380/1628).
# Downloaded josh_bellamy's headshot (381/1628).
# Downloaded brenton_bersin's headshot (382/1628).
# Downloaded cooper_helfet's headshot (383/1628).
# Downloaded austin_johnson's headshot (384/1628).
# Downloaded darren_fells's headshot (385/1628).
# Downloaded brandon_williams's headshot (386/1628).
# Downloaded rodney_smith's headshot (387/1628).
# Downloaded adam_thielen's headshot (388/1628).
# Downloaded tavarres_king's headshot (389/1628).
# Downloaded corey_fuller's headshot (390/1628).
# Downloaded charles_d._johnson's headshot (391/1628).
# Downloaded kerwynn_williams's headshot (392/1628).
# Downloaded russell_shepard's headshot (393/1628).
# Downloaded frankie_hammond's headshot (394/1628).
# Downloaded demetrius_harris's headshot (395/1628).
# Downloaded george_winn's headshot (396/1628).
# Downloaded rex_burkhead's headshot (397/1628).
# Downloaded cobi_hamilton's headshot (398/1628).
# Downloaded chris_thompson's headshot (399/1628).
# Downloaded travis_kelce's headshot (400/1628).
# Downloaded latavius_murray's headshot (401/1628).
# Downloaded ryan_nassib's headshot (402/1628).
# Downloaded isaiah_crowell's headshot (403/1628).
# Downloaded connor_shaw's headshot (404/1628).
# Downloaded charcandrick_west's headshot (405/1628).
# Downloaded albert_wilson's headshot (406/1628).
# Downloaded isaiah_burse's headshot (407/1628).
# Downloaded juwan_thompson's headshot (408/1628).
# Downloaded trey_burton's headshot (409/1628).
# Downloaded freddie_martino's headshot (410/1628).
# Downloaded ryan_hewitt's headshot (411/1628).
# Downloaded antonio_andrews's headshot (412/1628).
# Downloaded allen_hurns's headshot (413/1628).
# Downloaded asante_cleveland's headshot (414/1628).
# Downloaded zurlon_tipton's headshot (415/1628).
# Downloaded orleans_darkwa's headshot (416/1628).
# Downloaded damien_williams's headshot (417/1628).
# Downloaded corey_washington's headshot (418/1628).
# Downloaded trey_watts's headshot (419/1628).
# Downloaded josh_huff's headshot (420/1628).
# Downloaded crockett_gillmore's headshot (421/1628).
# Downloaded jeff_janis's headshot (422/1628).
# Downloaded michael_campanaro's headshot (423/1628).
# Downloaded jace_amaro's headshot (424/1628).
# Downloaded troy_niklas's headshot (425/1628).
# Downloaded carlos_hyde's headshot (426/1628).
# Downloaded john_brown's headshot (427/1628).
# Downloaded andre_williams's headshot (428/1628).
# Downloaded ka'deem_carey's headshot (429/1628).
# Downloaded de'anthony_thomas's headshot (430/1628).
# Downloaded james_white's headshot (431/1628).
# Downloaded tom_savage's headshot (432/1628).
# Downloaded lorenzo_taliaferro's headshot (433/1628).
# Downloaded ryan_grant's headshot (434/1628).
# Downloaded alfred_blue's headshot (435/1628).
# Downloaded jay_prosch's headshot (436/1628).
# Downloaded corey_brown's headshot (437/1628).
# Downloaded senorise_perry's headshot (438/1628).
# Downloaded taylor_gabriel's headshot (439/1628).
# Downloaded odell_beckham's headshot (440/1628).
# Downloaded brandin_cooks's headshot (441/1628).
# Downloaded teddy_bridgewater's headshot (442/1628).
# Downloaded storm_johnson's headshot (443/1628).
# Downloaded paul_richardson's headshot (444/1628).
# Downloaded logan_thomas's headshot (445/1628).
# Downloaded cameron_brate's headshot (446/1628).
# Downloaded branden_oliver's headshot (447/1628).
# Downloaded derek_carr's headshot (448/1628).
# Downloaded devonta_freeman's headshot (449/1628).
# Downloaded james_wright's headshot (450/1628).
# Downloaded jordan_matthews's headshot (451/1628).
# Downloaded jeremy_hill's headshot (452/1628).
# Downloaded c.j._fiedorowicz's headshot (453/1628).
# Downloaded devin_street's headshot (454/1628).
# Downloaded sammy_watkins's headshot (455/1628).
# Downloaded bruce_ellington's headshot (456/1628).
# Downloaded kevin_norwood's headshot (457/1628).
# Downloaded fitzgerald_toussaint's headshot (458/1628).
# Downloaded donte_moncrief's headshot (459/1628).
# Downloaded cody_latimer's headshot (460/1628).
# Downloaded jimmy_garoppolo's headshot (461/1628).
# Downloaded kelvin_benjamin's headshot (462/1628).
# Downloaded martavis_bryant's headshot (463/1628).
# Downloaded terrance_west's headshot (464/1628).
# Downloaded jerick_mckinnon's headshot (465/1628).
# Downloaded davante_adams's headshot (466/1628).
# Downloaded jarvis_landry's headshot (467/1628).
# Downloaded richard_rodgers's headshot (468/1628).
# Downloaded eric_ebron's headshot (469/1628).
# Downloaded charles_sims's headshot (470/1628).
# Downloaded blake_bortles's headshot (471/1628).
# Downloaded mike_evans's headshot (472/1628).
# Downloaded johnny_manziel's headshot (473/1628).
# Downloaded bishop_sankey's headshot (474/1628).
# Downloaded austin_seferian-jenkins's headshot (475/1628).
# Downloaded allen_robinson's headshot (476/1628).
# Downloaded marqise_lee's headshot (477/1628).
# Downloaded josh_harris's headshot (478/1628).
# Downloaded kellen_moore's headshot (479/1628).
# Downloaded alex_tanney's headshot (480/1628).
# Downloaded michael_williams's headshot (481/1628).
# Downloaded b.j._daniels's headshot (482/1628).
# Downloaded rashad_ross's headshot (483/1628).
# Downloaded jake_stoneburner's headshot (484/1628).
# Downloaded landry_jones's headshot (485/1628).
# Downloaded jonathan_krause's headshot (486/1628).
# Downloaded willie_snead's headshot (487/1628).
# Downloaded bennie_fowler's headshot (488/1628).
# Downloaded jeremy_butler's headshot (489/1628).
# Downloaded roosevelt_nix's headshot (490/1628).
# Downloaded brandon_coleman's headshot (491/1628).
# Downloaded seantavius_jones's headshot (492/1628).
# Downloaded tony_washington's headshot (493/1628).
# Downloaded javontee_herndon's headshot (494/1628).
# Downloaded jared_abbrederis's headshot (495/1628).
# Downloaded quincy_enunwa's headshot (496/1628).
# Downloaded seth_roberts's headshot (497/1628).
# Downloaded scott_simonson's headshot (498/1628).
# Downloaded t.j._jones's headshot (499/1628).
# Downloaded aj_mccarron's headshot (500/1628).
# Downloaded matt_hazel's headshot (501/1628).
# Downloaded jerome_cunningham's headshot (502/1628).
# Downloaded jarryd_hayne's headshot (503/1628).
# Downloaded jameis_winston's headshot (504/1628).
# Downloaded deandrew_white's headshot (505/1628).
# Downloaded tyler_varga's headshot (506/1628).
# Downloaded trey_williams's headshot (507/1628).
# Downloaded amari_cooper's headshot (508/1628).
# Downloaded devante_parker's headshot (509/1628).
# Downloaded nelson_agholor's headshot (510/1628).
# Downloaded maxx_williams's headshot (511/1628).
# Downloaded jaelen_strong's headshot (512/1628).
# Downloaded jeremy_langford's headshot (513/1628).
# Downloaded justin_hardy's headshot (514/1628).
# Downloaded javorius_allen's headshot (515/1628).
# Downloaded mycole_pruitt's headshot (516/1628).
# Downloaded stefon_diggs's headshot (517/1628).
# Downloaded jay_ajayi's headshot (518/1628).
# Downloaded michael_burton's headshot (519/1628).
# Downloaded nick_boyle's headshot (520/1628).
# Downloaded cameron_artis-payne's headshot (521/1628).
# Downloaded darren_waller's headshot (522/1628).
# Downloaded josh_robinson's headshot (523/1628).
# Downloaded aaron_ripkowski's headshot (524/1628).
# Downloaded zach_zenner's headshot (525/1628).
# Downloaded terron_ward's headshot (526/1628).
# Downloaded corey_grant's headshot (527/1628).
# Downloaded akeem_hunt's headshot (528/1628).
# Downloaded matt_lacosse's headshot (529/1628).
# Downloaded lucky_whitehead's headshot (530/1628).
# Downloaded terrence_magee's headshot (531/1628).
# Downloaded malcolm_brown's headshot (532/1628).
# Downloaded tyler_murphy's headshot (533/1628).
# Downloaded bradley_marquez's headshot (534/1628).
# Downloaded john_crockett's headshot (535/1628).
# Downloaded alonzo_harris's headshot (536/1628).
# Downloaded chris_harper's headshot (537/1628).
# Downloaded thomas_rawls's headshot (538/1628).
# Downloaded rod_smith's headshot (539/1628).
# Downloaded cameron_meredith's headshot (540/1628).
# Downloaded khari_lee's headshot (541/1628).
# Downloaded devin_smith's headshot (542/1628).
# Downloaded matt_jones's headshot (543/1628).
# Downloaded jamison_crowder's headshot (544/1628).
# Downloaded james_o'shaughnessy's headshot (545/1628).
# Downloaded geremy_davis's headshot (546/1628).
# Downloaded marcus_murphy's headshot (547/1628).
# Downloaded mario_alford's headshot (548/1628).
# Downloaded e.j._bibbs's headshot (549/1628).
# Downloaded darius_jennings's headshot (550/1628).
# Downloaded will_tye's headshot (551/1628).
# Downloaded donteea_dye's headshot (552/1628).
# Downloaded adam_humphries's headshot (553/1628).
# Downloaded andrew_turzilli's headshot (554/1628).
# Downloaded devin_funchess's headshot (555/1628).
# Downloaded tevin_coleman's headshot (556/1628).
# Downloaded blake_bell's headshot (557/1628).
# Downloaded mike_davis's headshot (558/1628).
# Downloaded malcolm_johnson's headshot (559/1628).
# Downloaded brian_parker's headshot (560/1628).
# Downloaded daniel_brown's headshot (561/1628).
# Downloaded ameer_abdullah's headshot (562/1628).
# Downloaded j.j._nelson's headshot (563/1628).
# Downloaded kaelin_clay's headshot (564/1628).
# Downloaded nick_o'leary's headshot (565/1628).
# Downloaded tre_mcbride's headshot (566/1628).
# Downloaded chris_conley's headshot (567/1628).
# Downloaded jalston_fowler's headshot (568/1628).
# Downloaded c.j._uzomah's headshot (569/1628).
# Downloaded jesse_james's headshot (570/1628).
# Downloaded geoff_swaim's headshot (571/1628).
# Downloaded melvin_gordon's headshot (572/1628).
# Downloaded trevor_siemian's headshot (573/1628).
# Downloaded tyrell_williams's headshot (574/1628).
# Downloaded sammie_coates's headshot (575/1628).
# Downloaded rashad_greene's headshot (576/1628).
# Downloaded vince_mayle's headshot (577/1628).
# Downloaded ty_montgomery's headshot (578/1628).
# Downloaded phillip_dorsett's headshot (579/1628).
# Downloaded t.j._yeldon's headshot (580/1628).
# Downloaded tyler_lockett's headshot (581/1628).
# Downloaded tyler_kroft's headshot (582/1628).
# Downloaded dorial_green-beckham's headshot (583/1628).
# Downloaded todd_gurley's headshot (584/1628).
# Downloaded sean_mannion's headshot (585/1628).
# Downloaded kasen_williams's headshot (586/1628).
# Downloaded clive_walford's headshot (587/1628).
# Downloaded duke_johnson's headshot (588/1628).
# Downloaded marcus_mariota's headshot (589/1628).
# Downloaded chase_reynolds's headshot (590/1628).
# Downloaded ifeanyi_momah's headshot (591/1628).
# Downloaded je'ron_hamm's headshot (592/1628).
# Downloaded erik_swoope's headshot (593/1628).
# Downloaded keith_smith's headshot (594/1628).
# Downloaded xavier_grimble's headshot (595/1628).
# Downloaded david_fales's headshot (596/1628).
# Downloaded kapri_bibbs's headshot (597/1628).
# Downloaded george_atkinson's headshot (598/1628).
# Downloaded walt_powell's headshot (599/1628).
# Downloaded chris_manhertz's headshot (600/1628).
# Downloaded quan_bray's headshot (601/1628).
# Downloaded randall_telfer's headshot (602/1628).
# Downloaded kevin_white's headshot (603/1628).
# Downloaded bryce_petty's headshot (604/1628).
# Downloaded brett_hundley's headshot (605/1628).
# Downloaded a.j._derby's headshot (606/1628).
# Downloaded shane_wynn's headshot (607/1628).
# Downloaded raheem_mostert's headshot (608/1628).
# Downloaded jordan_taylor's headshot (609/1628).
# Downloaded connor_hamlett's headshot (610/1628).
# Downloaded eli_rogers's headshot (611/1628).
# Downloaded matt_lengel's headshot (612/1628).
# Downloaded terrell_watson's headshot (613/1628).
# Downloaded damiere_byrd's headshot (614/1628).
# Downloaded isaac_fruechte's headshot (615/1628).
# Downloaded mack_brown's headshot (616/1628).
# Downloaded breshad_perriman's headshot (617/1628).
# Downloaded deandre_smelter's headshot (618/1628).
# Downloaded dezmin_lewis's headshot (619/1628).
# Downloaded neal_sterling's headshot (620/1628).
# Downloaded ben_koyack's headshot (621/1628).
# Downloaded gerald_christian's headshot (622/1628).
# Downloaded jeff_heuerman's headshot (623/1628).
# Downloaded bronson_hill's headshot (624/1628).
# Downloaded ross_travis's headshot (625/1628).
# Downloaded chester_rogers's headshot (626/1628).
# Downloaded maurice_harris's headshot (627/1628).
# Downloaded demarcus_ayers's headshot (628/1628).
# Downloaded rob_kelley's headshot (629/1628).
# Downloaded joe_kerridge's headshot (630/1628).
# Downloaded josh_ferguson's headshot (631/1628).
# Downloaded sterling_shepard's headshot (632/1628).
# Downloaded austin_hooper's headshot (633/1628).
# Downloaded c.j._prosise's headshot (634/1628).
# Downloaded nick_vannett's headshot (635/1628).
# Downloaded chris_moore's headshot (636/1628).
# Downloaded malcolm_mitchell's headshot (637/1628).
# Downloaded tyler_ervin's headshot (638/1628).
# Downloaded kenneth_dixon's headshot (639/1628).
# Downloaded paul_perkins's headshot (640/1628).
# Downloaded trevor_davis's headshot (641/1628).
# Downloaded alex_collins's headshot (642/1628).
# Downloaded jerell_adams's headshot (643/1628).
# Downloaded david_morgan's headshot (644/1628).
# Downloaded aaron_burbridge's headshot (645/1628).
# Downloaded dwayne_washington's headshot (646/1628).
# Downloaded trevone_boykin's headshot (647/1628).
# Downloaded kalif_raymond's headshot (648/1628).
# Downloaded tanner_mcevoy's headshot (649/1628).
# Downloaded bralon_addison's headshot (650/1628).
# Downloaded hakeem_valles's headshot (651/1628).
# Downloaded braedon_bowman's headshot (652/1628).
# Downloaded henry_krieger-coble's headshot (653/1628).
# Downloaded alex_erickson's headshot (654/1628).
# Downloaded cole_wick's headshot (655/1628).
# Downloaded d.j._foster's headshot (656/1628).
# Downloaded brandon_wilds's headshot (657/1628).
# Downloaded joshua_perkins's headshot (658/1628).
# Downloaded j.d._mckissic's headshot (659/1628).
# Downloaded geronimo_allison's headshot (660/1628).
# Downloaded roger_lewis's headshot (661/1628).
# Downloaded ben_braunecker's headshot (662/1628).
# Downloaded paul_mcroberts's headshot (663/1628).
# Downloaded robbie_chosen's headshot (664/1628).
# Downloaded jalin_marshall's headshot (665/1628).
# Downloaded bryce_treggs's headshot (666/1628).
# Downloaded stephen_anderson's headshot (667/1628).
# Downloaded wendall_williams's headshot (668/1628).
# Downloaded peyton_barber's headshot (669/1628).
# Downloaded alan_cross's headshot (670/1628).
# Downloaded josh_doctson's headshot (671/1628).
# Downloaded derrick_henry's headshot (672/1628).
# Downloaded michael_thomas's headshot (673/1628).
# Downloaded tajae_sharpe's headshot (674/1628).
# Downloaded jordan_howard's headshot (675/1628).
# Downloaded wendell_smallwood's headshot (676/1628).
# Downloaded kevin_hogan's headshot (677/1628).
# Downloaded jakeem_grant's headshot (678/1628).
# Downloaded dan_vitale's headshot (679/1628).
# Downloaded cody_core's headshot (680/1628).
# Downloaded daniel_braverman's headshot (681/1628).
# Downloaded daniel_lasco's headshot (682/1628).
# Downloaded paul_turner's headshot (683/1628).
# Downloaded brandon_burks's headshot (684/1628).
# Downloaded alex_ellis's headshot (685/1628).
# Downloaded tommylee_lewis's headshot (686/1628).
# Downloaded derek_watt's headshot (687/1628).
# Downloaded kenneth_farrow's headshot (688/1628).
# Downloaded johnny_holton's headshot (689/1628).
# Downloaded deandre_washington's headshot (690/1628).
# Downloaded carson_wentz's headshot (691/1628).
# Downloaded laquon_treadwell's headshot (692/1628).
# Downloaded andy_janovich's headshot (693/1628).
# Downloaded charone_peake's headshot (694/1628).
# Downloaded byron_marshall's headshot (695/1628).
# Downloaded corey_coleman's headshot (696/1628).
# Downloaded devontae_booker's headshot (697/1628).
# Downloaded jordan_payton's headshot (698/1628).
# Downloaded jonathan_williams's headshot (699/1628).
# Downloaded rashard_higgins's headshot (700/1628).
# Downloaded tyler_boyd's headshot (701/1628).
# Downloaded jalen_richard's headshot (702/1628).
# Downloaded tyreek_hill's headshot (703/1628).
# Downloaded ezekiel_elliott's headshot (704/1628).
# Downloaded leonte_carroo's headshot (705/1628).
# Downloaded braxton_miller's headshot (706/1628).
# Downloaded dak_prescott's headshot (707/1628).
# Downloaded ricardo_louis's headshot (708/1628).
# Downloaded seth_devalve's headshot (709/1628).
# Downloaded hunter_henry's headshot (710/1628).
# Downloaded cardale_jones's headshot (711/1628).
# Downloaded cody_kessler's headshot (712/1628).
# Downloaded jared_goff's headshot (713/1628).
# Downloaded paxton_lynch's headshot (714/1628).
# Downloaded tyler_higbee's headshot (715/1628).
# Downloaded pharoh_cooper's headshot (716/1628).
# Downloaded mike_thomas's headshot (717/1628).
# Downloaded kenyan_drake's headshot (718/1628).
# Downloaded jacoby_brissett's headshot (719/1628).
# Downloaded will_fuller's headshot (720/1628).
# Downloaded troymaine_pope's headshot (721/1628).
# Downloaded tyler_bray's headshot (722/1628).
# Downloaded david_fluellen's headshot (723/1628).
# Downloaded bernard_reedy's headshot (724/1628).
# Downloaded eric_tomlinson's headshot (725/1628).
# Downloaded taylor_heinicke's headshot (726/1628).
# Downloaded jordan_leslie's headshot (727/1628).
# Downloaded larry_pinkard's headshot (728/1628).
# Downloaded gabe_holmes's headshot (729/1628).
# Downloaded jake_rudock's headshot (730/1628).
# Downloaded tre_madden's headshot (731/1628).
# Downloaded joe_callahan's headshot (732/1628).
# Downloaded ryan_malleck's headshot (733/1628).
# Downloaded darius_powe's headshot (734/1628).
# Downloaded ed_eagan's headshot (735/1628).
# Downloaded lawrence_thomas's headshot (736/1628).
# Downloaded demarcus_robinson's headshot (737/1628).
# Downloaded nate_sudfeld's headshot (738/1628).
# Downloaded elijhaa_penny's headshot (739/1628).
# Downloaded hunter_sharp's headshot (740/1628).
# Downloaded c.j._ham's headshot (741/1628).
# Downloaded k.j._brent's headshot (742/1628).
# Downloaded max_mccaffrey's headshot (743/1628).
# Downloaded marcus_johnson's headshot (744/1628).
# Downloaded jaydon_mickens's headshot (745/1628).
# Downloaded austin_traylor's headshot (746/1628).
# Downloaded marquis_bundy's headshot (747/1628).
# Downloaded marvin_hall's headshot (748/1628).
# Downloaded garrett_griffin's headshot (749/1628).
# Downloaded darrell_daniels's headshot (750/1628).
# Downloaded jojo_natson's headshot (751/1628).
# Downloaded christian_mccaffrey's headshot (752/1628).
# Downloaded curtis_samuel's headshot (753/1628).
# Downloaded george_kittle's headshot (754/1628).
# Downloaded trent_taylor's headshot (755/1628).
# Downloaded aaron_jones's headshot (756/1628).
# Downloaded elijah_mcguire's headshot (757/1628).
# Downloaded devante_mays's headshot (758/1628).
# Downloaded kendrick_bourne's headshot (759/1628).
# Downloaded matt_breida's headshot (760/1628).
# Downloaded cole_hikutini's headshot (761/1628).
# Downloaded cethan_carter's headshot (762/1628).
# Downloaded michael_clark's headshot (763/1628).
# Downloaded patrick_ricard's headshot (764/1628).
# Downloaded leshun_daniels's headshot (765/1628).
# Downloaded jacob_hollister's headshot (766/1628).
# Downloaded de'veon_smith's headshot (767/1628).
# Downloaded antony_auclair's headshot (768/1628).
# Downloaded bobo_wilson's headshot (769/1628).
# Downloaded isaac_whitney's headshot (770/1628).
# Downloaded john_ross's headshot (771/1628).
# Downloaded jehu_chesson's headshot (772/1628).
# Downloaded isaiah_mckenzie's headshot (773/1628).
# Downloaded emanuel_byrd's headshot (774/1628).
# Downloaded samaje_perine's headshot (775/1628).
# Downloaded jeremy_sprinkle's headshot (776/1628).
# Downloaded mike_williams's headshot (777/1628).
# Downloaded deshaun_watson's headshot (778/1628).
# Downloaded james_conner's headshot (779/1628).
# Downloaded mack_hollins's headshot (780/1628).
# Downloaded tarik_cohen's headshot (781/1628).
# Downloaded michael_roberts's headshot (782/1628).
# Downloaded ryan_switzer's headshot (783/1628).
# Downloaded brian_hill's headshot (784/1628).
# Downloaded jamal_agnew's headshot (785/1628).
# Downloaded shelton_gibson's headshot (786/1628).
# Downloaded de'angelo_henderson_sr.'s headshot (787/1628).
# Downloaded noah_brown's headshot (788/1628).
# Downloaded chris_carson's headshot (789/1628).
# Downloaded matt_dayes's headshot (790/1628).
# Downloaded ricky_seals-jones's headshot (791/1628).
# Downloaded tanner_gentry's headshot (792/1628).
# Downloaded cooper_rush's headshot (793/1628).
# Error downloading keelan_cole's headshot: HTTPSConnectionPool(host='static.www.nfl.com', port=443): Max retries exceeded with url: /image/private/f_auto,q_auto/league/djdjurxk3b6y347zirvz (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x122c9e660>, 'Connection to static.www.nfl.com timed out. (connect timeout=None)'))
# Downloaded austin_ekeler's headshot (794/1628).
# Downloaded travis_rudolph's headshot (795/1628).
# Downloaded corey_clement's headshot (796/1628).
# Downloaded tion_green's headshot (797/1628).
# Downloaded justin_davis's headshot (798/1628).
# Downloaded marquez_williams's headshot (799/1628).
# Downloaded trey_edmunds's headshot (800/1628).
# Downloaded dede_westbrook's headshot (801/1628).
# Downloaded chad_hansen's headshot (802/1628).
# Downloaded leonard_fournette's headshot (803/1628).
# Downloaded juju_smith-schuster's headshot (804/1628).
# Downloaded jonnu_smith's headshot (805/1628).
# Downloaded josh_malone's headshot (806/1628).
# Downloaded mitchell_trubisky's headshot (807/1628).
# Downloaded corey_davis's headshot (808/1628).
# Downloaded patrick_mahomes's headshot (809/1628).
# Downloaded o.j._howard's headshot (810/1628).
# Downloaded evan_engram's headshot (811/1628).
# Downloaded david_njoku's headshot (812/1628).
# Downloaded zay_jones's headshot (813/1628).
# Downloaded dalvin_cook's headshot (814/1628).
# Downloaded gerald_everett's headshot (815/1628).
# Downloaded adam_shaheen's headshot (816/1628).
# Downloaded joe_mixon's headshot (817/1628).
# Downloaded deshone_kizer's headshot (818/1628).
# Downloaded alvin_kamara's headshot (819/1628).
# Downloaded cooper_kupp's headshot (820/1628).
# Downloaded taywan_taylor's headshot (821/1628).
# Downloaded ardarius_stewart's headshot (822/1628).
# Downloaded chris_godwin's headshot (823/1628).
# Downloaded kareem_hunt's headshot (824/1628).
# Downloaded d'onta_foreman's headshot (825/1628).
# Downloaded kenny_golladay's headshot (826/1628).
# Downloaded chad_williams's headshot (827/1628).
# Downloaded c.j._beathard's headshot (828/1628).
# Downloaded amara_darboh's headshot (829/1628).
# Downloaded josh_reynolds's headshot (830/1628).
# Downloaded jamaal_williams's headshot (831/1628).
# Downloaded wayne_gallman's headshot (832/1628).
# Downloaded marlon_mack's headshot (833/1628).
# Downloaded nathan_peterman's headshot (834/1628).
# Downloaded stacy_coley's headshot (835/1628).
# Downloaded bradley_sowell's headshot (836/1628).
# Downloaded garrett_gilbert's headshot (837/1628).
# Downloaded deandre_carter's headshot (838/1628).
# Downloaded jake_kumerow's headshot (839/1628).
# Downloaded jeff_driskel's headshot (840/1628).
# Downloaded david_grinnage's headshot (841/1628).
# Downloaded andy_jones's headshot (842/1628).
# Downloaded darius_jackson's headshot (843/1628).
# Downloaded rico_gathers's headshot (844/1628).
# Downloaded mo_alie-cox's headshot (845/1628).
# Downloaded johnny_mundt's headshot (846/1628).
# Downloaded zach_pascal's headshot (847/1628).
# Downloaded alex_armah's headshot (848/1628).
# Downloaded victor_bolden's headshot (849/1628).
# Downloaded nick_mullens's headshot (850/1628).
# Downloaded taysom_hill's headshot (851/1628).
# Downloaded taquan_mizzell's headshot (852/1628).
# Downloaded ricky_ortiz's headshot (853/1628).
# Downloaded tim_patrick's headshot (854/1628).
# Downloaded tim_white's headshot (855/1628).
# Downloaded austin_carr's headshot (856/1628).
# Downloaded keon_hatcher's headshot (857/1628).
# Downloaded anthony_firkser's headshot (858/1628).
# Downloaded isaiah_ford's headshot (859/1628).
# Downloaded gehrig_dieter's headshot (860/1628).
# Downloaded marcus_kemp's headshot (861/1628).
# Downloaded jake_butt's headshot (862/1628).
# Downloaded eric_saubert's headshot (863/1628).
# Downloaded david_moore's headshot (864/1628).
# Downloaded chad_kelly's headshot (865/1628).
# Downloaded jason_croom's headshot (866/1628).
# Downloaded blake_jarwin's headshot (867/1628).
# Downloaded sean_culkin's headshot (868/1628).
# Downloaded tyrone_swoopes's headshot (869/1628).
# Downloaded robert_tonyan's headshot (870/1628).
# Downloaded riley_mccarron's headshot (871/1628).
# Downloaded t.j._logan's headshot (872/1628).
# Downloaded joshua_dobbs's headshot (873/1628).
# Downloaded jordan_leggett's headshot (874/1628).
# Downloaded jeremy_mcnichols's headshot (875/1628).
# Downloaded dan_arnold's headshot (876/1628).
# Downloaded brandon_zylstra's headshot (877/1628).
# Downloaded river_cracraft's headshot (878/1628).
# Downloaded ross_dwelley's headshot (879/1628).
# Downloaded matt_flanagan's headshot (880/1628).
# Downloaded phillip_lindsay's headshot (881/1628).
# Downloaded jeffery_wilson's headshot (882/1628).
# Downloaded will_dissly's headshot (883/1628).
# Downloaded trenton_cannon's headshot (884/1628).
# Downloaded gus_edwards's headshot (885/1628).
# Downloaded de'lance_turner's headshot (886/1628).
# Downloaded mike_boone's headshot (887/1628).
# Downloaded roc_thomas's headshot (888/1628).
# Downloaded dontrell_hilliard's headshot (889/1628).
# Downloaded derrick_willies's headshot (890/1628).
# Downloaded j'mon_moore's headshot (891/1628).
# Downloaded tyler_conklin's headshot (892/1628).
# Downloaded marquez_valdes-scantling's headshot (893/1628).
# Downloaded damion_ratley's headshot (894/1628).
# Downloaded equanimeous_st._brown's headshot (895/1628).
# Downloaded richie_james's headshot (896/1628).
# Downloaded darrel_williams's headshot (897/1628).
# Downloaded chad_beebe's headshot (898/1628).
# Downloaded keith_kirkwood's headshot (899/1628).
# Downloaded jaylen_samuels's headshot (900/1628).
# Downloaded trey_quinn's headshot (901/1628).
# Downloaded josh_rosen's headshot (902/1628).
# Downloaded courtland_sutton's headshot (903/1628).
# Downloaded kerryon_johnson's headshot (904/1628).
# Downloaded dallas_goedert's headshot (905/1628).
# Downloaded anthony_miller's headshot (906/1628).
# Downloaded jordan_akins's headshot (907/1628).
# Downloaded ian_thomas's headshot (908/1628).
# Downloaded keke_coutee's headshot (909/1628).
# Downloaded nyheim_hines's headshot (910/1628).
# Downloaded kyle_lauletta's headshot (911/1628).
# Downloaded daesean_hamilton's headshot (912/1628).
# Downloaded ito_smith's headshot (913/1628).
# Downloaded dalton_schultz's headshot (914/1628).
# Downloaded justin_watson's headshot (915/1628).
# Downloaded jordan_wilkins's headshot (916/1628).
# Downloaded ray-ray_mccloud's headshot (917/1628).
# Downloaded russell_gage's headshot (918/1628).
# Downloaded jordan_thomas's headshot (919/1628).
# Downloaded javon_wims's headshot (920/1628).
# Downloaded dave_williams's headshot (921/1628).
# Downloaded justin_jackson's headshot (922/1628).
# Downloaded josh_adams's headshot (923/1628).
# Downloaded trent_sherfield's headshot (924/1628).
# Downloaded jalen_tolliver's headshot (925/1628).
# Downloaded jawill_davis's headshot (926/1628).
# Downloaded keith_ford's headshot (927/1628).
# Downloaded robert_foster's headshot (928/1628).
# Downloaded cam_phillips's headshot (929/1628).
# Downloaded allen_lazard's headshot (930/1628).
# Downloaded jordan_franks's headshot (931/1628).
# Downloaded j.j._jones's headshot (932/1628).
# Downloaded detrez_newsome's headshot (933/1628).
# Downloaded kyle_allen's headshot (934/1628).
# Downloaded chris_lacy's headshot (935/1628).
# Downloaded shaun_wilson's headshot (936/1628).
# Downloaded vyncint_smith's headshot (937/1628).
# Downloaded brandon_powell's headshot (938/1628).
# Downloaded cameron_batson's headshot (939/1628).
# Downloaded deontay_burnett's headshot (940/1628).
# Downloaded james_washington's headshot (941/1628).
# Downloaded mark_walton's headshot (942/1628).
# Downloaded chase_edmonds's headshot (943/1628).
# Downloaded auden_tate's headshot (944/1628).
# Downloaded darvin_kidsy's headshot (945/1628).
# Downloaded marcell_ateman's headshot (946/1628).
# Downloaded rashaad_penny's headshot (947/1628).
# Downloaded mark_andrews's headshot (948/1628).
# Downloaded michael_gallup's headshot (949/1628).
# Downloaded tre'quan_smith's headshot (950/1628).
# Downloaded christopher_herndon's headshot (951/1628).
# Downloaded antonio_callaway's headshot (952/1628).
# Downloaded christian_kirk's headshot (953/1628).
# Downloaded d.j._chark's headshot (954/1628).
# Downloaded nick_chubb's headshot (955/1628).
# Downloaded lamar_jackson's headshot (956/1628).
# Downloaded durham_smythe's headshot (957/1628).
# Downloaded kalen_ballage's headshot (958/1628).
# Downloaded john_kelly's headshot (959/1628).
# Downloaded ronald_jones's headshot (960/1628).
# Downloaded d.j._moore's headshot (961/1628).
# Downloaded mike_gesicki's headshot (962/1628).
# Downloaded hayden_hurst's headshot (963/1628).
# Downloaded calvin_ridley's headshot (964/1628).
# Downloaded royce_freeman's headshot (965/1628).
# Downloaded saquon_barkley's headshot (966/1628).
# Downloaded sony_michel's headshot (967/1628).
# Downloaded khadarel_hodge's headshot (968/1628).
# Downloaded baker_mayfield's headshot (969/1628).
# Downloaded josh_allen's headshot (970/1628).
# Downloaded dante_pettis's headshot (971/1628).
# Downloaded malik_turner's headshot (972/1628).
# Downloaded sam_darnold's headshot (973/1628).
# Downloaded diontae_spencer's headshot (974/1628).
# Downloaded brandon_allen's headshot (975/1628).
# Downloaded tra_carson's headshot (976/1628).
# Downloaded tevin_jones's headshot (977/1628).
# Downloaded duke_williams's headshot (978/1628).
# Downloaded j.p._holtz's headshot (979/1628).
# Downloaded cyril_grayson's headshot (980/1628).
# Downloaded c.j._board's headshot (981/1628).
# Downloaded cody_hollister's headshot (982/1628).
# Downloaded pharaoh_brown's headshot (983/1628).
# Downloaded robert_davis's headshot (984/1628).
# Downloaded krishawn_hogan's headshot (985/1628).
# Downloaded andre_patton's headshot (986/1628).
# Downloaded greg_ward's headshot (987/1628).
# Downloaded dare_ogunbowale's headshot (988/1628).
# Downloaded fred_brown's headshot (989/1628).
# Downloaded rashard_davis's headshot (990/1628).
# Downloaded steven_mitchell's headshot (991/1628).
# Downloaded cam_sims's headshot (992/1628).
# Downloaded christian_blake's headshot (993/1628).
# Downloaded tim_boyle's headshot (994/1628).
# Downloaded da'mari_scott's headshot (995/1628).
# Downloaded jaleel_scott's headshot (996/1628).
# Downloaded byron_pringle's headshot (997/1628).
# Downloaded deon_yelder's headshot (998/1628).
# ...
# Downloaded john_bates's headshot (1301/1628).
# Downloaded tylan_wallace's headshot (1302/1628).
# Downloaded ihmir_smith-marsette's headshot (1303/1628).
# Downloaded noah_gray's headshot (1304/1628).
# Downloaded larry_rountree's headshot (1305/1628).
# Downloaded racey_mcmath's headshot (1306/1628).
# Downloaded demetric_felton's headshot (1307/1628).
# Downloaded seth_williams's headshot (1308/1628).
# Downloaded kylin_hill's headshot (1309/1628).
# Downloaded jermar_jefferson's headshot (1310/1628).
# Downloaded dax_milne's headshot (1311/1628).
# Downloaded mekhi_sargent's headshot (1312/1628).
# Downloaded adam_prentice's headshot (1313/1628).
# Downloaded jack_stoll's headshot (1314/1628).
# Downloaded brock_wright's headshot (1315/1628).
# Downloaded jaret_patterson's headshot (1316/1628).
# Downloaded jaquan_hardy's headshot (1317/1628).
# Downloaded feleipe_franks's headshot (1318/1628).
# Downloaded kene_nwangwu's headshot (1319/1628).
# Downloaded chris_evans's headshot (1320/1628).
# Downloaded jake_funk's headshot (1321/1628).
# Downloaded ben_skowronek's headshot (1322/1628).
# Downloaded rhamondre_stevenson's headshot (1323/1628).
# Downloaded kylen_granson's headshot (1324/1628).
# Downloaded jaelon_darden's headshot (1325/1628).
# Downloaded sam_ehlinger's headshot (1326/1628).
# Downloaded luke_farrell's headshot (1327/1628).
# Downloaded najee_harris's headshot (1328/1628).
# Downloaded pat_freiermuth's headshot (1329/1628).
# Downloaded davis_mills's headshot (1330/1628).
# Downloaded ja'marr_chase's headshot (1331/1628).
# Downloaded khalil_herbert's headshot (1332/1628).
# Downloaded dazz_newsome's headshot (1333/1628).
# Downloaded c.j._saunders's headshot (1334/1628).
# Downloaded devonta_smith's headshot (1335/1628).
# Downloaded kadarius_toney's headshot (1336/1628).
# Downloaded kenneth_gainwell's headshot (1337/1628).
# Downloaded michael_carter's headshot (1338/1628).
# Downloaded ian_book's headshot (1339/1628).
# Downloaded rondale_moore's headshot (1340/1628).
# Downloaded justin_fields's headshot (1341/1628).
# Downloaded kellen_mond's headshot (1342/1628).
# Downloaded frank_darby's headshot (1343/1628).
# Downloaded terrace_marshall's headshot (1344/1628).
# Downloaded amon-ra_st._brown's headshot (1345/1628).
# Downloaded kyle_pitts's headshot (1346/1628).
# Downloaded trevor_lawrence's headshot (1347/1628).
# Downloaded mac_jones's headshot (1348/1628).
# Downloaded elijah_moore's headshot (1349/1628).
# Downloaded trey_sermon's headshot (1350/1628).
# Downloaded josh_palmer's headshot (1351/1628).
# Downloaded amari_rodgers's headshot (1352/1628).
# Downloaded javonte_williams's headshot (1353/1628).
# Downloaded anthony_schwartz's headshot (1354/1628).
# Downloaded hunter_long's headshot (1355/1628).
# Downloaded tommy_tremble's headshot (1356/1628).
# Downloaded tre'_mckitty's headshot (1357/1628).
# Downloaded trey_lance's headshot (1358/1628).
# Downloaded zach_wilson's headshot (1359/1628).
# Downloaded nsimba_webster's headshot (1360/1628).
# Downloaded andre_baccellia's headshot (1361/1628).
# Downloaded bryce_perkins's headshot (1362/1628).
# Downloaded tyler_mabry's headshot (1363/1628).
# Downloaded isaiah_hodgins's headshot (1364/1628).
# Downloaded mason_kinsey's headshot (1365/1628).
# Downloaded tim_jones's headshot (1366/1628).
# Downloaded d.j._turner's headshot (1367/1628).
# Downloaded spencer_brown's headshot (1368/1628).
# Downloaded quintin_morris's headshot (1369/1628).
# Downloaded simi_fehoko's headshot (1370/1628).
# Downloaded miller_forristall's headshot (1371/1628).
# Downloaded cade_johnson's headshot (1372/1628).
# Downloaded caleb_huntley's headshot (1373/1628).
# Downloaded austin_trammell's headshot (1374/1628).
# Downloaded tutu_atwell's headshot (1375/1628).
# Downloaded jalen_camp's headshot (1376/1628).
# Downloaded jacob_harris's headshot (1377/1628).
# Downloaded kyle_trask's headshot (1378/1628).
# Downloaded avery_williams's headshot (1379/1628).
# Downloaded michael_bandy's headshot (1380/1628).
# Downloaded travis_etienne's headshot (1381/1628).
# Downloaded lance_mccutcheon's headshot (1382/1628).
# Downloaded sam_howell's headshot (1383/1628).
# Downloaded cole_turner's headshot (1384/1628).
# Downloaded tyler_badie's headshot (1385/1628).
# Downloaded grant_calcaterra's headshot (1386/1628).
# Downloaded trestan_ebner's headshot (1387/1628).
# Downloaded dareke_young's headshot (1388/1628).
# Downloaded samori_toure's headshot (1389/1628).
# Downloaded jake_tonges's headshot (1390/1628).
# Downloaded zonovan_knight's headshot (1391/1628).
# Downloaded armani_rogers's headshot (1392/1628).
# Downloaded anthony_brown's headshot (1393/1628).
# Downloaded isiah_pacheco's headshot (1394/1628).
# Downloaded jaylen_warren's headshot (1395/1628).
# Downloaded drake_london's headshot (1396/1628).
# Downloaded chris_olave's headshot (1397/1628).
# Downloaded jameson_williams's headshot (1398/1628).
# Downloaded george_pickens's headshot (1399/1628).
# Downloaded james_cook's headshot (1400/1628).
# Downloaded greg_dulcich's headshot (1401/1628).
# Downloaded rachaad_white's headshot (1402/1628).
# Downloaded david_bell's headshot (1403/1628).
# Downloaded dameon_pierce's headshot (1404/1628).
# Downloaded khalil_shakir's headshot (1405/1628).
# Downloaded tyler_allgeier's headshot (1406/1628).
# Downloaded snoop_conner's headshot (1407/1628).
# Downloaded jerome_ford's headshot (1408/1628).
# Downloaded montrell_washington's headshot (1409/1628).
# Downloaded kyle_philips's headshot (1410/1628).
# Downloaded ty_chandler's headshot (1411/1628).
# Downloaded teagan_quitoriano's headshot (1412/1628).
# Downloaded james_mitchell's headshot (1413/1628).
# Downloaded kevin_harris's headshot (1414/1628).
# Downloaded jalen_nailor's headshot (1415/1628).
# Downloaded keaontay_ingram's headshot (1416/1628).
# Downloaded mike_woods's headshot (1417/1628).
# Downloaded connor_heyward's headshot (1418/1628).
# Downloaded ko_kieft's headshot (1419/1628).
# Downloaded skylar_thompson's headshot (1420/1628).
# Downloaded zander_horvath's headshot (1421/1628).
# Downloaded tanner_conner's headshot (1422/1628).
# Downloaded braylon_sanders's headshot (1423/1628).
# Downloaded brandon_johnson's headshot (1424/1628).
# Downloaded jalen_virgil's headshot (1425/1628).
# Downloaded raheem_blackshear's headshot (1426/1628).
# Downloaded troy_hairston's headshot (1427/1628).
# Downloaded stone_smartt's headshot (1428/1628).
# Downloaded deven_thompkins's headshot (1429/1628).
# Downloaded jordan_mason's headshot (1430/1628).
# Downloaded rashid_shaheed's headshot (1431/1628).
# Downloaded ronnie_rivers's headshot (1432/1628).
# Downloaded malik_davis's headshot (1433/1628).
# Downloaded peyton_hendershot's headshot (1434/1628).
# Downloaded dennis_houston's headshot (1435/1628).
# Downloaded julius_chestnut's headshot (1436/1628).
# Downloaded hassan_haskins's headshot (1437/1628).
# Downloaded alec_pierce's headshot (1438/1628).
# Downloaded jalen_tolbert's headshot (1439/1628).
# Downloaded maurice_alexander's headshot (1440/1628).
# Downloaded garrett_wilson's headshot (1441/1628).
# Downloaded jahan_dotson's headshot (1442/1628).
# Downloaded treylon_burks's headshot (1443/1628).
# Downloaded trey_mcbride's headshot (1444/1628).
# Downloaded velus_jones's headshot (1445/1628).
# Downloaded brian_robinson's headshot (1446/1628).
# Downloaded jelani_woods's headshot (1447/1628).
# Downloaded kavontae_turpin's headshot (1448/1628).
# Downloaded jeremy_ruckert's headshot (1449/1628).
# Downloaded chigoziem_okonkwo's headshot (1450/1628).
# Downloaded romeo_doubs's headshot (1451/1628).
# Downloaded tyrion_davis-price's headshot (1452/1628).
# Downloaded danny_gray's headshot (1453/1628).
# Downloaded brock_purdy's headshot (1454/1628).
# Downloaded isaiah_likely's headshot (1455/1628).
# Downloaded kyren_williams's headshot (1456/1628).
# Downloaded zamir_white's headshot (1457/1628).
# Downloaded jake_ferguson's headshot (1458/1628).
# Downloaded isaiah_spiller's headshot (1459/1628).
# Downloaded charlie_kolar's headshot (1460/1628).
# Downloaded skyy_moore's headshot (1461/1628).
# Downloaded erik_ezukanma's headshot (1462/1628).
# Downloaded pierre_strong's headshot (1463/1628).
# Downloaded kenny_pickett's headshot (1464/1628).
# Downloaded tyquan_thornton's headshot (1465/1628).
# Downloaded bailey_zappe's headshot (1466/1628).
# Downloaded daniel_bellinger's headshot (1467/1628).
# Downloaded wan'dale_robinson's headshot (1468/1628).
# Downloaded breece_hall's headshot (1469/1628).
# Downloaded desmond_ridder's headshot (1470/1628).
# Downloaded christian_watson's headshot (1471/1628).
# Downloaded malik_willis's headshot (1472/1628).
# Downloaded cade_otton's headshot (1473/1628).
# Downloaded kenneth_walker's headshot (1474/1628).
# Downloaded daylen_baldwin's headshot (1475/1628).
# Downloaded josh_ali's headshot (1476/1628).
# Downloaded david_wells's headshot (1477/1628).
# Downloaded jake_browning's headshot (1478/1628).
# Downloaded cody_thompson's headshot (1479/1628).
# Downloaded trishton_jackson's headshot (1480/1628).
# Downloaded bo_melton's headshot (1481/1628).
# Downloaded tyler_goodson's headshot (1482/1628).
# Downloaded britain_covey's headshot (1483/1628).
# Downloaded irvin_charles's headshot (1484/1628).
# Downloaded justyn_ross's headshot (1485/1628).
# Downloaded andrew_ogletree's headshot (1486/1628).
# Downloaded john_fitzpatrick's headshot (1487/1628).
# Downloaded nick_muse's headshot (1488/1628).
# Downloaded jashaun_corbin's headshot (1489/1628).
# Downloaded kwamie_lassiter's headshot (1490/1628).
# Downloaded rod_williams's headshot (1491/1628).
# Downloaded cole_fotheringham's headshot (1492/1628).
# Downloaded lucas_krull's headshot (1493/1628).
# Downloaded john_metchie's headshot (1494/1628).
# Downloaded tucker_fisk's headshot (1495/1628).
# Downloaded calvin_austin's headshot (1496/1628).
# Downloaded israel_abanikanda's headshot (1497/1628).
# Downloaded sean_clifford's headshot (1498/1628).
# Downloaded dontayvion_wicks's headshot (1499/1628).
# Downloaded will_mallory's headshot (1500/1628).
# Downloaded eric_gray's headshot (1501/1628).
# Downloaded evan_hull's headshot (1502/1628).
# Downloaded tyson_bagent's headshot (1503/1628).
# Downloaded keaton_mitchell's headshot (1504/1628).
# Downloaded malik_heath's headshot (1505/1628).
# Downloaded tommy_devito's headshot (1506/1628).
# Downloaded jason_brownlee's headshot (1507/1628).
# Downloaded xavier_gipson's headshot (1508/1628).
# Downloaded bijan_robinson's headshot (1509/1628).
# Downloaded jaxon_smith-njigba's headshot (1510/1628).
# Downloaded quentin_johnston's headshot (1511/1628).
# Downloaded luke_schoonmaker's headshot (1512/1628).
# Downloaded kendre_miller's headshot (1513/1628).
# Downloaded tank_bigsby's headshot (1514/1628).
# Downloaded darnell_washington's headshot (1515/1628).
# Downloaded michael_wilson's headshot (1516/1628).
# Downloaded tre_tucker's headshot (1517/1628).
# Downloaded derius_davis's headshot (1518/1628).
# Downloaded charlie_jones's headshot (1519/1628).
# Downloaded aidan_o'connell's headshot (1520/1628).
# Downloaded clayton_tune's headshot (1521/1628).
# Downloaded dorian_thompson-robinson's headshot (1522/1628).
# Downloaded josh_whyle's headshot (1523/1628).
# Downloaded chase_brown's headshot (1524/1628).
# Downloaded jaren_hall's headshot (1525/1628).
# Downloaded parker_washington's headshot (1526/1628).
# Downloaded kayshon_boutte's headshot (1527/1628).
# Downloaded a.t._perry's headshot (1528/1628).
# Downloaded xavier_hutchinson's headshot (1529/1628).
# Downloaded andrei_iosivas's headshot (1530/1628).
# Downloaded demario_douglas's headshot (1531/1628).
# Downloaded deuce_vaughn's headshot (1532/1628).
# Downloaded antoine_green's headshot (1533/1628).
# Downloaded colton_dowell's headshot (1534/1628).
# Downloaded jalen_brooks's headshot (1535/1628).
# Downloaded ronnie_bell's headshot (1536/1628).
# Downloaded elijah_cooks's headshot (1537/1628).
# Downloaded jordan_mims's headshot (1538/1628).
# Downloaded christopher_brooks's headshot (1539/1628).
# Downloaded emari_demercado's headshot (1540/1628).
# Downloaded julian_hill's headshot (1541/1628).
# Downloaded jake_bobo's headshot (1542/1628).
# Downloaded jaleel_mclaughlin's headshot (1543/1628).
# Downloaded emanuel_wilson's headshot (1544/1628).
# Downloaded rakim_jarrett's headshot (1545/1628).
# Downloaded elijah_dotson's headshot (1546/1628).
# Downloaded malik_cunningham's headshot (1547/1628).
# Downloaded dalton_kincaid's headshot (1548/1628).
# Downloaded brenton_strange's headshot (1549/1628).
# Downloaded jalin_hyatt's headshot (1550/1628).
# Downloaded tyler_scott's headshot (1551/1628).
# Downloaded sean_tucker's headshot (1552/1628).
# Downloaded marvin_mims's headshot (1553/1628).
# Downloaded tank_dell's headshot (1554/1628).
# Downloaded jordan_addison's headshot (1555/1628).
# Downloaded tucker_kraft's headshot (1556/1628).
# Downloaded josh_downs's headshot (1557/1628).
# Downloaded roschon_johnson's headshot (1558/1628).
# Downloaded tyjae_spears's headshot (1559/1628).
# Downloaded devon_achane's headshot (1560/1628).
# Downloaded elijah_higgins's headshot (1561/1628).
# Downloaded payne_durham's headshot (1562/1628).
# Downloaded trey_palmer's headshot (1563/1628).
# Downloaded jonathan_mingo's headshot (1564/1628).
# Downloaded zay_flowers's headshot (1565/1628).
# Downloaded sam_laporta's headshot (1566/1628).
# Downloaded michael_mayer's headshot (1567/1628).
# Downloaded rashee_rice's headshot (1568/1628).
# Downloaded davis_allen's headshot (1569/1628).
# Downloaded puka_nacua's headshot (1570/1628).
# Downloaded zach_evans's headshot (1571/1628).
# Downloaded jahmyr_gibbs's headshot (1572/1628).
# Downloaded luke_musgrave's headshot (1573/1628).
# Downloaded jayden_reed's headshot (1574/1628).
# Downloaded bryce_young's headshot (1575/1628).
# Downloaded will_levis's headshot (1576/1628).
# Downloaded c.j._stroud's headshot (1577/1628).
# Downloaded anthony_richardson's headshot (1578/1628).
# Downloaded zach_charbonnet's headshot (1579/1628).
# Downloaded grant_dubose's headshot (1580/1628).
# Downloaded scott_matlock's headshot (1581/1628).
# Downloaded kenny_mcintosh's headshot (1582/1628).
# Downloaded hunter_luepke's headshot (1583/1628).
# Downloaded nate_adkins's headshot (1584/1628).
# Downloaded jake_haener's headshot (1585/1628).
# Downloaded johnny_wilson's headshot (1586/1628).
# Downloaded carson_steele's headshot (1587/1628).
# Downloaded malik_nabers's headshot (1588/1628).
# Downloaded brock_bowers's headshot (1589/1628).
# Downloaded xavier_legette's headshot (1590/1628).
# Downloaded luke_mccaffrey's headshot (1591/1628).
# Downloaded cade_stover's headshot (1592/1628).
# Downloaded bucky_irving's headshot (1593/1628).
# Downloaded isaac_guerendo's headshot (1594/1628).
# Downloaded sione_vaki's headshot (1595/1628).
# Downloaded audric_estime's headshot (1596/1628).
# Downloaded tyrone_tracy's headshot (1597/1628).
# Downloaded bub_means's headshot (1598/1628).
# Downloaded devaughn_vele's headshot (1599/1628).
# Downloaded brevyn_spann-ford's headshot (1600/1628).
# Downloaded kameron_johnson's headshot (1601/1628).
# Downloaded british_brooks's headshot (1602/1628).
# Downloaded mason_tipton's headshot (1603/1628).
# Downloaded bo_nix's headshot (1604/1628).
# Downloaded blake_corum's headshot (1605/1628).
# Downloaded jordan_whittington's headshot (1606/1628).
# Downloaded a.j._barner's headshot (1607/1628).
# Downloaded braelon_allen's headshot (1608/1628).
# Downloaded isaiah_davis's headshot (1609/1628).
# Downloaded jermaine_burton's headshot (1610/1628).
# Downloaded marshawn_lloyd's headshot (1611/1628).
# Downloaded erick_all's headshot (1612/1628).
# Downloaded jared_wiley's headshot (1613/1628).
# Downloaded theo_johnson's headshot (1614/1628).
# Downloaded jalen_mcmillan's headshot (1615/1628).
# Downloaded troy_franklin's headshot (1616/1628).
# Downloaded jaylen_wright's headshot (1617/1628).
# Downloaded ray_davis's headshot (1618/1628).
# Downloaded adonai_mitchell's headshot (1619/1628).
# Downloaded xavier_worthy's headshot (1620/1628).
# Downloaded keon_coleman's headshot (1621/1628).
# Downloaded ladd_mcconkey's headshot (1622/1628).
# Downloaded caleb_williams's headshot (1623/1628).
# Downloaded rome_odunze's headshot (1624/1628).
# Downloaded malachi_corley's headshot (1625/1628).
# Downloaded trey_benson's headshot (1626/1628).
# Download complete: 1626/1628 images successfully downloaded.

# %% [markdown]
# # Table of Contents
# - [BETTING TRENDS](#betting-trends)
#   - [General](#betting-general)
#   - [Performance as Favorite](#performance-as-favorite)
#   - [Performance as Underdog](#performance-as-underdog)
# - [TEAM TRENDS](#team-trends)
#     - [General](#team-general)
#     - [Defense](#defense)
#     - [Sacks](#sacks)
#     - [Offense](#offense)
#         - [Passing](#passing)
#         - [Rushing](#rushing)
# - [PLAYER TRENDS](#player-trends)
#     - [General](#player-general)
#     - [Quarterbacks](#quarterbacks)
#     - [Running Backs](#running-backs)
#     - [Wide Receivers](#wide-receivers)
#     - [Tight Ends](#tight-ends)
# - [RANDOM](#random)
