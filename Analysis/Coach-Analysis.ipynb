# %%
import math
import sqlite3
import pandas as pd
import warnings
from IPython.display import display
warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# 2024 coaches and lifetime records

import sqlite3
import pandas as pd

# Path to your SQLite database file
db_path = 'data/nfl.db'

# Connect to the SQLite database
conn = sqlite3.connect(db_path)
cursor = conn.cursor()

# Step 1: Fetch the distinct coaches from the 2024 season
query_coaches_2024 = """
SELECT DISTINCT home_coach
FROM Games
WHERE season = 2024 AND home_coach IS NOT NULL;
"""
cursor.execute(query_coaches_2024)
coaches_2024 = cursor.fetchall()

# Convert the list of tuples into a simple list of coach names
coaches_2024 = [coach[0] for coach in coaches_2024]

# Step 2: Query to fetch win/loss data for each coach and team
query = f"""
SELECT home_coach, home_team, 
       SUM(CASE WHEN home_score > away_score THEN 1 ELSE 0 END) AS wins,
       SUM(CASE WHEN home_score < away_score THEN 1 ELSE 0 END) AS losses
FROM Games
WHERE home_coach IN ({','.join('?' for _ in coaches_2024)})
GROUP BY home_coach, home_team;
"""
cursor.execute(query, coaches_2024)
coach_team_wl_data = cursor.fetchall()

# Close the connection
conn.close()

# Step 3: Prepare a dictionary to store win/loss data for each coach and team
coach_team_wl_dict = {}
for coach, team, wins, losses in coach_team_wl_data:
    if coach not in coach_team_wl_dict:
        coach_team_wl_dict[coach] = []
    coach_team_wl_dict[coach].append((team, wins, losses))

# Step 4: Convert to a readable format and print the win/loss records
for coach, team_records in coach_team_wl_dict.items():
    print(f"{coach}:")
    for team, wins, losses in team_records:
        print(f"   - {team}: {wins} Wins, {losses} Losses")
# Out:
# Andy Reid:
#    - KC: 80 Wins, 28 Losses
#    - PHI: 68 Wins, 47 Losses
# Antonio Pierce:
#    - LVR: 5 Wins, 3 Losses
# Brian Callahan:
#    - TEN: 0 Wins, 2 Losses
# Brian Daboll:
#    - NYG: 9 Wins, 9 Losses
# Dan Campbell:
#    - DET: 18 Wins, 12 Losses
# Dan Quinn:
#    - ATL: 23 Wins, 23 Losses
#    - WAS: 1 Wins, 0 Losses
# Dave Canales:
#    - CAR: 0 Wins, 2 Losses
# DeMeco Ryans:
#    - HOU: 9 Wins, 3 Losses
# Dennis Allen:
#    - LVR: 6 Wins, 12 Losses
#    - NO: 10 Wins, 9 Losses
# Doug Pederson:
#    - JAX: 10 Wins, 9 Losses
#    - PHI: 28 Wins, 14 Losses
# Jerod Mayo:
#    - NE: 0 Wins, 1 Losses
# Jim Harbaugh:
#    - LAC: 1 Wins, 1 Losses
#    - SF: 25 Wins, 10 Losses
# John Harbaugh:
#    - BAL: 97 Wins, 41 Losses
# Jonathan Gannon:
#    - ARI: 3 Wins, 8 Losses
# Kevin O'Connell:
#    - MIN: 12 Wins, 8 Losses
# Kevin Stefanski:
#    - CLE: 24 Wins, 12 Losses
# Kyle Shanahan:
#    - SF: 39 Wins, 26 Losses
# Matt Eberflus:
#    - CHI: 9 Wins, 10 Losses
# Matt LaFleur:
#    - GB: 35 Wins, 12 Losses
# Mike Macdonald:
#    - SEA: 2 Wins, 0 Losses
# Mike McCarthy:
#    - DAL: 25 Wins, 12 Losses
#    - GB: 78 Wins, 30 Losses
# Mike McDaniel:
#    - MIA: 14 Wins, 6 Losses
# Mike Tomlin:
#    - PIT: 103 Wins, 44 Losses
# Nick Sirianni:
#    - PHI: 19 Wins, 11 Losses
# Raheem Morris:
#    - ATL: 3 Wins, 5 Losses
#    - TB: 8 Wins, 16 Losses
# Robert Saleh:
#    - NYJ: 11 Wins, 17 Losses
# Sean McDermott:
#    - BUF: 48 Wins, 19 Losses
# Sean McVay:
#    - LAR: 40 Wins, 23 Losses
# Sean Payton:
#    - DEN: 5 Wins, 5 Losses
#    - NO: 86 Wins, 44 Losses
# Shane Steichen:
#    - IND: 6 Wins, 6 Losses
# Todd Bowles:
#    - MIA: 1 Wins, 0 Losses
#    - NYJ: 14 Wins, 18 Losses
#    - TB: 12 Wins, 10 Losses
# Zac Taylor:
#    - CIN: 24 Wins, 22 Losses

# %%
# Find all coaches from current season

games_file_path = 'data/Games.csv'  # Replace with your file path
games_df = pd.read_csv(games_file_path)

# Filter for the 2024 season
season_2024_df = games_df[games_df['season'] == 2024]

# Get unique coach names from both 'away_coach' and 'home_coach' columns
unique_away_coaches = season_2024_df['away_coach'].unique()
unique_home_coaches = season_2024_df['home_coach'].unique()

# Combine the unique away and home coaches into one set
coaches = set(unique_away_coaches).union(set(unique_home_coaches))

# Display the unique coach names for the 2024 season
print("Unique 2024 Coaches:")
for coach in coaches:
    print(coach)
# Out:
# Unique 2024 Coaches:
# Jerod Mayo
# Brian Daboll
# Jonathan Gannon
# Shane Steichen
# Kevin O'Connell
# Nick Sirianni
# Robert Saleh
# Dave Canales
# Antonio Pierce
# Dan Campbell
# Jim Harbaugh
# Mike McCarthy
# Kevin Stefanski
# Todd Bowles
# DeMeco Ryans
# Kyle Shanahan
# Sean McDermott
# Mike Macdonald
# Brian Callahan
# Doug Pederson
# Sean Payton
# Zac Taylor
# Matt Eberflus
# Mike Tomlin
# Dennis Allen
# Dan Quinn
# Raheem Morris
# Mike McDaniel
# Sean McVay
# Matt LaFleur
# Andy Reid
# John Harbaugh

# %%
# Evaluate b2b away game performances by coaches
# Also in Travel-Analysis.ipynb

games_file_path = 'data/Games.csv'  # Replace with the actual path
games_df = pd.read_csv(games_file_path)

# Filter for the 2024 season
season_2024_df = games_df[games_df['season'] == 2024]

# Get unique coach names from both 'away_coach' and 'home_coach' columns
unique_away_coaches = season_2024_df['away_coach'].unique()
unique_home_coaches = season_2024_df['home_coach'].unique()

# Combine the unique away and home coaches into one set
unique_coaches_2024 = set(unique_away_coaches).union(set(unique_home_coaches))

# Filter for games where the coach is in the unique list of 2024 coaches
games_df['coach'] = games_df['away_coach']  # Use away_coach for analysis
games_df = games_df[games_df['coach'].isin(unique_coaches_2024)]

# Ensure that 'b2b_away' column exists, or add it if necessary
# Assume 'b2b_away' is already calculated, if not, add the logic for calculating it

# Analyze ATS performance for B2B away games (yes) and non-B2B away games (no) grouped by coach
b2b_away_coaches = games_df[games_df['b2b_away'] == 'yes'].groupby('coach').apply(
    lambda x: pd.Series({
        'b2b_away_games': len(x),
        'ats_wins': (x['team_covered'] == x['away_team']).sum(),
        'ats_losses': (x['team_covered'] != x['away_team']).sum(),
        'ats_win_pct': (x['team_covered'] == x['away_team']).sum() / len(x)
    })
).sort_values(by='ats_win_pct', ascending=False)

non_b2b_away_coaches = games_df[games_df['b2b_away'] == 'no'].groupby('coach').apply(
    lambda x: pd.Series({
        'non_b2b_away_games': len(x),
        'ats_wins': (x['team_covered'] == x['away_team']).sum(),
        'ats_losses': (x['team_covered'] != x['away_team']).sum(),
        'ats_win_pct': (x['team_covered'] == x['away_team']).sum() / len(x)
    })
).sort_values(by='ats_win_pct', ascending=False)

# Display both analyses
print("ATS Performance for B2B Away Games by Coach (2024):")
print(b2b_away_coaches)

# print("\nATS Performance for Non-B2B Away Games by Coach (2024):")
# print(non_b2b_away_coaches)
# Out:
# ATS Performance for B2B Away Games by Coach (2024):
#                  b2b_away_games  ats_wins  ats_losses  ats_win_pct
# coach
# DeMeco Ryans                1.0       1.0         0.0     1.000000
# Antonio Pierce              1.0       1.0         0.0     1.000000
# Matt LaFleur               12.0       9.0         3.0     0.750000
# Kevin O'Connell             4.0       3.0         1.0     0.750000
# Sean Payton                18.0      13.0         5.0     0.722222
# Zac Taylor                 15.0      10.0         5.0     0.666667
# Shane Steichen              3.0       2.0         1.0     0.666667
# Kyle Shanahan              20.0      13.0         7.0     0.650000
# Robert Saleh                5.0       3.0         2.0     0.600000
# Dennis Allen                5.0       3.0         2.0     0.600000
# John Harbaugh              22.0      13.0         9.0     0.590909
# Andy Reid                  19.0      11.0         8.0     0.578947
# Brian Daboll                9.0       5.0         4.0     0.555556
# Sean McDermott             15.0       8.0         7.0     0.533333
# Jonathan Gannon             2.0       1.0         1.0     0.500000
# Mike McDaniel               6.0       3.0         3.0     0.500000
# Sean McVay                 18.0       9.0         9.0     0.500000
# Dan Campbell                8.0       4.0         4.0     0.500000
# Matt Eberflus               6.0       3.0         3.0     0.500000
# Doug Pederson              17.0       8.0         9.0     0.470588
# Mike Tomlin                21.0       9.0        12.0     0.428571
# Mike McCarthy              23.0       9.0        14.0     0.391304
# Todd Bowles                14.0       5.0         9.0     0.357143
# Dan Quinn                  15.0       5.0        10.0     0.333333
# Nick Sirianni               7.0       2.0         5.0     0.285714
# Kevin Stefanski            13.0       2.0        11.0     0.153846
# Raheem Morris               1.0       0.0         1.0     0.000000

# %%
# From old NFL-Modeling Repo

# %%
import pandas as pd
import plotly.express as px

# Data for Super Bowl-winning coaches and years
# Data for Super Bowl-winning coaches and years
super_bowl_wins_by_coach = {
    'Mike Ditka': ['1985'],
    'Andy Reid': ['2019'],
    'Gary Kubiak': ['2015'],
    'Mike Shanahan': ['1997', '1998'],
    'Tom Coughlin': ['2007', '2011'],
    'Tom Landry': ['1971', '1977'],
    'Mike Tomlin': ['2008'],
    'Weeb Ewbank': ['1968'],
    'Don Shula': ['1972', '1973'],
    'Mike McCarthy': ['2010'],
    'Brian Billick': ['2000'],
    'Mike Holmgren': ['1996'],
    'John Madden': ['1976'],
    'Bill Walsh': ['1981', '1984', '1988'],
    'Hank Stram': ['1969'],
    'Pete Carroll': ['2013'],
    'George Seifert': ['1989', '1994'],
    'Vince Lombardi': ['1966', '1967'],
    'Sean Payton': ['2009'],
    'Chuck Noll': ['1974', '1975', '1978', '1979'],
    'Don McCafferty': ['1970'],
    'Jimmy Johnson': ['1992', '1993'],
    'Barry Switzer': ['1995'],
    'Bill Parcells': ['1986', '1990'],
    'Tony Dungy': ['2006'],
    'Tom Flores': ['1980', '1983'],
    'John Harbaugh': ['2012'],
    'Doug Pederson': ['2017'],
    'Sean McVay': ['2021'],
    'Bill Cowher': ['2005'],
    'Joe Gibbs': ['1982', '1987', '1991'],
    'Bill Belichick': ['2001', '2003', '2004', '2014', '2016', '2018'],
    'Jon Gruden': ['2002'],
    'Bruce Arians': ['2020'],
    'Dick Vermeil': ['1999']
}

# Preparing the data for the timeline
timeline_data = []
for coach, years in super_bowl_wins_by_coach.items():
    for year in years:
        timeline_data.append({'Coach': coach, 'Year': int(year)})

timeline_df = pd.DataFrame(timeline_data)

# Creating an interactive scatter plot using Plotly Express
fig = px.scatter(timeline_df, x='Year', y='Coach', title='Timeline of Super Bowl Wins by Coaches',
                 text='Year', hover_data=['Coach', 'Year'], color='Coach', height=1000)

# Customizing the plot appearance
fig.update_traces(marker=dict(size=10),
                  textposition='top center')
fig.update_layout(showlegend=False,
                  xaxis_title='Year',
                  yaxis_title='Coach',
                  yaxis=dict(categoryorder='total ascending'))

# Displaying the interactive plot
fig.show()
import pandas as pd
import os

# Path to the directory containing the CSV files
coaching_results_path = './data-coaches/coaching-results'  # Replace with the actual path to your CSV files

# Data for Super Bowl-winning coaches and years
super_bowl_wins_by_coach = {
    # Your data here
}

# Dictionary to store the Super Bowl-winning coaches, years, and teams
super_bowl_wins_details = {}

# Loop through the Super Bowl-winning coaches to find the years and teams they won
for coach_name, years in super_bowl_wins_by_coach.items():
    # Convert the coach name to the file name format
    file_name = coach_name.replace(' ', '_') + '.csv'
    file_path = os.path.join(coaching_results_path, file_name)
    coach_data = pd.read_csv(file_path, header=1)

    # Find the rows where "Super Bowl" is mentioned in the "Notes" column
    for year in years:
        winning_year_data = coach_data[coach_data['Year'] == year]
        team = winning_year_data['Tm'].iloc[0] if not winning_year_data.empty else 'Unknown'
        super_bowl_wins_details[(coach_name, int(year))] = team

# Sorting the results by year
sorted_super_bowl_wins_details = sorted(super_bowl_wins_details.items(), key=lambda x: x[0][1])

# Printing the results
for (coach, year), team in sorted_super_bowl_wins_details:
    print(f"{year}: {coach} - {team}")

# %%
# !mkdir data/data-coaches
# !mkdir -p data-coaches/coaching-results/

# %%
# Scrape Newer

import requests
from bs4 import BeautifulSoup, Comment
import pandas as pd
import time
import random
import os
from IPython.display import display, HTML
import csv
from tqdm.notebook import tqdm

### Scrape head coach names URL's ###

url = 'https://www.pro-football-reference.com/coaches/'  # Replace with your URL

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find the table containing the coaches
table = soup.find('table', {'id': 'coaches'})

# Initialize list to store coaches
coaches = []

# Loop through each row in the table
for row in table.find_all('tr'):
    # Initialize a dictionary to store coach data
    coach = {}

    # Extract the coach name and href link
    name_link = row.find('a')
    if name_link:
        coach['name'] = name_link.text
        coach['link'] = name_link['href']

    # Extract the number of super bowls
    super_bowls = row.find('td', {'data-stat': 'championships_super_bowl'})
    if super_bowls and super_bowls.text.strip():
        coach['super_bowls'] = int(super_bowls.text)

    # Extract the number of wins and losses
    wins = row.find('td', {'data-stat': 'wins'})
    if wins and wins.text.strip():
        coach['wins'] = int(wins.text)

    losses = row.find('td', {'data-stat': 'losses'})
    if losses and losses.text.strip():
        coach['losses'] = int(losses.text)

    # Add coach to list if data was found
    if coach:
        coaches.append(coach)
        
#print(f'There have been {coaches.count} head coaches in the NFL') 
print(f'There are {len(coaches)} coaches.')

for coach in coaches:
    print(coach)
        
# Create a DataFrame from the list of coaches
df = pd.DataFrame(coaches)

# Create new 'url' column
df['url'] = 'https://www.pro-football-reference.com' + df['link']

# Save the DataFrame to a CSV file
df.to_csv('./data-coaches/head_coaches_general.csv', index=False)




### Loop Through Coaches ###
# Coaching Results
df = pd.read_csv('./data-coaches/head_coaches_general.csv')

# Get the total number of rows in the DataFrame
total_rows = len(df)

# Initialize the progress bar
for index, row in tqdm(df.iterrows(), total=total_rows):
    url = row['url']
    name = row['name']

    # Send a GET request to the URL
    response = requests.get(url)

    # Parse the HTML content
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the div containing the table
    table_wrapper = soup.find('div', id='all_coaching_results')

    # Find the table within the div (assuming it's the first table)
    table = table_wrapper.find('table')

    # Create a filename using the name
    filename = f"./data-coaches/coaching-results/{name.replace(' ', '_')}.csv"

    # Open a CSV file for writing
    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.writer(csvfile)

        # Iterate through the rows of the table
        for row in table.find_all('tr'):
            # Get all the columns in the row (both th and td elements)
            columns = row.find_all(['th', 'td'])

            # Extract the text from each column
            row_data = [col.text for col in columns]

            # Write the row data to the CSV file
            writer.writerow(row_data)

    print(f'CSV file has been written successfully for {name}.')
    
    time.sleep(2.5)


# ### Team Ranks ###
# # Read the CSV file with pandas
# df = pd.read_csv('./data-coaches/head_coaches_general.csv')

# # Loop through the rows in the DataFrame
# for index, row in df.iterrows():
#     url = row['url']
#     name = row['name']

#     # Send a GET request to the URL
#     response = requests.get(url)

#     # Parse the HTML content
#     soup = BeautifulSoup(response.content, 'html.parser')

#     # Find the div containing the table
#     table_wrapper = soup.find('div', id='all_coaching_ranks')

#     # Find the table within the div (assuming it's the first table)
#     table = table_wrapper.find('table')

#     # Create a filename using the name
#     filename = f"./data-coaches/team-ranks/{name.replace(' ', '_')}_coaching_ranks.csv"

#     # Open a CSV file for writing
#     with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
#         writer = csv.writer(csvfile)

#         # Iterate through the rows of the table
#         for row in table.find_all('tr'):
#             # Get all the columns in the row (both th and td elements)
#             columns = row.find_all(['th', 'td'])

#             # Extract the text from each column
#             row_data = [col.text for col in columns]

#             # Write the row data to the CSV file
#             writer.writerow(row_data)

#     print(f'CSV file has been written successfully for {name}.')
    
#     time.sleep(5)
# Out:
# There are 529 coaches.
# {'name': 'Don Shula', 'link': '/coaches/ShulDo0.htm', 'super_bowls': 2, 'wins': 328, 'losses': 156}
# {'name': 'George Halas', 'link': '/coaches/HalaGe0.htm', 'super_bowls': 0, 'wins': 318, 'losses': 148}
# {'name': 'Bill Belichick', 'link': '/coaches/BeliBi0.htm', 'super_bowls': 6, 'wins': 302, 'losses': 165}
# {'name': 'Andy Reid', 'link': '/coaches/ReidAn0.htm', 'super_bowls': 3, 'wins': 264, 'losses': 144}
# {'name': 'Tom Landry', 'link': '/coaches/LandTo0.htm', 'super_bowls': 2, 'wins': 250, 'losses': 162}
# {'name': 'Curly Lambeau', 'link': '/coaches/LambCu0.htm', 'super_bowls': 0, 'wins': 226, 'losses': 132}
# {'name': 'Paul Brown', 'link': '/coaches/BrowPa0.htm', 'super_bowls': 0, 'wins': 213, 'losses': 104}
# {'name': 'Marty Schottenheimer', 'link': '/coaches/SchoMa0.htm', 'super_bowls': 0, 'wins': 200, 'losses': 126}
# {'name': 'Chuck Noll', 'link': '/coaches/NollCh0.htm', 'super_bowls': 4, 'wins': 193, 'losses': 148}
# {'name': 'Dan Reeves', 'link': '/coaches/ReevDa0.htm', 'super_bowls': 0, 'wins': 190, 'losses': 165}
# {'name': 'Chuck Knox', 'link': '/coaches/KnoxCh0.htm', 'super_bowls': 0, 'wins': 186, 'losses': 147}
# {'name': 'Mike Tomlin', 'link': '/coaches/TomlMi0.htm', 'super_bowls': 1, 'wins': 178, 'losses': 102}
# {'name': 'Jeff Fisher', 'link': '/coaches/FishJe0.htm', 'super_bowls': 0, 'wins': 173, 'losses': 165}
# {'name': 'Bill Parcells', 'link': '/coaches/ParcBi0.htm', 'super_bowls': 2, 'wins': 172, 'losses': 130}
# {'name': 'Pete Carroll', 'link': '/coaches/CarrPe0.htm', 'super_bowls': 1, 'wins': 170, 'losses': 120}
# {'name': 'Tom Coughlin', 'link': '/coaches/CougTo0.htm', 'super_bowls': 2, 'wins': 170, 'losses': 150}
# {'name': 'Mike McCarthy', 'link': '/coaches/McCaMi0.htm', 'super_bowls': 1, 'wins': 170, 'losses': 105}
# {'name': 'Mike Shanahan', 'link': '/coaches/ShanMi0.htm', 'super_bowls': 2, 'wins': 170, 'losses': 138}
# {'name': 'John Harbaugh', 'link': '/coaches/HarbJo0.htm', 'super_bowls': 1, 'wins': 165, 'losses': 101}
# {'name': 'Sean Payton', 'link': '/coaches/PaytSe0.htm', 'super_bowls': 1, 'wins': 164, 'losses': 101}
# {'name': 'Mike Holmgren', 'link': '/coaches/HolmMi0.htm', 'super_bowls': 1, 'wins': 161, 'losses': 111}
# {'name': 'Bud Grant', 'link': '/coaches/GranBu0.htm', 'super_bowls': 0, 'wins': 158, 'losses': 96}
# {'name': 'Joe Gibbs', 'link': '/coaches/GibbJo0.htm', 'super_bowls': 3, 'wins': 154, 'losses': 94}
# {'name': 'Steve Owen', 'link': '/coaches/OwenSt0.htm', 'super_bowls': 0, 'wins': 153, 'losses': 100}
# {'name': 'Bill Cowher', 'link': '/coaches/CowhBi0.htm', 'super_bowls': 1, 'wins': 149, 'losses': 90}
# {'name': 'Marv Levy', 'link': '/coaches/LevyMa0.htm', 'super_bowls': 0, 'wins': 143, 'losses': 112}
# {'name': 'Tony Dungy', 'link': '/coaches/DungTo0.htm', 'super_bowls': 1, 'wins': 139, 'losses': 69}
# {'name': 'John Fox', 'link': '/coaches/FoxxJo0.htm', 'super_bowls': 0, 'wins': 133, 'losses': 123}
# {'name': 'Marvin Lewis', 'link': '/coaches/LewiMa0.htm', 'super_bowls': 0, 'wins': 131, 'losses': 122}
# {'name': 'Hank Stram', 'link': '/coaches/StraHa0.htm', 'super_bowls': 1, 'wins': 131, 'losses': 97}
# {'name': 'Weeb Ewbank', 'link': '/coaches/EwbaWe0.htm', 'super_bowls': 1, 'wins': 130, 'losses': 129}
# {'name': 'Jim Mora', 'link': '/coaches/MoraJi0.htm', 'super_bowls': 0, 'wins': 125, 'losses': 106}
# {'name': 'Sid Gillman', 'link': '/coaches/GillSi0.htm', 'super_bowls': 0, 'wins': 122, 'losses': 99}
# {'name': 'Mike Ditka', 'link': '/coaches/DitkMi0.htm', 'super_bowls': 1, 'wins': 121, 'losses': 95}
# {'name': 'Dick Vermeil', 'link': '/coaches/VermDi0.htm', 'super_bowls': 1, 'wins': 120, 'losses': 109}
# {'name': 'Jon Gruden', 'link': '/coaches/GrudJo0.htm', 'super_bowls': 1, 'wins': 117, 'losses': 112}
# {'name': 'George Allen', 'link': '/coaches/AlleGe0.htm', 'super_bowls': 0, 'wins': 116, 'losses': 47}
# {'name': 'George Seifert', 'link': '/coaches/SeifGe0.htm', 'super_bowls': 2, 'wins': 114, 'losses': 62}
# {'name': 'Norv Turner', 'link': '/coaches/TurnNo0.htm', 'super_bowls': 0, 'wins': 114, 'losses': 122}
# {'name': 'Dennis Green', 'link': '/coaches/GreeDe0.htm', 'super_bowls': 0, 'wins': 113, 'losses': 94}
# {'name': 'Don Coryell', 'link': '/coaches/CoryDo0.htm', 'super_bowls': 0, 'wins': 111, 'losses': 83}
# {'name': 'Buddy Parker', 'link': '/coaches/ParkRa0.htm', 'super_bowls': 0, 'wins': 104, 'losses': 75}
# {'name': 'John Madden', 'link': '/coaches/MaddJo0.htm', 'super_bowls': 1, 'wins': 103, 'losses': 32}
# {'name': 'Ron Rivera', 'link': '/coaches/RiveRo0.htm', 'super_bowls': 0, 'wins': 102, 'losses': 103}
# {'name': 'Tom Flores', 'link': '/coaches/FlorTo0.htm', 'super_bowls': 2, 'wins': 97, 'losses': 87}
# {'name': 'Vince Lombardi', 'link': '/coaches/LombVi0.htm', 'super_bowls': 2, 'wins': 96, 'losses': 34}
# {'name': 'Lou Saban', 'link': '/coaches/SabaLo0.htm', 'super_bowls': 0, 'wins': 95, 'losses': 99}
# {'name': 'Jack Del Rio', 'link': '/coaches/DelRJa0.htm', 'super_bowls': 0, 'wins': 93, 'losses': 94}
# {'name': 'Lovie Smith', 'link': '/coaches/SmitLo0.htm', 'super_bowls': 0, 'wins': 92, 'losses': 100}
# {'name': 'Bill Walsh', 'link': '/coaches/WalsBi0.htm', 'super_bowls': 3, 'wins': 92, 'losses': 59}
# {'name': 'Buck Shaw', 'link': '/coaches/ShawLa0.htm', 'super_bowls': 0, 'wins': 90, 'losses': 55}
# {'name': 'Jimmy Conzelman', 'link': '/coaches/ConzJi0.htm', 'super_bowls': 0, 'wins': 87, 'losses': 63}
# {'name': 'Ted Marchibroda', 'link': '/coaches/MarcTe0.htm', 'super_bowls': 0, 'wins': 87, 'losses': 98}
# {'name': 'Jack Pardee', 'link': '/coaches/PardJa0.htm', 'super_bowls': 0, 'wins': 87, 'losses': 77}
# {'name': 'Jason Garrett', 'link': '/coaches/GarrJa0.htm', 'super_bowls': 0, 'wins': 85, 'losses': 67}
# {'name': 'Sam Wyche', 'link': '/coaches/WychSa0.htm', 'super_bowls': 0, 'wins': 84, 'losses': 107}
# {'name': 'Gary Kubiak', 'link': '/coaches/KubiGa0.htm', 'super_bowls': 1, 'wins': 82, 'losses': 75}
# {'name': 'Bum Phillips', 'link': '/coaches/PhilBu0.htm', 'super_bowls': 0, 'wins': 82, 'losses': 77}
# {'name': 'Wade Phillips', 'link': '/coaches/PhilWa0.htm', 'super_bowls': 0, 'wins': 82, 'losses': 64}
# {'name': 'Dave Wannstedt', 'link': '/coaches/WannDa0.htm', 'super_bowls': 0, 'wins': 82, 'losses': 87}
# {'name': 'Bruce Arians', 'link': '/coaches/AriaBr0.htm', 'super_bowls': 1, 'wins': 80, 'losses': 48}
# {'name': 'Brian Billick', 'link': '/coaches/BillBr0.htm', 'super_bowls': 1, 'wins': 80, 'losses': 64}
# {'name': 'Ray Flaherty', 'link': '/coaches/FlahRa0.htm', 'super_bowls': 0, 'wins': 80, 'losses': 37}
# {'name': 'Jimmy Johnson', 'link': '/coaches/JohnJi0.htm', 'super_bowls': 2, 'wins': 80, 'losses': 64}
# {'name': 'Sean McDermott', 'link': '/coaches/McDeSe0.htm', 'super_bowls': 0, 'wins': 78, 'losses': 43}
# {'name': 'Blanton Collier', 'link': '/coaches/CollBl0.htm', 'super_bowls': 0, 'wins': 76, 'losses': 34}
# {'name': 'Forrest Gregg', 'link': '/coaches/GregFo0.htm', 'super_bowls': 0, 'wins': 75, 'losses': 85}
# {'name': 'John Robinson', 'link': '/coaches/RobiJo0.htm', 'wins': 75, 'losses': 68}
# {'name': 'Bobby Ross', 'link': '/coaches/RossBo0.htm', 'super_bowls': 0, 'wins': 74, 'losses': 63}
# {'name': 'Steve Mariucci', 'link': '/coaches/MariSt0.htm', 'super_bowls': 0, 'wins': 72, 'losses': 67}
# {'name': 'Sean McVay', 'link': '/coaches/McVaSe0.htm', 'super_bowls': 1, 'wins': 72, 'losses': 49}
# {'name': 'Mike Zimmer', 'link': '/coaches/ZimmMi0.htm', 'super_bowls': 0, 'wins': 72, 'losses': 56}
# {'name': 'Dick Nolan', 'link': '/coaches/NolaDi0.htm', 'super_bowls': 0, 'wins': 69, 'losses': 82}
# {'name': 'George Wilson', 'link': '/coaches/WilsGe0.htm', 'super_bowls': 0, 'wins': 68, 'losses': 84}
# {'name': 'Kyle Shanahan', 'link': '/coaches/ShanKy0.htm', 'super_bowls': 0, 'wins': 67, 'losses': 55}
# {'name': 'Wayne Fontes', 'link': '/coaches/FontWa0.htm', 'super_bowls': 0, 'wins': 66, 'losses': 67}
# {'name': 'Mike Smith', 'link': '/coaches/SmitMi0.htm', 'super_bowls': 0, 'wins': 66, 'losses': 46}
# {'name': 'Norm Van Brocklin', 'link': '/coaches/VanBNo0.htm', 'super_bowls': 0, 'wins': 66, 'losses': 100}
# {'name': 'Potsy Clark', 'link': '/coaches/ClarPo0.htm', 'super_bowls': 0, 'wins': 64, 'losses': 42}
# {'name': 'Wally Lemm', 'link': '/coaches/LemmWa0.htm', 'super_bowls': 0, 'wins': 64, 'losses': 64}
# {'name': 'Greasy Neale', 'link': '/coaches/NealGr0.htm', 'super_bowls': 0, 'wins': 63, 'losses': 43}
# {'name': 'Jim Caldwell', 'link': '/coaches/CaldJi0.htm', 'super_bowls': 0, 'wins': 62, 'losses': 50}
# {'name': 'Doug Pederson', 'link': '/coaches/PedeDo0.htm', 'super_bowls': 1, 'wins': 62, 'losses': 58}
# {'name': 'Matt LaFleur', 'link': '/coaches/LaFlMa0.htm', 'super_bowls': 0, 'wins': 61, 'losses': 29}
# {'name': 'Rex Ryan', 'link': '/coaches/RyanRe0.htm', 'super_bowls': 0, 'wins': 61, 'losses': 66}
# {'name': 'Jerry Glanville', 'link': '/coaches/GlanJe0.htm', 'super_bowls': 0, 'wins': 60, 'losses': 69}
# {'name': 'Dick Jauron', 'link': '/coaches/JaurDi0.htm', 'super_bowls': 0, 'wins': 60, 'losses': 82}
# {'name': 'Guy Chamberlin', 'link': '/coaches/ChamGu0.htm', 'super_bowls': 0, 'wins': 58, 'losses': 16}
# {'name': 'Jim Fassel', 'link': '/coaches/FassJi0.htm', 'super_bowls': 0, 'wins': 58, 'losses': 53}
# {'name': 'Joe Kuharich', 'link': '/coaches/KuhaJo0.htm', 'super_bowls': 0, 'wins': 58, 'losses': 81}
# {'name': 'Allie Sherman', 'link': '/coaches/SherAl0.htm', 'wins': 57, 'losses': 51}
# {'name': 'Mike Sherman', 'link': '/coaches/SherMi0.htm', 'wins': 57, 'losses': 39}
# {'name': 'Art Shell', 'link': '/coaches/ShelAr0.htm', 'wins': 56, 'losses': 52}
# {'name': 'Buddy Ryan', 'link': '/coaches/RyanBu0.htm', 'super_bowls': 0, 'wins': 55, 'losses': 55}
# {'name': 'Herm Edwards', 'link': '/coaches/EdwaHe0.htm', 'super_bowls': 0, 'wins': 54, 'losses': 74}
# {'name': 'Ron Meyer', 'link': '/coaches/MeyeRo0.htm', 'super_bowls': 0, 'wins': 54, 'losses': 50}
# {'name': 'Mike Vrabel', 'link': '/coaches/VrabMi0.htm', 'super_bowls': 0, 'wins': 54, 'losses': 45}
# {'name': 'Jim Lee Howell', 'link': '/coaches/HoweJi0.htm', 'wins': 53, 'losses': 27}
# {'name': 'Mike Martz', 'link': '/coaches/MartMi0.htm', 'wins': 53, 'losses': 32}
# {'name': 'Chuck Pagano', 'link': '/coaches/PagaCh0.htm', 'super_bowls': 0, 'wins': 53, 'losses': 43}
# {'name': 'Joe Walton', 'link': '/coaches/WaltJo0.htm', 'super_bowls': 0, 'wins': 53, 'losses': 57}
# {'name': 'Jerry Burns', 'link': '/coaches/BurnJe0.htm', 'wins': 52, 'losses': 43}
# {'name': 'Mike Holovak', 'link': '/coaches/HoloMi0.htm', 'super_bowls': 0, 'wins': 52, 'losses': 47}
# {'name': "Bill O'Brien", 'link': '/coaches/OBriBi0.htm', 'super_bowls': 0, 'wins': 52, 'losses': 48}
# {'name': 'Bart Starr', 'link': '/coaches/StarBa0.htm', 'super_bowls': 0, 'wins': 52, 'losses': 76}
# {'name': 'Roy Andrews', 'link': '/coaches/AndrRo0.htm', 'super_bowls': 0, 'wins': 51, 'losses': 27}
# {'name': 'Monte Clark', 'link': '/coaches/ClarMo0.htm', 'super_bowls': 0, 'wins': 51, 'losses': 67}
# {'name': 'Leeman Bennett', 'link': '/coaches/BennLe0.htm', 'super_bowls': 0, 'wins': 50, 'losses': 69}
# {'name': 'Raymond Berry', 'link': '/coaches/BerrRa0.htm', 'super_bowls': 0, 'wins': 48, 'losses': 39}
# {'name': 'Dom Capers', 'link': '/coaches/CapeDo0.htm', 'super_bowls': 0, 'wins': 48, 'losses': 80}
# {'name': 'Dan Quinn', 'link': '/coaches/QuinDa0.htm', 'super_bowls': 0, 'wins': 48, 'losses': 44}
# {'name': 'Ken Whisenhunt', 'link': '/coaches/WhisKe0.htm', 'super_bowls': 0, 'wins': 48, 'losses': 71}
# {'name': 'Todd Bowles', 'link': '/coaches/BowlTo0.htm', 'super_bowls': 0, 'wins': 47, 'losses': 61}
# {'name': 'Bruce Coslet', 'link': '/coaches/CoslBr0.htm', 'super_bowls': 0, 'wins': 47, 'losses': 77}
# {'name': 'Jim Harbaugh', 'link': '/coaches/HarbJi0.htm', 'wins': 47, 'losses': 22}
# {'name': 'Jim Haslett', 'link': '/coaches/HaslJi0.htm', 'super_bowls': 0, 'wins': 47, 'losses': 61}
# {'name': 'Sam Rutigliano', 'link': '/coaches/RutiSa0.htm', 'wins': 47, 'losses': 50}
# {'name': 'Chuck Fairbanks', 'link': '/coaches/FairCh0.htm', 'super_bowls': 0, 'wins': 46, 'losses': 39}
# {'name': 'Nick Skorich', 'link': '/coaches/SkorNi0.htm', 'super_bowls': 0, 'wins': 45, 'losses': 48}
# {'name': 'Ray Malavasi', 'link': '/coaches/MalaRa0.htm', 'super_bowls': 0, 'wins': 44, 'losses': 41}
# {'name': 'John McKay', 'link': '/coaches/McKaJo0.htm', 'super_bowls': 0, 'wins': 44, 'losses': 88}
# {'name': 'Charley Winner', 'link': '/coaches/WinnCh0.htm', 'super_bowls': 0, 'wins': 44, 'losses': 44}
# {'name': 'Joe Schmidt', 'link': '/coaches/SchmJo0.htm', 'super_bowls': 0, 'wins': 43, 'losses': 34}
# {'name': 'Ray Perkins', 'link': '/coaches/PerkRa0.htm', 'super_bowls': 0, 'wins': 42, 'losses': 75}
# {'name': 'Frank Reich', 'link': '/coaches/ReicFr0.htm', 'super_bowls': 0, 'wins': 41, 'losses': 43}
# {'name': 'Dennis Erickson', 'link': '/coaches/EricDe0.htm', 'super_bowls': 0, 'wins': 40, 'losses': 56}
# {'name': 'Rich Kotite', 'link': '/coaches/KotiRi0.htm', 'super_bowls': 0, 'wins': 40, 'losses': 56}
# {'name': 'Red Miller', 'link': '/coaches/MillRe0.htm', 'super_bowls': 0, 'wins': 40, 'losses': 22}
# {'name': 'John Rauch', 'link': '/coaches/RaucJo0.htm', 'super_bowls': 0, 'wins': 40, 'losses': 28}
# {'name': 'Barry Switzer', 'link': '/coaches/SwitBa0.htm', 'super_bowls': 1, 'wins': 40, 'losses': 24}
# {'name': 'Zac Taylor', 'link': '/coaches/TaylZa0.htm', 'super_bowls': 0, 'wins': 40, 'losses': 48}
# {'name': 'Brad Childress', 'link': '/coaches/ChilBr0.htm', 'wins': 39, 'losses': 35}
# {'name': 'Jim Hanifan', 'link': '/coaches/HaniJi0.htm', 'super_bowls': 0, 'wins': 39, 'losses': 53}
# {'name': 'Walt Michaels', 'link': '/coaches/MichWa0.htm', 'super_bowls': 0, 'wins': 39, 'losses': 47}
# {'name': 'Dan Henning', 'link': '/coaches/HennDa0.htm', 'super_bowls': 0, 'wins': 38, 'losses': 73}
# {'name': 'Doug Marrone', 'link': '/coaches/MarrDo0.htm', 'super_bowls': 0, 'wins': 38, 'losses': 60}
# {'name': 'Nick Sirianni', 'link': '/coaches/SiriNi0.htm', 'wins': 38, 'losses': 19}
# {'name': 'Kevin Stefanski', 'link': '/coaches/StefKe0.htm', 'super_bowls': 0, 'wins': 38, 'losses': 36}
# {'name': 'Ray Rhodes', 'link': '/coaches/RhodRa0.htm', 'super_bowls': 0, 'wins': 37, 'losses': 42}
# {'name': 'Lindy Infante', 'link': '/coaches/InfaLi0.htm', 'super_bowls': 0, 'wins': 36, 'losses': 60}
# {'name': 'Mike Mularkey', 'link': '/coaches/MulaMi0.htm', 'super_bowls': 0, 'wins': 36, 'losses': 53}
# {'name': 'Jay Gruden', 'link': '/coaches/GrudJa0.htm', 'super_bowls': 0, 'wins': 35, 'losses': 49}
# {'name': 'Jack Patera', 'link': '/coaches/PateJa0.htm', 'super_bowls': 0, 'wins': 35, 'losses': 59}
# {'name': 'Tommy Prothro', 'link': '/coaches/ProtTo0.htm', 'super_bowls': 0, 'wins': 35, 'losses': 51}
# {'name': 'Dan Campbell', 'link': '/coaches/CampDa1.htm', 'wins': 34, 'losses': 34}
# {'name': 'Marion Campbell', 'link': '/coaches/CampMa0.htm', 'super_bowls': 0, 'wins': 34, 'losses': 80}
# {'name': 'Chan Gailey', 'link': '/coaches/GailCh0.htm', 'super_bowls': 0, 'wins': 34, 'losses': 46}
# {'name': 'Tommy Hughitt', 'link': '/coaches/HughTo0.htm', 'super_bowls': 0, 'wins': 34, 'losses': 15}
# {'name': 'Matt Nagy', 'link': '/coaches/NagyMa0.htm', 'super_bowls': 0, 'wins': 34, 'losses': 31}
# {'name': 'John Ralston', 'link': '/coaches/RalsJo0.htm', 'super_bowls': 0, 'wins': 34, 'losses': 33}
# {'name': 'Anthony Lynn', 'link': '/coaches/LynnAn0.htm', 'super_bowls': 0, 'wins': 33, 'losses': 32}
# {'name': 'Eric Mangini', 'link': '/coaches/MangEr0.htm', 'super_bowls': 0, 'wins': 33, 'losses': 47}
# {'name': 'Dick Rauch', 'link': '/coaches/RaucDi0.htm', 'super_bowls': 0, 'wins': 33, 'losses': 24}
# {'name': 'Romeo Crennel', 'link': '/coaches/CrenRo0.htm', 'super_bowls': 0, 'wins': 32, 'losses': 63}
# {'name': 'Adam Gase', 'link': '/coaches/GaseAd0.htm', 'super_bowls': 0, 'wins': 32, 'losses': 48}
# {'name': 'Pop Ivy', 'link': '/coaches/IvyxPo0.htm', 'super_bowls': 0, 'wins': 32, 'losses': 42}
# {'name': 'Tony Sparano', 'link': '/coaches/SparTo0.htm', 'super_bowls': 0, 'wins': 32, 'losses': 41}
# {'name': 'Mike Tice', 'link': '/coaches/TiceMi0.htm', 'wins': 32, 'losses': 33}
# {'name': 'Paddy Driscoll', 'link': '/coaches/DrisPa0.htm', 'super_bowls': 0, 'wins': 31, 'losses': 17}
# {'name': 'Jim Mora', 'link': '/coaches/MoraJi1.htm', 'super_bowls': 0, 'wins': 31, 'losses': 33}
# {'name': 'Neill Armstrong', 'link': '/coaches/ArmsNe0.htm', 'super_bowls': 0, 'wins': 30, 'losses': 34}
# {'name': 'Dutch Clark', 'link': '/coaches/ClarDu0.htm', 'super_bowls': 0, 'wins': 30, 'losses': 34}
# {'name': 'Walt Kiesling', 'link': '/coaches/KiesWa0.htm', 'super_bowls': 0, 'wins': 30, 'losses': 55}
# {'name': 'John Mackovic', 'link': '/coaches/MackJo0.htm', 'super_bowls': 0, 'wins': 30, 'losses': 34}
# {'name': 'Mike McCormack', 'link': '/coaches/McCoMi0.htm', 'super_bowls': 0, 'wins': 29, 'losses': 51}
# {'name': 'Jim Schwartz', 'link': '/coaches/SchwJi0.htm', 'super_bowls': 0, 'wins': 29, 'losses': 51}
# {'name': 'Alex Webster', 'link': '/coaches/WebsAl0.htm', 'wins': 29, 'losses': 40}
# {'name': 'Chip Kelly', 'link': '/coaches/KellCh0.htm', 'super_bowls': 0, 'wins': 28, 'losses': 35}
# {'name': 'Kliff Kingsbury', 'link': '/coaches/KingKl0.htm', 'super_bowls': 0, 'wins': 28, 'losses': 37}
# {'name': 'Don McCafferty', 'link': '/coaches/McCaDo0.htm', 'super_bowls': 1, 'wins': 28, 'losses': 17}
# {'name': 'Jock Sutherland', 'link': '/coaches/SuthJo0.htm', 'super_bowls': 0, 'wins': 28, 'losses': 16}
# {'name': 'Vince Tobin', 'link': '/coaches/TobiVi0.htm', 'super_bowls': 0, 'wins': 28, 'losses': 43}
# {'name': 'Red Hickey', 'link': '/coaches/HickHo0.htm', 'super_bowls': 0, 'wins': 27, 'losses': 27}
# {'name': 'Mike McCoy', 'link': '/coaches/McCoMi1.htm', 'super_bowls': 0, 'wins': 27, 'losses': 37}
# {'name': 'Dennis Allen', 'link': '/coaches/AlleDe0.htm', 'wins': 26, 'losses': 51}
# {'name': 'Jack Christiansen', 'link': '/coaches/ChriJa0.htm', 'super_bowls': 0, 'wins': 26, 'losses': 38}
# {'name': 'Dudley DeGroot', 'link': '/coaches/DeGrDu0.htm', 'super_bowls': 0, 'wins': 26, 'losses': 16}
# {'name': 'Joe Philbin', 'link': '/coaches/PhilJo0.htm', 'super_bowls': 0, 'wins': 26, 'losses': 30}
# {'name': 'Hampton Pool', 'link': '/coaches/PoolHa0.htm', 'super_bowls': 0, 'wins': 26, 'losses': 19}
# {'name': 'Dan Devine', 'link': '/coaches/DeviDa0.htm', 'super_bowls': 0, 'wins': 25, 'losses': 27}
# {'name': 'Raheem Morris', 'link': '/coaches/MorrRa0.htm', 'super_bowls': 0, 'wins': 25, 'losses': 41}
# {'name': "Kevin O'Connell", 'link': '/coaches/OConKe0.htm', 'wins': 25, 'losses': 15}
# {'name': 'Jim Trimble', 'link': '/coaches/TrimJi0.htm', 'super_bowls': 0, 'wins': 25, 'losses': 20}
# {'name': 'Joe Bugel', 'link': '/coaches/BugeJo0.htm', 'super_bowls': 0, 'wins': 24, 'losses': 56}
# {'name': 'Butch Davis', 'link': '/coaches/DaviBu0.htm', 'wins': 24, 'losses': 35}
# {'name': 'Brian Flores', 'link': '/coaches/FlorBr0.htm', 'super_bowls': 0, 'wins': 24, 'losses': 25}
# {'name': 'Ralph Jones', 'link': '/coaches/JoneRa0.htm', 'super_bowls': 0, 'wins': 24, 'losses': 10}
# {'name': 'Brandon Staley', 'link': '/coaches/StalBr0.htm', 'wins': 24, 'losses': 24}
# {'name': 'Red Strader', 'link': '/coaches/StraNo0.htm', 'super_bowls': 0, 'wins': 24, 'losses': 22}
# {'name': 'Hunk Anderson', 'link': '/coaches/AndeHu0.htm', 'super_bowls': 0, 'wins': 23, 'losses': 11}
# {'name': 'Al Davis', 'link': '/coaches/DaviAl0.htm', 'super_bowls': 0, 'wins': 23, 'losses': 16}
# {'name': 'Luke Johnsos', 'link': '/coaches/JohnLu0.htm', 'super_bowls': 0, 'wins': 23, 'losses': 11}
# {'name': 'Gene Stallings', 'link': '/coaches/StalGe0.htm', 'super_bowls': 0, 'wins': 23, 'losses': 34}
# {'name': 'June Jones', 'link': '/coaches/JoneJu0.htm', 'super_bowls': 0, 'wins': 22, 'losses': 36}
# {'name': 'Mike McDaniel', 'link': '/coaches/McDaMi0.htm', 'wins': 22, 'losses': 18}
# {'name': 'Mike Munchak', 'link': '/coaches/MuncMi0.htm', 'wins': 22, 'losses': 26}
# {'name': 'Gregg Williams', 'link': '/coaches/WillGr0.htm', 'super_bowls': 0, 'wins': 22, 'losses': 34}
# {'name': 'Joe Bach', 'link': '/coaches/BachJo0.htm', 'super_bowls': 0, 'wins': 21, 'losses': 27}
# {'name': 'Phil Bengtson', 'link': '/coaches/BengPh0.htm', 'super_bowls': 0, 'wins': 21, 'losses': 25}
# {'name': 'Ron Erhardt', 'link': '/coaches/ErhaRo0.htm', 'super_bowls': 0, 'wins': 21, 'losses': 28}
# {'name': 'Leslie Frazier', 'link': '/coaches/FrazLe0.htm', 'wins': 21, 'losses': 32}
# {'name': 'Bill McPeak', 'link': '/coaches/McPeBi0.htm', 'super_bowls': 0, 'wins': 21, 'losses': 46}
# {'name': 'Arthur Smith', 'link': '/coaches/SmitAr0.htm', 'wins': 21, 'losses': 30}
# {'name': 'Harland Svare', 'link': '/coaches/SvarHa0.htm', 'super_bowls': 0, 'wins': 21, 'losses': 48}
# {'name': 'Jim Dooley', 'link': '/coaches/DoolJi0.htm', 'super_bowls': 0, 'wins': 20, 'losses': 36}
# {'name': 'Gus Dorais', 'link': '/coaches/DoraGu0.htm', 'super_bowls': 0, 'wins': 20, 'losses': 31}
# {'name': 'Josh McDaniels', 'link': '/coaches/McDaJo0.htm', 'super_bowls': 0, 'wins': 20, 'losses': 33}
# {'name': 'John Michelosen', 'link': '/coaches/MichJo0.htm', 'super_bowls': 0, 'wins': 20, 'losses': 26}
# {'name': 'Robert Saleh', 'link': '/coaches/SaleRo0.htm', 'wins': 20, 'losses': 36}
# {'name': 'Joe Stydahar', 'link': '/coaches/StydJo0.htm', 'super_bowls': 0, 'wins': 20, 'losses': 28}
# {'name': 'Frankie Albert', 'link': '/coaches/AlbeFr0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 16}
# {'name': 'Red Dawson', 'link': '/coaches/DawsRe0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 25}
# {'name': 'Vic Fangio', 'link': '/coaches/FangVi0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 30}
# {'name': 'Todd Haley', 'link': '/coaches/HaleTo0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 26}
# {'name': 'Dirk Koetter', 'link': '/coaches/KoetDi0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 29}
# {'name': 'David Shula', 'link': '/coaches/ShulDa0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 52}
# {'name': 'Pat Shurmur', 'link': '/coaches/ShurPa0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 46}
# {'name': 'Sammy Baugh', 'link': '/coaches/BaugSa0.htm', 'super_bowls': 0, 'wins': 18, 'losses': 24}
# {'name': 'Bill Callahan', 'link': '/coaches/CallBi0.htm', 'super_bowls': 0, 'wins': 18, 'losses': 25}
# {'name': 'Bill Johnson', 'link': '/coaches/JohnBi0.htm', 'super_bowls': 0, 'wins': 18, 'losses': 15}
# {'name': 'Mike Nolan', 'link': '/coaches/NolaMi0.htm', 'wins': 18, 'losses': 37}
# {'name': 'Darryl Rogers', 'link': '/coaches/RogeDa0.htm', 'super_bowls': 0, 'wins': 18, 'losses': 40}
# {'name': 'Mike Singletary', 'link': '/coaches/SingMi0.htm', 'super_bowls': 0, 'wins': 18, 'losses': 22}
# {'name': 'Bill Austin', 'link': '/coaches/AustBi0.htm', 'super_bowls': 0, 'wins': 17, 'losses': 36}
# {'name': 'Lisle Blackbourn', 'link': '/coaches/BlacLi0.htm', 'super_bowls': 0, 'wins': 17, 'losses': 31}
# {'name': 'Tom Cable', 'link': '/coaches/CablTo0.htm', 'wins': 17, 'losses': 27}
# {'name': 'Brian Daboll', 'link': '/coaches/DaboBr0.htm', 'wins': 17, 'losses': 23}
# {'name': 'Otto Graham', 'link': '/coaches/GrahOt0.htm', 'super_bowls': 0, 'wins': 17, 'losses': 22}
# {'name': 'Dave McGinnis', 'link': '/coaches/McGiDa0.htm', 'super_bowls': 0, 'wins': 17, 'losses': 40}
# {'name': 'Al Saunders', 'link': '/coaches/SaunAl0.htm', 'super_bowls': 0, 'wins': 17, 'losses': 22}
# {'name': 'Dewey Scanlon', 'link': '/coaches/ScanDe0.htm', 'super_bowls': 0, 'wins': 17, 'losses': 15}
# {'name': 'Norm Barry', 'link': '/coaches/BarrNo0.htm', 'super_bowls': 0, 'wins': 16, 'losses': 8}
# {'name': 'Milan Creighton', 'link': '/coaches/CreiMi0.htm', 'super_bowls': 0, 'wins': 16, 'losses': 26}
# {'name': 'Gunther Cunningham', 'link': '/coaches/CunnGu0.htm', 'super_bowls': 0, 'wins': 16, 'losses': 16}
# {'name': 'Turk Edwards', 'link': '/coaches/EdwaTu0.htm', 'super_bowls': 0, 'wins': 16, 'losses': 18}
# {'name': 'Elgie Tobin', 'link': '/coaches/TobiEl0.htm', 'super_bowls': 0, 'wins': 16, 'losses': 3}
# {'name': 'Dave Campo', 'link': '/coaches/CampDa0.htm', 'super_bowls': 0, 'wins': 15, 'losses': 33}
# {'name': 'Rick Forzano', 'link': '/coaches/ForzRi0.htm', 'super_bowls': 0, 'wins': 15, 'losses': 17}
# {'name': 'Earl Potteiger', 'link': '/coaches/PottEa0.htm', 'super_bowls': 0, 'wins': 15, 'losses': 12}
# {'name': 'DeMeco Ryans', 'link': '/coaches/RyanDe0.htm', 'wins': 15, 'losses': 9}
# {'name': 'Nick Saban', 'link': '/coaches/SabaNi0.htm', 'super_bowls': 0, 'wins': 15, 'losses': 17}
# {'name': 'Adam Walsh', 'link': '/coaches/WalsAd0.htm', 'super_bowls': 0, 'wins': 15, 'losses': 5}
# {'name': 'Ed Weir', 'link': '/coaches/WeirEd0.htm', 'super_bowls': 0, 'wins': 15, 'losses': 7}
# {'name': 'Mike White', 'link': '/coaches/WhitMi0.htm', 'wins': 15, 'losses': 17}
# {'name': 'Punk Berryman', 'link': '/coaches/BerrPu0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 10}
# {'name': 'Gus Bradley', 'link': '/coaches/BradGu0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 48}
# {'name': 'Matt Eberflus', 'link': '/coaches/EberMa0.htm', 'wins': 14, 'losses': 26}
# {'name': 'Ray Handley', 'link': '/coaches/HandRa0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 18}
# {'name': 'Bo McMillin', 'link': '/coaches/McMiAl0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 24}
# {'name': 'John McVay', 'link': '/coaches/McVaJo0.htm', 'wins': 14, 'losses': 23}
# {'name': 'Ray Richards', 'link': '/coaches/RichRa0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 21}
# {'name': 'Mike Riley', 'link': '/coaches/RileMi0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 34}
# {'name': 'Gene Ronzani', 'link': '/coaches/RonzGe0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 31}
# {'name': 'Babe Ruetz', 'link': '/coaches/RuetBa0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 11}
# {'name': 'Paul Schissler', 'link': '/coaches/SchiPa0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 29}
# {'name': 'Clark Shaughnessy', 'link': '/coaches/ShauCl0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 7}
# {'name': 'Jim Thorpe', 'link': '/coaches/ThorJi0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 25}
# {'name': 'Bull Behman', 'link': '/coaches/BehmBu0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 20}
# {'name': 'Rich Brooks', 'link': '/coaches/BrooRi0.htm', 'wins': 13, 'losses': 19}
# {'name': 'Joe Collier', 'link': '/coaches/CollJo0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 16}
# {'name': 'Cap Edwards', 'link': '/coaches/EdwaCa0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 11}
# {'name': 'Tom Fears', 'link': '/coaches/FearTo0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 34}
# {'name': 'Arnie Horween', 'link': '/coaches/HorwAr0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 8}
# {'name': 'Ben McAdoo', 'link': '/coaches/McAdBe0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 15}
# {'name': 'Matt Patricia', 'link': '/coaches/PatrMa0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 29}
# {'name': 'Jimmy Phelan', 'link': '/coaches/PhelJi0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 35}
# {'name': 'Shane Steichen', 'link': '/coaches/SteiSh0.htm', 'wins': 13, 'losses': 11}
# {'name': 'Marc Trestman', 'link': '/coaches/TresMa0.htm', 'wins': 13, 'losses': 19}
# {'name': 'Lud Wray', 'link': '/coaches/WrayLu0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 25}
# {'name': 'Jack Depler', 'link': '/coaches/DeplJa0.htm', 'super_bowls': 0, 'wins': 12, 'losses': 21}
# {'name': 'Dick LeBeau', 'link': '/coaches/LeBeDi0.htm', 'super_bowls': 0, 'wins': 12, 'losses': 33}
# {'name': 'Ernie Nevers', 'link': '/coaches/NeveEr0.htm', 'super_bowls': 0, 'wins': 12, 'losses': 27}
# {'name': 'Steve Spurrier', 'link': '/coaches/SpurSt0.htm', 'super_bowls': 0, 'wins': 12, 'losses': 20}
# {'name': 'Rube Ursella', 'link': '/coaches/UrseRu0.htm', 'super_bowls': 0, 'wins': 12, 'losses': 8}
# {'name': 'Jim Zorn', 'link': '/coaches/ZornJi0.htm', 'super_bowls': 0, 'wins': 12, 'losses': 20}
# {'name': 'Bud Carson', 'link': '/coaches/CarsBu0.htm', 'wins': 11, 'losses': 13}
# {'name': 'Lone Star Dietz', 'link': '/coaches/DietLo0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 11}
# {'name': 'Abe Gibron', 'link': '/coaches/GibrAb0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 30}
# {'name': 'Tommy Hudspeth', 'link': '/coaches/HudsTo0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 13}
# {'name': 'Hue Jackson', 'link': '/coaches/JackHu0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 44}
# {'name': 'Vance Joseph', 'link': '/coaches/JoseVa0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 21}
# {'name': 'Frank Kush', 'link': '/coaches/KushFr0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 28}
# {'name': 'Scott Linehan', 'link': '/coaches/LineSc0.htm', 'wins': 11, 'losses': 25}
# {'name': 'John North', 'link': '/coaches/NortJo0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 23}
# {'name': 'Buster Ramsey', 'link': '/coaches/RamsGa0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 16}
# {'name': 'Matt Rhule', 'link': '/coaches/RhulMa0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 27}
# {'name': 'Lou Rymkus', 'link': '/coaches/RymkLo0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 7}
# {'name': 'Greg Schiano', 'link': '/coaches/SchiGr0.htm', 'wins': 11, 'losses': 21}
# {'name': 'Steve Spagnuolo', 'link': '/coaches/SpagSt0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 41}
# {'name': 'Paul Wiggin', 'link': '/coaches/WiggPa0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 24}
# {'name': 'Bert Bell', 'link': '/coaches/BellBe0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 46}
# {'name': 'Guil Falcon', 'link': '/coaches/FalcGu0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 10}
# {'name': 'Harry Gilmer', 'link': '/coaches/GilmHa0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 16}
# {'name': 'Cecil Isbell', 'link': '/coaches/IsbeCe0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 23}
# {'name': 'Joe Judge', 'link': '/coaches/JudgJo0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 23}
# {'name': 'Rod Marinelli', 'link': '/coaches/MariRo0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 38}
# {'name': 'Mike Pettine', 'link': '/coaches/PettMi0.htm', 'wins': 10, 'losses': 22}
# {'name': 'Kay Stephenson', 'link': '/coaches/StepKa0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 26}
# {'name': 'Jack Faulkner', 'link': '/coaches/FaulJa0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 22}
# {'name': 'Al Groh', 'link': '/coaches/GrohAl0.htm', 'wins': 9, 'losses': 7}
# {'name': 'John Mazur', 'link': '/coaches/MazuJo0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 21}
# {'name': 'Cap McEwan', 'link': '/coaches/McEwCa0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 11}
# {'name': 'Nelson Talbot', 'link': '/coaches/TalbNe0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 6}
# {'name': 'Joe Vitt', 'link': '/coaches/VittJo0.htm', 'wins': 9, 'losses': 12}
# {'name': 'Charlie Waller', 'link': '/coaches/WallCh0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 7}
# {'name': 'Bob Waterfield', 'link': '/coaches/WateBo0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 24}
# {'name': 'Bud Wilkinson', 'link': '/coaches/WilkBu0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 20}
# {'name': 'Steve Wilks', 'link': '/coaches/WilkSt0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 19}
# {'name': 'Doc Alexander', 'link': '/coaches/AlexDo0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 8}
# {'name': 'Ed Biles', 'link': '/coaches/BileEd0.htm', 'wins': 8, 'losses': 23}
# {'name': 'Hugh Campbell', 'link': '/coaches/CampHu0.htm', 'wins': 8, 'losses': 22}
# {'name': 'Bob Folwell', 'link': '/coaches/FolwBo0.htm', 'wins': 8, 'losses': 4}
# {'name': 'Jack Forsyth', 'link': '/coaches/ForsJa0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 6}
# {'name': 'Frank Gansz', 'link': '/coaches/GanzFr0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 22}
# {'name': 'Bob Hollway', 'link': '/coaches/HollBo0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 18}
# {'name': 'Ed Khayat', 'link': '/coaches/KhayEd0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 15}
# {'name': 'Dick MacPherson', 'link': '/coaches/McPhDi0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 24}
# {'name': 'Fritz Pollard', 'link': '/coaches/PollFr0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 4}
# {'name': 'Homer Rice', 'link': '/coaches/RiceHo0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 19}
# {'name': 'Carl Storck', 'link': '/coaches/StorCa0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 26}
# {'name': 'Doug Wycoff', 'link': '/coaches/WycoDo0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 9}
# {'name': 'Bill Arnsparger', 'link': '/coaches/ArnsBi0.htm', 'wins': 7, 'losses': 28}
# {'name': 'Rich Bisaccia', 'link': '/coaches/BisaRi0.htm', 'wins': 7, 'losses': 5}
# {'name': 'Hugh Devore', 'link': '/coaches/DevoHu0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 18}
# {'name': 'Frank Filchock', 'link': '/coaches/FilcFr0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 20}
# {'name': 'Jonathan Gannon', 'link': '/coaches/GannJo0.htm', 'wins': 7, 'losses': 17}
# {'name': 'Herb Kopf', 'link': '/coaches/KopfHe0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 22}
# {'name': 'Antonio Pierce', 'link': '/coaches/PierAn0.htm', 'wins': 7, 'losses': 9}
# {'name': 'J.D. Roberts', 'link': '/coaches/RobeJ.0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 25}
# {'name': 'Ralph Scott', 'link': '/coaches/ScotRa0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 8}
# {'name': 'Clipper Smith', 'link': '/coaches/SmitCl0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 16}
# {'name': 'Jerry Williams', 'link': '/coaches/WillJe0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 22}
# {'name': 'Dutch Bergman', 'link': '/coaches/BergDu0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 3}
# {'name': 'Johnny Blood', 'link': '/coaches/BlooJo0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 19}
# {'name': 'Eddie Erdelatz', 'link': '/coaches/ErdeEd0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 10}
# {'name': 'Kevin Gilbride', 'link': '/coaches/GilbKe0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 16}
# {'name': 'Archie Golembeski', 'link': '/coaches/GoleAr0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 5}
# {'name': 'Gus Henderson', 'link': '/coaches/HendGu0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 5}
# {'name': 'Tut Imlay', 'link': '/coaches/ImlaTu0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 3}
# {'name': 'Freddie Kitchens', 'link': '/coaches/KitcFr0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 10}
# {'name': 'Brick Muller', 'link': '/coaches/MullBr0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 3}
# {'name': 'Mike Nixon', 'link': '/coaches/NixoMi0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 30}
# {'name': 'Bob Snyder', 'link': '/coaches/SnydBo0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 6}
# {'name': 'Mac Speedie', 'link': '/coaches/SpeeMa0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 19}
# {'name': 'Jim Tomsula', 'link': '/coaches/TomsJi0.htm', 'wins': 6, 'losses': 11}
# {'name': 'John Armstrong', 'link': '/coaches/ArmsJo0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 2}
# {'name': 'Clem Crowe', 'link': '/coaches/CrowCl0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 12}
# {'name': 'Rod Dowhower', 'link': '/coaches/DowhRo0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 24}
# {'name': 'Hal Erickson', 'link': '/coaches/EricHa0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 8}
# {'name': 'Benny Friedman', 'link': '/coaches/FrieBe0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 9}
# {'name': 'Hal Griffen', 'link': '/coaches/GrifHa0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 6}
# {'name': 'Lane Kiffin', 'link': '/coaches/KiffLa0.htm', 'wins': 5, 'losses': 15}
# {'name': 'Jim Laird', 'link': '/coaches/LairJi0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 7}
# {'name': 'Ken Meyer', 'link': '/coaches/MeyeKe0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 9}
# {'name': 'Marty Mornhinweg', 'link': '/coaches/MornMa0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 27}
# {'name': 'Chris Palmer', 'link': '/coaches/PalmCh0.htm', 'wins': 5, 'losses': 27}
# {'name': 'Harry Robb', 'link': '/coaches/RobbHa0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 13}
# {'name': 'Clive Rush', 'link': '/coaches/RushCl0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 16}
# {'name': 'Dick Todd', 'link': '/coaches/ToddDi0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 4}
# {'name': 'Bulldog Turner', 'link': '/coaches/TurnCl0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 9}
# {'name': 'Herman Ball', 'link': '/coaches/BallHe0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 16}
# {'name': 'Cliff Battles', 'link': '/coaches/BattCl0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 16}
# {'name': 'Scotty Bierce', 'link': '/coaches/BierSc0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 2}
# {'name': 'Hank Bullough', 'link': '/coaches/BullHa0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 18}
# {'name': 'Rob Chudzinski', 'link': '/coaches/ChudRo0.htm', 'wins': 4, 'losses': 12}
# {'name': 'David Culley', 'link': '/coaches/CullDa0.htm', 'wins': 4, 'losses': 13}
# {'name': 'Russ Daugherty', 'link': '/coaches/DaugRu0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 4}
# {'name': 'Aldo Donelli', 'link': '/coaches/DoneAl0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 11}
# {'name': 'Bill Edwards', 'link': '/coaches/EdwaBi0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 9}
# {'name': 'Nathaniel Hackett', 'link': '/coaches/HackNa0.htm', 'wins': 4, 'losses': 11}
# {'name': 'Phil Handler', 'link': '/coaches/HandPh0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 34}
# {'name': 'Norb Hecker', 'link': '/coaches/HeckNo0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 26}
# {'name': 'Ed Hughes', 'link': '/coaches/HughEd0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 9}
# {'name': 'Jim Kendrick', 'link': '/coaches/KendJi0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 7}
# {'name': 'Art Lewis', 'link': '/coaches/LewiAr0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 4}
# {'name': 'Mike Macdonald', 'link': '/coaches/MacdMi0.htm', 'wins': 4, 'losses': 3}
# {'name': 'Gary Moeller', 'link': '/coaches/MoelGa0.htm', 'wins': 4, 'losses': 3}
# {'name': 'Richie Petitbon', 'link': '/coaches/PetiRi0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 12}
# {'name': 'Ed Robinson', 'link': '/coaches/RobiEd0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 4}
# {'name': 'Charley Rogers', 'link': '/coaches/RogeCh0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 4}
# {'name': 'John Sandusky', 'link': '/coaches/SandJo0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 5}
# {'name': 'Howard Schnellenberger', 'link': '/coaches/SchnHo0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 13}
# {'name': 'Joey Sternaman', 'link': '/coaches/SterJo0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 3}
# {'name': 'Hugh Taylor', 'link': '/coaches/TaylHu0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 10}
# {'name': 'Red Weaver', 'link': '/coaches/WeavRe0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 13}
# {'name': 'Richard Williamson', 'link': '/coaches/WillRi0.htm', 'wins': 4, 'losses': 15}
# {'name': 'Swede Youngstrom', 'link': '/coaches/YounSw0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 4}
# {'name': 'Jim Bates', 'link': '/coaches/BateJi0.htm', 'wins': 3, 'losses': 4}
# {'name': 'Wayne Brenkert', 'link': '/coaches/BrenWa0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 7}
# {'name': 'Untz Brewer', 'link': '/coaches/BrewUn0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 5}
# {'name': 'Marty Brill', 'link': '/coaches/BrilMa0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 3}
# {'name': 'Forrest Douds', 'link': '/coaches/DoudJa0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 6}
# {'name': 'Frank Fausch', 'link': '/coaches/FausFr0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 5}
# {'name': 'Perry Fewell', 'link': '/coaches/FewePe0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 8}
# {'name': 'Mike Getto', 'link': '/coaches/GettMi0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 8}
# {'name': 'George Gibson', 'link': '/coaches/GibsGe0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 10}
# {'name': 'Pete Henry', 'link': '/coaches/HenrPe0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 17}
# {'name': 'Wally Hess', 'link': '/coaches/HessWa0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 12}
# {'name': 'Lou Holtz', 'link': '/coaches/HoltLo0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 10}
# {'name': 'Jack Keogh', 'link': '/coaches/KeogJa0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 7}
# {'name': 'Billy Marshall', 'link': '/coaches/MarsBi0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 8}
# {'name': 'Keith Molesworth', 'link': '/coaches/MoleKe0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 9}
# {'name': 'Ted Nesser', 'link': '/coaches/NessTe0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 14}
# {'name': 'Mike Palm', 'link': '/coaches/PalmMi0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 3}
# {'name': 'Pat Peppler', 'link': '/coaches/PeppPa0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 6}
# {'name': 'Bobby Petrino', 'link': '/coaches/PetrBo0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 10}
# {'name': 'Jim Ringo', 'link': '/coaches/RingJi0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 20}
# {'name': 'Les Steckel', 'link': '/coaches/StecLe0.htm', 'wins': 3, 'losses': 13}
# {'name': 'Pete Stinchcomb', 'link': '/coaches/StinPe0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 3}
# {'name': 'John Whelchel', 'link': '/coaches/WhelJo0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 3}
# {'name': 'Darrell Bevell', 'link': '/coaches/BeveDa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 7}
# {'name': 'Pat Boland', 'link': '/coaches/BolaPa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 3}
# {'name': 'Johnny Bryan', 'link': '/coaches/BryaJo0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 13}
# {'name': 'Eddie Casey', 'link': '/coaches/CaseEd0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 8}
# {'name': 'Pete Cawthon', 'link': '/coaches/CawtPe0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 13}
# {'name': 'Jack Chevigny', 'link': '/coaches/ChevJa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 6}
# {'name': 'Al Cornsweet', 'link': '/coaches/CornAl0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 8}
# {'name': 'Luby DiMeolo', 'link': '/coaches/DiMeLu0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 10}
# {'name': 'Bob Dove', 'link': '/coaches/DoveBo0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 2}
# {'name': 'Chuck Drulis', 'link': '/coaches/DrulCh0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 0}
# {'name': 'Marty Feldman', 'link': '/coaches/FeldMa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 15}
# {'name': 'Budge Garrett', 'link': '/coaches/GarrBu0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 1}
# {'name': 'Hank Gillo', 'link': '/coaches/GillHa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 5}
# {'name': 'Hal Hanson', 'link': '/coaches/HansHa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 7}
# {'name': 'Mel Hein', 'link': '/coaches/HeinMe0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 1}
# {'name': 'Harvey Johnson', 'link': '/coaches/JohnHa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 23}
# {'name': 'Aaron Kromer', 'link': '/coaches/KromAa0.htm', 'wins': 2, 'losses': 4}
# {'name': 'Jim Leonard', 'link': '/coaches/LeonJi0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 8}
# {'name': 'Ned Mathews', 'link': '/coaches/MathNe0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 2}
# {'name': 'Harry Mehre', 'link': '/coaches/MehrHa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 5}
# {'name': 'Urban Meyer', 'link': '/coaches/MeyeUr0.htm', 'wins': 2, 'losses': 11}
# {'name': 'Wayne Millner', 'link': '/coaches/MillWa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 8}
# {'name': 'Charley Moran', 'link': '/coaches/MoraCh0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 5}
# {'name': 'Al Pierotti', 'link': '/coaches/PierAl0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 2}
# {'name': 'Ray Prochaska', 'link': '/coaches/ProcRa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 0}
# {'name': 'Terry Robiskie', 'link': '/coaches/RobiTe0.htm', 'wins': 2, 'losses': 6}
# {'name': 'Ted Shipkey', 'link': '/coaches/ShipTe0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 1}
# {'name': 'Herb Sies', 'link': '/coaches/SiesHe0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 3}
# {'name': 'Jerry Smith', 'link': '/coaches/SmitJe0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 3}
# {'name': 'Chuck Studley', 'link': '/coaches/StudCh0.htm', 'wins': 2, 'losses': 8}
# {'name': 'Gus Tebell', 'link': '/coaches/TebeGu0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 1}
# {'name': 'Joe Thomas', 'link': '/coaches/ThomJo0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 9}
# {'name': 'Mel Tucker', 'link': '/coaches/TuckMe0.htm', 'wins': 2, 'losses': 3}
# {'name': 'Rick Venturi', 'link': '/coaches/VentRi0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 17}
# {'name': 'Carl Voyles', 'link': '/coaches/VoylCa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 12}
# {'name': 'Willie Wilkin', 'link': '/coaches/WilkWi0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 2}
# {'name': 'Ray Willsey', 'link': '/coaches/WilsRa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 0}
# {'name': 'Larry Wilson', 'link': '/coaches/WilsLa0.htm', 'wins': 2, 'losses': 1}
# {'name': 'Hoge Workman', 'link': '/coaches/WorkHo0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 8}
# {'name': 'Shorty Barr', 'link': '/coaches/BarrSh0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 2}
# {'name': 'Tom Bettis', 'link': '/coaches/BettTo0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 6}
# {'name': 'Hugo Bezdek', 'link': '/coaches/BezdHu0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 13}
# {'name': 'Fred Bruney', 'link': '/coaches/BrunFr0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 0}
# {'name': 'Brian Callahan', 'link': '/coaches/CallBr0.htm', 'wins': 1, 'losses': 5}
# {'name': 'Cam Cameron', 'link': '/coaches/CameCa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 15}
# {'name': 'Dave Canales', 'link': '/coaches/CanaDa0.htm', 'wins': 1, 'losses': 6}
# {'name': 'Bill Conkright', 'link': '/coaches/ConkRe0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 8}
# {'name': 'Mel Doherty', 'link': '/coaches/DoheMe0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 3}
# {'name': 'Walt Driskill', 'link': '/coaches/DrisWa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 7}
# {'name': 'Charley Ewart', 'link': '/coaches/EwarCh0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 10}
# {'name': 'Jack Fish', 'link': '/coaches/FishJa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 7}
# {'name': 'Fred Gillies', 'link': '/coaches/GillFr0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 5}
# {'name': 'Hinkey Haines', 'link': '/coaches/HainHi0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 3}
# {'name': 'Dick Hanley', 'link': '/coaches/HanlDi0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 1}
# {'name': 'Ernie Hefferle', 'link': '/coaches/HeffEr0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 7}
# {'name': 'Jack Hegarty', 'link': '/coaches/HegaJa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 2}
# {'name': 'Jack Heldt', 'link': '/coaches/HeldJa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 6}
# {'name': 'Max Hicks', 'link': '/coaches/HickMa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 3}
# {'name': 'Herb Joesting', 'link': '/coaches/JoesHe0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 9}
# {'name': 'Al Jolley', 'link': '/coaches/JollAl0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 10}
# {'name': 'Walt Koppisch', 'link': '/coaches/KoppWa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 6}
# {'name': 'Ollie Kraehe', 'link': '/coaches/KraeOl0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 4}
# {'name': 'Lou Mahrt', 'link': '/coaches/MahrLo0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 6}
# {'name': 'Jerod Mayo', 'link': '/coaches/MayoJe0.htm', 'wins': 1, 'losses': 6}
# {'name': 'Pete McCulley', 'link': '/coaches/McCuPe0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 8}
# {'name': 'Ed McKeever', 'link': '/coaches/McKeEd0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 13}
# {'name': 'Ray McLean', 'link': '/coaches/McLeRa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 12}
# {'name': 'Jack Meagher', 'link': '/coaches/MeagJa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 5}
# {'name': 'Frank Nied', 'link': '/coaches/NiedFr0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 3}
# {'name': "Fred O'Connor", 'link': '/coaches/OConFr0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 6}
# {'name': 'Bill Peterson', 'link': '/coaches/PeteBi0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 18}
# {'name': 'Jerry Rosburg', 'link': '/coaches/RosbJe0.htm', 'wins': 1, 'losses': 1}
# {'name': 'Rod Rust', 'link': '/coaches/RustRo0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 15}
# {'name': 'Andy Salata', 'link': '/coaches/SalaAn0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 7}
# {'name': 'Jeff Saturday', 'link': '/coaches/SatuJe0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 7}
# {'name': 'Tom Scott', 'link': '/coaches/ScotTo0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 0}
# {'name': 'Ken Shipp', 'link': '/coaches/ShipKe0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 4}
# {'name': 'Jim Shofner', 'link': '/coaches/ShofJi0.htm', 'wins': 1, 'losses': 6}
# {'name': 'Dick Stanfel', 'link': '/coaches/StanDi0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 3}
# {'name': 'Mal Stevens', 'link': '/coaches/StevMa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 4}
# ...
# CSV file has been written successfully for Bo McMillin.
# CSV file has been written successfully for John McVay.
# CSV file has been written successfully for Ray Richards.
# CSV file has been written successfully for Mike Riley.
# CSV file has been written successfully for Gene Ronzani.
# CSV file has been written successfully for Babe Ruetz.
# CSV file has been written successfully for Paul Schissler.
# CSV file has been written successfully for Clark Shaughnessy.
# CSV file has been written successfully for Jim Thorpe.
# CSV file has been written successfully for Bull Behman.
# CSV file has been written successfully for Rich Brooks.
# CSV file has been written successfully for Joe Collier.
# CSV file has been written successfully for Cap Edwards.
# CSV file has been written successfully for Tom Fears.
# CSV file has been written successfully for Arnie Horween.
# CSV file has been written successfully for Ben McAdoo.
# CSV file has been written successfully for Matt Patricia.
# CSV file has been written successfully for Jimmy Phelan.
# CSV file has been written successfully for Shane Steichen.
# CSV file has been written successfully for Marc Trestman.
# CSV file has been written successfully for Lud Wray.
# CSV file has been written successfully for Jack Depler.
# CSV file has been written successfully for Dick LeBeau.
# CSV file has been written successfully for Ernie Nevers.
# CSV file has been written successfully for Steve Spurrier.
# CSV file has been written successfully for Rube Ursella.
# CSV file has been written successfully for Jim Zorn.
# CSV file has been written successfully for Bud Carson.
# CSV file has been written successfully for Lone Star Dietz.
# CSV file has been written successfully for Abe Gibron.
# CSV file has been written successfully for Tommy Hudspeth.
# CSV file has been written successfully for Hue Jackson.
# CSV file has been written successfully for Vance Joseph.
# CSV file has been written successfully for Frank Kush.
# CSV file has been written successfully for Scott Linehan.
# CSV file has been written successfully for John North.
# CSV file has been written successfully for Buster Ramsey.
# CSV file has been written successfully for Matt Rhule.
# CSV file has been written successfully for Lou Rymkus.
# CSV file has been written successfully for Greg Schiano.
# CSV file has been written successfully for Steve Spagnuolo.
# CSV file has been written successfully for Paul Wiggin.
# CSV file has been written successfully for Bert Bell.
# CSV file has been written successfully for Guil Falcon.
# CSV file has been written successfully for Harry Gilmer.
# CSV file has been written successfully for Cecil Isbell.
# CSV file has been written successfully for Joe Judge.
# CSV file has been written successfully for Rod Marinelli.
# CSV file has been written successfully for Mike Pettine.
# CSV file has been written successfully for Kay Stephenson.
# CSV file has been written successfully for Jack Faulkner.
# CSV file has been written successfully for Al Groh.
# CSV file has been written successfully for John Mazur.
# CSV file has been written successfully for Cap McEwan.
# CSV file has been written successfully for Nelson Talbot.
# CSV file has been written successfully for Joe Vitt.
# CSV file has been written successfully for Charlie Waller.
# CSV file has been written successfully for Bob Waterfield.
# CSV file has been written successfully for Bud Wilkinson.
# CSV file has been written successfully for Steve Wilks.
# CSV file has been written successfully for Doc Alexander.
# CSV file has been written successfully for Ed Biles.
# CSV file has been written successfully for Hugh Campbell.
# CSV file has been written successfully for Bob Folwell.
# CSV file has been written successfully for Jack Forsyth.
# CSV file has been written successfully for Frank Gansz.
# CSV file has been written successfully for Bob Hollway.
# CSV file has been written successfully for Ed Khayat.
# CSV file has been written successfully for Dick MacPherson.
# CSV file has been written successfully for Fritz Pollard.
# CSV file has been written successfully for Homer Rice.
# CSV file has been written successfully for Carl Storck.
# CSV file has been written successfully for Doug Wycoff.
# CSV file has been written successfully for Bill Arnsparger.
# CSV file has been written successfully for Rich Bisaccia.
# CSV file has been written successfully for Hugh Devore.
# CSV file has been written successfully for Frank Filchock.
# CSV file has been written successfully for Jonathan Gannon.
# CSV file has been written successfully for Herb Kopf.
# CSV file has been written successfully for Antonio Pierce.
# CSV file has been written successfully for J.D. Roberts.
# CSV file has been written successfully for Ralph Scott.
# CSV file has been written successfully for Clipper Smith.
# CSV file has been written successfully for Jerry Williams.
# CSV file has been written successfully for Dutch Bergman.
# CSV file has been written successfully for Johnny Blood.
# CSV file has been written successfully for Eddie Erdelatz.
# CSV file has been written successfully for Kevin Gilbride.
# CSV file has been written successfully for Archie Golembeski.
# CSV file has been written successfully for Gus Henderson.
# CSV file has been written successfully for Tut Imlay.
# CSV file has been written successfully for Freddie Kitchens.
# CSV file has been written successfully for Brick Muller.
# CSV file has been written successfully for Mike Nixon.
# CSV file has been written successfully for Bob Snyder.
# CSV file has been written successfully for Mac Speedie.
# CSV file has been written successfully for Jim Tomsula.
# CSV file has been written successfully for John Armstrong.
# CSV file has been written successfully for Clem Crowe.
# CSV file has been written successfully for Rod Dowhower.
# CSV file has been written successfully for Hal Erickson.
# CSV file has been written successfully for Benny Friedman.
# CSV file has been written successfully for Hal Griffen.
# CSV file has been written successfully for Lane Kiffin.
# CSV file has been written successfully for Jim Laird.
# CSV file has been written successfully for Ken Meyer.
# CSV file has been written successfully for Marty Mornhinweg.
# CSV file has been written successfully for Chris Palmer.
# CSV file has been written successfully for Harry Robb.
# CSV file has been written successfully for Clive Rush.
# CSV file has been written successfully for Dick Todd.
# CSV file has been written successfully for Bulldog Turner.
# CSV file has been written successfully for Herman Ball.
# CSV file has been written successfully for Cliff Battles.
# CSV file has been written successfully for Scotty Bierce.
# CSV file has been written successfully for Hank Bullough.
# CSV file has been written successfully for Rob Chudzinski.
# CSV file has been written successfully for David Culley.
# CSV file has been written successfully for Russ Daugherty.
# CSV file has been written successfully for Aldo Donelli.
# CSV file has been written successfully for Bill Edwards.
# CSV file has been written successfully for Nathaniel Hackett.
# CSV file has been written successfully for Phil Handler.
# CSV file has been written successfully for Norb Hecker.
# CSV file has been written successfully for Ed Hughes.
# CSV file has been written successfully for Jim Kendrick.
# CSV file has been written successfully for Art Lewis.
# CSV file has been written successfully for Mike Macdonald.
# CSV file has been written successfully for Gary Moeller.
# CSV file has been written successfully for Richie Petitbon.
# CSV file has been written successfully for Ed Robinson.
# CSV file has been written successfully for Charley Rogers.
# CSV file has been written successfully for John Sandusky.
# CSV file has been written successfully for Howard Schnellenberger.
# CSV file has been written successfully for Joey Sternaman.
# CSV file has been written successfully for Hugh Taylor.
# CSV file has been written successfully for Red Weaver.
# CSV file has been written successfully for Richard Williamson.
# CSV file has been written successfully for Swede Youngstrom.
# CSV file has been written successfully for Jim Bates.
# CSV file has been written successfully for Wayne Brenkert.
# CSV file has been written successfully for Untz Brewer.
# CSV file has been written successfully for Marty Brill.
# CSV file has been written successfully for Forrest Douds.
# CSV file has been written successfully for Frank Fausch.
# CSV file has been written successfully for Perry Fewell.
# CSV file has been written successfully for Mike Getto.
# CSV file has been written successfully for George Gibson.
# CSV file has been written successfully for Pete Henry.
# CSV file has been written successfully for Wally Hess.
# CSV file has been written successfully for Lou Holtz.
# CSV file has been written successfully for Jack Keogh.
# CSV file has been written successfully for Billy Marshall.
# CSV file has been written successfully for Keith Molesworth.
# CSV file has been written successfully for Ted Nesser.
# CSV file has been written successfully for Mike Palm.
# CSV file has been written successfully for Pat Peppler.
# CSV file has been written successfully for Bobby Petrino.
# CSV file has been written successfully for Jim Ringo.
# CSV file has been written successfully for Les Steckel.
# CSV file has been written successfully for Pete Stinchcomb.
# CSV file has been written successfully for John Whelchel.
# CSV file has been written successfully for Darrell Bevell.
# CSV file has been written successfully for Pat Boland.
# CSV file has been written successfully for Johnny Bryan.
# CSV file has been written successfully for Eddie Casey.
# CSV file has been written successfully for Pete Cawthon.
# CSV file has been written successfully for Jack Chevigny.
# CSV file has been written successfully for Al Cornsweet.
# CSV file has been written successfully for Luby DiMeolo.
# CSV file has been written successfully for Bob Dove.
# CSV file has been written successfully for Chuck Drulis.
# CSV file has been written successfully for Marty Feldman.
# CSV file has been written successfully for Budge Garrett.
# CSV file has been written successfully for Hank Gillo.
# CSV file has been written successfully for Hal Hanson.
# CSV file has been written successfully for Mel Hein.
# CSV file has been written successfully for Harvey Johnson.
# CSV file has been written successfully for Aaron Kromer.
# CSV file has been written successfully for Jim Leonard.
# CSV file has been written successfully for Ned Mathews.
# CSV file has been written successfully for Harry Mehre.
# CSV file has been written successfully for Urban Meyer.
# CSV file has been written successfully for Wayne Millner.
# CSV file has been written successfully for Charley Moran.
# CSV file has been written successfully for Al Pierotti.
# CSV file has been written successfully for Ray Prochaska.
# CSV file has been written successfully for Terry Robiskie.
# CSV file has been written successfully for Ted Shipkey.
# CSV file has been written successfully for Herb Sies.
# CSV file has been written successfully for Jerry Smith.
# CSV file has been written successfully for Chuck Studley.
# CSV file has been written successfully for Gus Tebell.
# CSV file has been written successfully for Joe Thomas.
# CSV file has been written successfully for Mel Tucker.
# CSV file has been written successfully for Rick Venturi.
# CSV file has been written successfully for Carl Voyles.
# CSV file has been written successfully for Willie Wilkin.
# CSV file has been written successfully for Ray Willsey.
# CSV file has been written successfully for Larry Wilson.
# CSV file has been written successfully for Hoge Workman.
# CSV file has been written successfully for Shorty Barr.
# CSV file has been written successfully for Tom Bettis.
# CSV file has been written successfully for Hugo Bezdek.
# CSV file has been written successfully for Fred Bruney.
# CSV file has been written successfully for Brian Callahan.
# CSV file has been written successfully for Cam Cameron.
# CSV file has been written successfully for Dave Canales.
# CSV file has been written successfully for Bill Conkright.
# CSV file has been written successfully for Mel Doherty.
# CSV file has been written successfully for Walt Driskill.
# CSV file has been written successfully for Charley Ewart.
# CSV file has been written successfully for Jack Fish.
# CSV file has been written successfully for Fred Gillies.
# CSV file has been written successfully for Hinkey Haines.
# CSV file has been written successfully for Dick Hanley.
# CSV file has been written successfully for Ernie Hefferle.
# CSV file has been written successfully for Jack Hegarty.
# CSV file has been written successfully for Jack Heldt.
# CSV file has been written successfully for Max Hicks.
# CSV file has been written successfully for Herb Joesting.
# CSV file has been written successfully for Al Jolley.
# CSV file has been written successfully for Walt Koppisch.
# CSV file has been written successfully for Ollie Kraehe.
# CSV file has been written successfully for Lou Mahrt.
# CSV file has been written successfully for Jerod Mayo.
# CSV file has been written successfully for Pete McCulley.
# CSV file has been written successfully for Ed McKeever.
# CSV file has been written successfully for Ray McLean.
# CSV file has been written successfully for Jack Meagher.
# CSV file has been written successfully for Frank Nied.
# CSV file has been written successfully for Fred O'Connor.
# CSV file has been written successfully for Bill Peterson.
# CSV file has been written successfully for Jerry Rosburg.
# CSV file has been written successfully for Rod Rust.
# CSV file has been written successfully for Andy Salata.
# CSV file has been written successfully for Jeff Saturday.
# CSV file has been written successfully for Tom Scott.
# CSV file has been written successfully for Ken Shipp.
# CSV file has been written successfully for Jim Shofner.
# CSV file has been written successfully for Dick Stanfel.
# CSV file has been written successfully for Mal Stevens.
# CSV file has been written successfully for Eric Studesville.
# CSV file has been written successfully for Chris Tabor.
# CSV file has been written successfully for Emmitt Thomas.
# CSV file has been written successfully for Russell Tollefson.
# CSV file has been written successfully for Ron Waller.
# CSV file has been written successfully for Chile Walsh.
# CSV file has been written successfully for Hubert Wiggs.
# CSV file has been written successfully for Doc Young.
# CSV file has been written successfully for Fay Abbott.
# CSV file has been written successfully for Dim Batterson.
# CSV file has been written successfully for Joe Brandy.
# CSV file has been written successfully for Charlie Brickley.
# CSV file has been written successfully for Frank Bridges.
# CSV file has been written successfully for Coonie Checkaye.
# CSV file has been written successfully for Algy Clark.
# CSV file has been written successfully for Stan Cofall.
# CSV file has been written successfully for Frank Coughlin.
# CSV file has been written successfully for Jim Crowley.
# CSV file has been written successfully for Herb Dell.
# CSV file has been written successfully for John Fassel.
# CSV file has been written successfully for Tex Grigg.
# CSV file has been written successfully for Bo Hanley.
# CSV file has been written successfully for Dutch Hendrian.
# CSV file has been written successfully for Austin Higgins.
# CSV file has been written successfully for Ken Huffine.
# CSV file has been written successfully for Hal Hunter.
# CSV file has been written successfully for Bull Karcis.
# CSV file has been written successfully for Ed Kubale.
# CSV file has been written successfully for Hank Kuhlmann.
# CSV file has been written successfully for Leo Lyons.
# CSV file has been written successfully for Alfred McGall.
# CSV file has been written successfully for Wally McIlwain.
# CSV file has been written successfully for Dick Modzelewski.
# CSV file has been written successfully for Johnny Murphy.
# CSV file has been written successfully for Al Nesser.
# CSV file has been written successfully for Tam Rose.
# CSV file has been written successfully for Lenny Sachs.
# CSV file has been written successfully for Giff Smith.
# CSV file has been written successfully for Jeff Ulbrich.

# %%
### Clean headers and delete extra rows

# Define the directory path where your CSV files are stored
directory_path = 'data-coaches/coaching-results/'

# Loop through each CSV file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.csv'):
        file_path = os.path.join(directory_path, filename)
        
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file_path, skiprows=1)
        
        # Filter the DataFrame to only keep rows where 'Year' contains a 4-digit number
        df = df[df['Year'].astype(str).str.match('^\d{4}$')]
        
        # Save the cleaned DataFrame back to a new CSV file
        cleaned_file_path = os.path.join(directory_path, f'cleaned_{filename}')
        df.to_csv(cleaned_file_path, index=False)
### Combine all coach files

# Define the directory path where your CSV files are stored
directory_path = 'data-coaches/coaching-results/'

# %%
## Scrape head coach names URL's

import requests
from bs4 import BeautifulSoup, Comment
import pandas as pd
from tqdm import tqdm
import time
import random
import os

url = 'https://www.pro-football-reference.com/coaches/'  # Replace with your URL

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find the table containing the coaches
table = soup.find('table', {'id': 'coaches'})

# Initialize list to store coaches
coaches = []

# Loop through each row in the table
for row in table.find_all('tr'):
    # Initialize a dictionary to store coach data
    coach = {}

    # Extract the coach name and href link
    name_link = row.find('a')
    if name_link:
        coach['name'] = name_link.text
        coach['link'] = name_link['href']

    # Extract the number of super bowls
    super_bowls = row.find('td', {'data-stat': 'championships_super_bowl'})
    if super_bowls and super_bowls.text.strip():
        coach['super_bowls'] = int(super_bowls.text)

    # Extract the number of wins and losses
    wins = row.find('td', {'data-stat': 'wins'})
    if wins and wins.text.strip():
        coach['wins'] = int(wins.text)

    losses = row.find('td', {'data-stat': 'losses'})
    if losses and losses.text.strip():
        coach['losses'] = int(losses.text)

    # Add coach to list if data was found
    if coach:
        coaches.append(coach)
        
#print(f'There have been {coaches.count} head coaches in the NFL') 
print(f'There are {len(coaches)} coaches.')

for coach in coaches:
    print(coach)
        
# Create a DataFrame from the list of coaches
df = pd.DataFrame(coaches)

# Create new 'url' column
df['url'] = 'https://www.pro-football-reference.com' + df['link']

# Save the DataFrame to a CSV file
df.to_csv('./data/head_coaches.csv', index=False)
# Out:
# There are 529 coaches.
# {'name': 'Don Shula', 'link': '/coaches/ShulDo0.htm', 'super_bowls': 2, 'wins': 328, 'losses': 156}
# {'name': 'George Halas', 'link': '/coaches/HalaGe0.htm', 'super_bowls': 0, 'wins': 318, 'losses': 148}
# {'name': 'Bill Belichick', 'link': '/coaches/BeliBi0.htm', 'super_bowls': 6, 'wins': 302, 'losses': 165}
# {'name': 'Andy Reid', 'link': '/coaches/ReidAn0.htm', 'super_bowls': 3, 'wins': 264, 'losses': 144}
# {'name': 'Tom Landry', 'link': '/coaches/LandTo0.htm', 'super_bowls': 2, 'wins': 250, 'losses': 162}
# {'name': 'Curly Lambeau', 'link': '/coaches/LambCu0.htm', 'super_bowls': 0, 'wins': 226, 'losses': 132}
# {'name': 'Paul Brown', 'link': '/coaches/BrowPa0.htm', 'super_bowls': 0, 'wins': 213, 'losses': 104}
# {'name': 'Marty Schottenheimer', 'link': '/coaches/SchoMa0.htm', 'super_bowls': 0, 'wins': 200, 'losses': 126}
# {'name': 'Chuck Noll', 'link': '/coaches/NollCh0.htm', 'super_bowls': 4, 'wins': 193, 'losses': 148}
# {'name': 'Dan Reeves', 'link': '/coaches/ReevDa0.htm', 'super_bowls': 0, 'wins': 190, 'losses': 165}
# {'name': 'Chuck Knox', 'link': '/coaches/KnoxCh0.htm', 'super_bowls': 0, 'wins': 186, 'losses': 147}
# {'name': 'Mike Tomlin', 'link': '/coaches/TomlMi0.htm', 'super_bowls': 1, 'wins': 178, 'losses': 102}
# {'name': 'Jeff Fisher', 'link': '/coaches/FishJe0.htm', 'super_bowls': 0, 'wins': 173, 'losses': 165}
# {'name': 'Bill Parcells', 'link': '/coaches/ParcBi0.htm', 'super_bowls': 2, 'wins': 172, 'losses': 130}
# {'name': 'Pete Carroll', 'link': '/coaches/CarrPe0.htm', 'super_bowls': 1, 'wins': 170, 'losses': 120}
# {'name': 'Tom Coughlin', 'link': '/coaches/CougTo0.htm', 'super_bowls': 2, 'wins': 170, 'losses': 150}
# {'name': 'Mike McCarthy', 'link': '/coaches/McCaMi0.htm', 'super_bowls': 1, 'wins': 170, 'losses': 105}
# {'name': 'Mike Shanahan', 'link': '/coaches/ShanMi0.htm', 'super_bowls': 2, 'wins': 170, 'losses': 138}
# {'name': 'John Harbaugh', 'link': '/coaches/HarbJo0.htm', 'super_bowls': 1, 'wins': 165, 'losses': 101}
# {'name': 'Sean Payton', 'link': '/coaches/PaytSe0.htm', 'super_bowls': 1, 'wins': 164, 'losses': 101}
# {'name': 'Mike Holmgren', 'link': '/coaches/HolmMi0.htm', 'super_bowls': 1, 'wins': 161, 'losses': 111}
# {'name': 'Bud Grant', 'link': '/coaches/GranBu0.htm', 'super_bowls': 0, 'wins': 158, 'losses': 96}
# {'name': 'Joe Gibbs', 'link': '/coaches/GibbJo0.htm', 'super_bowls': 3, 'wins': 154, 'losses': 94}
# {'name': 'Steve Owen', 'link': '/coaches/OwenSt0.htm', 'super_bowls': 0, 'wins': 153, 'losses': 100}
# {'name': 'Bill Cowher', 'link': '/coaches/CowhBi0.htm', 'super_bowls': 1, 'wins': 149, 'losses': 90}
# {'name': 'Marv Levy', 'link': '/coaches/LevyMa0.htm', 'super_bowls': 0, 'wins': 143, 'losses': 112}
# {'name': 'Tony Dungy', 'link': '/coaches/DungTo0.htm', 'super_bowls': 1, 'wins': 139, 'losses': 69}
# {'name': 'John Fox', 'link': '/coaches/FoxxJo0.htm', 'super_bowls': 0, 'wins': 133, 'losses': 123}
# {'name': 'Marvin Lewis', 'link': '/coaches/LewiMa0.htm', 'super_bowls': 0, 'wins': 131, 'losses': 122}
# {'name': 'Hank Stram', 'link': '/coaches/StraHa0.htm', 'super_bowls': 1, 'wins': 131, 'losses': 97}
# {'name': 'Weeb Ewbank', 'link': '/coaches/EwbaWe0.htm', 'super_bowls': 1, 'wins': 130, 'losses': 129}
# {'name': 'Jim Mora', 'link': '/coaches/MoraJi0.htm', 'super_bowls': 0, 'wins': 125, 'losses': 106}
# {'name': 'Sid Gillman', 'link': '/coaches/GillSi0.htm', 'super_bowls': 0, 'wins': 122, 'losses': 99}
# {'name': 'Mike Ditka', 'link': '/coaches/DitkMi0.htm', 'super_bowls': 1, 'wins': 121, 'losses': 95}
# {'name': 'Dick Vermeil', 'link': '/coaches/VermDi0.htm', 'super_bowls': 1, 'wins': 120, 'losses': 109}
# {'name': 'Jon Gruden', 'link': '/coaches/GrudJo0.htm', 'super_bowls': 1, 'wins': 117, 'losses': 112}
# {'name': 'George Allen', 'link': '/coaches/AlleGe0.htm', 'super_bowls': 0, 'wins': 116, 'losses': 47}
# {'name': 'George Seifert', 'link': '/coaches/SeifGe0.htm', 'super_bowls': 2, 'wins': 114, 'losses': 62}
# {'name': 'Norv Turner', 'link': '/coaches/TurnNo0.htm', 'super_bowls': 0, 'wins': 114, 'losses': 122}
# {'name': 'Dennis Green', 'link': '/coaches/GreeDe0.htm', 'super_bowls': 0, 'wins': 113, 'losses': 94}
# {'name': 'Don Coryell', 'link': '/coaches/CoryDo0.htm', 'super_bowls': 0, 'wins': 111, 'losses': 83}
# {'name': 'Buddy Parker', 'link': '/coaches/ParkRa0.htm', 'super_bowls': 0, 'wins': 104, 'losses': 75}
# {'name': 'John Madden', 'link': '/coaches/MaddJo0.htm', 'super_bowls': 1, 'wins': 103, 'losses': 32}
# {'name': 'Ron Rivera', 'link': '/coaches/RiveRo0.htm', 'super_bowls': 0, 'wins': 102, 'losses': 103}
# {'name': 'Tom Flores', 'link': '/coaches/FlorTo0.htm', 'super_bowls': 2, 'wins': 97, 'losses': 87}
# {'name': 'Vince Lombardi', 'link': '/coaches/LombVi0.htm', 'super_bowls': 2, 'wins': 96, 'losses': 34}
# {'name': 'Lou Saban', 'link': '/coaches/SabaLo0.htm', 'super_bowls': 0, 'wins': 95, 'losses': 99}
# {'name': 'Jack Del Rio', 'link': '/coaches/DelRJa0.htm', 'super_bowls': 0, 'wins': 93, 'losses': 94}
# {'name': 'Lovie Smith', 'link': '/coaches/SmitLo0.htm', 'super_bowls': 0, 'wins': 92, 'losses': 100}
# {'name': 'Bill Walsh', 'link': '/coaches/WalsBi0.htm', 'super_bowls': 3, 'wins': 92, 'losses': 59}
# {'name': 'Buck Shaw', 'link': '/coaches/ShawLa0.htm', 'super_bowls': 0, 'wins': 90, 'losses': 55}
# {'name': 'Jimmy Conzelman', 'link': '/coaches/ConzJi0.htm', 'super_bowls': 0, 'wins': 87, 'losses': 63}
# {'name': 'Ted Marchibroda', 'link': '/coaches/MarcTe0.htm', 'super_bowls': 0, 'wins': 87, 'losses': 98}
# {'name': 'Jack Pardee', 'link': '/coaches/PardJa0.htm', 'super_bowls': 0, 'wins': 87, 'losses': 77}
# {'name': 'Jason Garrett', 'link': '/coaches/GarrJa0.htm', 'super_bowls': 0, 'wins': 85, 'losses': 67}
# {'name': 'Sam Wyche', 'link': '/coaches/WychSa0.htm', 'super_bowls': 0, 'wins': 84, 'losses': 107}
# {'name': 'Gary Kubiak', 'link': '/coaches/KubiGa0.htm', 'super_bowls': 1, 'wins': 82, 'losses': 75}
# {'name': 'Bum Phillips', 'link': '/coaches/PhilBu0.htm', 'super_bowls': 0, 'wins': 82, 'losses': 77}
# {'name': 'Wade Phillips', 'link': '/coaches/PhilWa0.htm', 'super_bowls': 0, 'wins': 82, 'losses': 64}
# {'name': 'Dave Wannstedt', 'link': '/coaches/WannDa0.htm', 'super_bowls': 0, 'wins': 82, 'losses': 87}
# {'name': 'Bruce Arians', 'link': '/coaches/AriaBr0.htm', 'super_bowls': 1, 'wins': 80, 'losses': 48}
# {'name': 'Brian Billick', 'link': '/coaches/BillBr0.htm', 'super_bowls': 1, 'wins': 80, 'losses': 64}
# {'name': 'Ray Flaherty', 'link': '/coaches/FlahRa0.htm', 'super_bowls': 0, 'wins': 80, 'losses': 37}
# {'name': 'Jimmy Johnson', 'link': '/coaches/JohnJi0.htm', 'super_bowls': 2, 'wins': 80, 'losses': 64}
# {'name': 'Sean McDermott', 'link': '/coaches/McDeSe0.htm', 'super_bowls': 0, 'wins': 78, 'losses': 43}
# {'name': 'Blanton Collier', 'link': '/coaches/CollBl0.htm', 'super_bowls': 0, 'wins': 76, 'losses': 34}
# {'name': 'Forrest Gregg', 'link': '/coaches/GregFo0.htm', 'super_bowls': 0, 'wins': 75, 'losses': 85}
# {'name': 'John Robinson', 'link': '/coaches/RobiJo0.htm', 'wins': 75, 'losses': 68}
# {'name': 'Bobby Ross', 'link': '/coaches/RossBo0.htm', 'super_bowls': 0, 'wins': 74, 'losses': 63}
# {'name': 'Steve Mariucci', 'link': '/coaches/MariSt0.htm', 'super_bowls': 0, 'wins': 72, 'losses': 67}
# {'name': 'Sean McVay', 'link': '/coaches/McVaSe0.htm', 'super_bowls': 1, 'wins': 72, 'losses': 49}
# {'name': 'Mike Zimmer', 'link': '/coaches/ZimmMi0.htm', 'super_bowls': 0, 'wins': 72, 'losses': 56}
# {'name': 'Dick Nolan', 'link': '/coaches/NolaDi0.htm', 'super_bowls': 0, 'wins': 69, 'losses': 82}
# {'name': 'George Wilson', 'link': '/coaches/WilsGe0.htm', 'super_bowls': 0, 'wins': 68, 'losses': 84}
# {'name': 'Kyle Shanahan', 'link': '/coaches/ShanKy0.htm', 'super_bowls': 0, 'wins': 67, 'losses': 55}
# {'name': 'Wayne Fontes', 'link': '/coaches/FontWa0.htm', 'super_bowls': 0, 'wins': 66, 'losses': 67}
# {'name': 'Mike Smith', 'link': '/coaches/SmitMi0.htm', 'super_bowls': 0, 'wins': 66, 'losses': 46}
# {'name': 'Norm Van Brocklin', 'link': '/coaches/VanBNo0.htm', 'super_bowls': 0, 'wins': 66, 'losses': 100}
# {'name': 'Potsy Clark', 'link': '/coaches/ClarPo0.htm', 'super_bowls': 0, 'wins': 64, 'losses': 42}
# {'name': 'Wally Lemm', 'link': '/coaches/LemmWa0.htm', 'super_bowls': 0, 'wins': 64, 'losses': 64}
# {'name': 'Greasy Neale', 'link': '/coaches/NealGr0.htm', 'super_bowls': 0, 'wins': 63, 'losses': 43}
# {'name': 'Jim Caldwell', 'link': '/coaches/CaldJi0.htm', 'super_bowls': 0, 'wins': 62, 'losses': 50}
# {'name': 'Doug Pederson', 'link': '/coaches/PedeDo0.htm', 'super_bowls': 1, 'wins': 62, 'losses': 58}
# {'name': 'Matt LaFleur', 'link': '/coaches/LaFlMa0.htm', 'super_bowls': 0, 'wins': 61, 'losses': 29}
# {'name': 'Rex Ryan', 'link': '/coaches/RyanRe0.htm', 'super_bowls': 0, 'wins': 61, 'losses': 66}
# {'name': 'Jerry Glanville', 'link': '/coaches/GlanJe0.htm', 'super_bowls': 0, 'wins': 60, 'losses': 69}
# {'name': 'Dick Jauron', 'link': '/coaches/JaurDi0.htm', 'super_bowls': 0, 'wins': 60, 'losses': 82}
# {'name': 'Guy Chamberlin', 'link': '/coaches/ChamGu0.htm', 'super_bowls': 0, 'wins': 58, 'losses': 16}
# {'name': 'Jim Fassel', 'link': '/coaches/FassJi0.htm', 'super_bowls': 0, 'wins': 58, 'losses': 53}
# {'name': 'Joe Kuharich', 'link': '/coaches/KuhaJo0.htm', 'super_bowls': 0, 'wins': 58, 'losses': 81}
# {'name': 'Allie Sherman', 'link': '/coaches/SherAl0.htm', 'wins': 57, 'losses': 51}
# {'name': 'Mike Sherman', 'link': '/coaches/SherMi0.htm', 'wins': 57, 'losses': 39}
# {'name': 'Art Shell', 'link': '/coaches/ShelAr0.htm', 'wins': 56, 'losses': 52}
# {'name': 'Buddy Ryan', 'link': '/coaches/RyanBu0.htm', 'super_bowls': 0, 'wins': 55, 'losses': 55}
# {'name': 'Herm Edwards', 'link': '/coaches/EdwaHe0.htm', 'super_bowls': 0, 'wins': 54, 'losses': 74}
# {'name': 'Ron Meyer', 'link': '/coaches/MeyeRo0.htm', 'super_bowls': 0, 'wins': 54, 'losses': 50}
# {'name': 'Mike Vrabel', 'link': '/coaches/VrabMi0.htm', 'super_bowls': 0, 'wins': 54, 'losses': 45}
# {'name': 'Jim Lee Howell', 'link': '/coaches/HoweJi0.htm', 'wins': 53, 'losses': 27}
# {'name': 'Mike Martz', 'link': '/coaches/MartMi0.htm', 'wins': 53, 'losses': 32}
# {'name': 'Chuck Pagano', 'link': '/coaches/PagaCh0.htm', 'super_bowls': 0, 'wins': 53, 'losses': 43}
# {'name': 'Joe Walton', 'link': '/coaches/WaltJo0.htm', 'super_bowls': 0, 'wins': 53, 'losses': 57}
# {'name': 'Jerry Burns', 'link': '/coaches/BurnJe0.htm', 'wins': 52, 'losses': 43}
# {'name': 'Mike Holovak', 'link': '/coaches/HoloMi0.htm', 'super_bowls': 0, 'wins': 52, 'losses': 47}
# {'name': "Bill O'Brien", 'link': '/coaches/OBriBi0.htm', 'super_bowls': 0, 'wins': 52, 'losses': 48}
# {'name': 'Bart Starr', 'link': '/coaches/StarBa0.htm', 'super_bowls': 0, 'wins': 52, 'losses': 76}
# {'name': 'Roy Andrews', 'link': '/coaches/AndrRo0.htm', 'super_bowls': 0, 'wins': 51, 'losses': 27}
# {'name': 'Monte Clark', 'link': '/coaches/ClarMo0.htm', 'super_bowls': 0, 'wins': 51, 'losses': 67}
# {'name': 'Leeman Bennett', 'link': '/coaches/BennLe0.htm', 'super_bowls': 0, 'wins': 50, 'losses': 69}
# {'name': 'Raymond Berry', 'link': '/coaches/BerrRa0.htm', 'super_bowls': 0, 'wins': 48, 'losses': 39}
# {'name': 'Dom Capers', 'link': '/coaches/CapeDo0.htm', 'super_bowls': 0, 'wins': 48, 'losses': 80}
# {'name': 'Dan Quinn', 'link': '/coaches/QuinDa0.htm', 'super_bowls': 0, 'wins': 48, 'losses': 44}
# {'name': 'Ken Whisenhunt', 'link': '/coaches/WhisKe0.htm', 'super_bowls': 0, 'wins': 48, 'losses': 71}
# {'name': 'Todd Bowles', 'link': '/coaches/BowlTo0.htm', 'super_bowls': 0, 'wins': 47, 'losses': 61}
# {'name': 'Bruce Coslet', 'link': '/coaches/CoslBr0.htm', 'super_bowls': 0, 'wins': 47, 'losses': 77}
# {'name': 'Jim Harbaugh', 'link': '/coaches/HarbJi0.htm', 'wins': 47, 'losses': 22}
# {'name': 'Jim Haslett', 'link': '/coaches/HaslJi0.htm', 'super_bowls': 0, 'wins': 47, 'losses': 61}
# {'name': 'Sam Rutigliano', 'link': '/coaches/RutiSa0.htm', 'wins': 47, 'losses': 50}
# {'name': 'Chuck Fairbanks', 'link': '/coaches/FairCh0.htm', 'super_bowls': 0, 'wins': 46, 'losses': 39}
# {'name': 'Nick Skorich', 'link': '/coaches/SkorNi0.htm', 'super_bowls': 0, 'wins': 45, 'losses': 48}
# {'name': 'Ray Malavasi', 'link': '/coaches/MalaRa0.htm', 'super_bowls': 0, 'wins': 44, 'losses': 41}
# {'name': 'John McKay', 'link': '/coaches/McKaJo0.htm', 'super_bowls': 0, 'wins': 44, 'losses': 88}
# {'name': 'Charley Winner', 'link': '/coaches/WinnCh0.htm', 'super_bowls': 0, 'wins': 44, 'losses': 44}
# {'name': 'Joe Schmidt', 'link': '/coaches/SchmJo0.htm', 'super_bowls': 0, 'wins': 43, 'losses': 34}
# {'name': 'Ray Perkins', 'link': '/coaches/PerkRa0.htm', 'super_bowls': 0, 'wins': 42, 'losses': 75}
# {'name': 'Frank Reich', 'link': '/coaches/ReicFr0.htm', 'super_bowls': 0, 'wins': 41, 'losses': 43}
# {'name': 'Dennis Erickson', 'link': '/coaches/EricDe0.htm', 'super_bowls': 0, 'wins': 40, 'losses': 56}
# {'name': 'Rich Kotite', 'link': '/coaches/KotiRi0.htm', 'super_bowls': 0, 'wins': 40, 'losses': 56}
# {'name': 'Red Miller', 'link': '/coaches/MillRe0.htm', 'super_bowls': 0, 'wins': 40, 'losses': 22}
# {'name': 'John Rauch', 'link': '/coaches/RaucJo0.htm', 'super_bowls': 0, 'wins': 40, 'losses': 28}
# {'name': 'Barry Switzer', 'link': '/coaches/SwitBa0.htm', 'super_bowls': 1, 'wins': 40, 'losses': 24}
# {'name': 'Zac Taylor', 'link': '/coaches/TaylZa0.htm', 'super_bowls': 0, 'wins': 40, 'losses': 48}
# {'name': 'Brad Childress', 'link': '/coaches/ChilBr0.htm', 'wins': 39, 'losses': 35}
# {'name': 'Jim Hanifan', 'link': '/coaches/HaniJi0.htm', 'super_bowls': 0, 'wins': 39, 'losses': 53}
# {'name': 'Walt Michaels', 'link': '/coaches/MichWa0.htm', 'super_bowls': 0, 'wins': 39, 'losses': 47}
# {'name': 'Dan Henning', 'link': '/coaches/HennDa0.htm', 'super_bowls': 0, 'wins': 38, 'losses': 73}
# {'name': 'Doug Marrone', 'link': '/coaches/MarrDo0.htm', 'super_bowls': 0, 'wins': 38, 'losses': 60}
# {'name': 'Nick Sirianni', 'link': '/coaches/SiriNi0.htm', 'wins': 38, 'losses': 19}
# {'name': 'Kevin Stefanski', 'link': '/coaches/StefKe0.htm', 'super_bowls': 0, 'wins': 38, 'losses': 36}
# {'name': 'Ray Rhodes', 'link': '/coaches/RhodRa0.htm', 'super_bowls': 0, 'wins': 37, 'losses': 42}
# {'name': 'Lindy Infante', 'link': '/coaches/InfaLi0.htm', 'super_bowls': 0, 'wins': 36, 'losses': 60}
# {'name': 'Mike Mularkey', 'link': '/coaches/MulaMi0.htm', 'super_bowls': 0, 'wins': 36, 'losses': 53}
# {'name': 'Jay Gruden', 'link': '/coaches/GrudJa0.htm', 'super_bowls': 0, 'wins': 35, 'losses': 49}
# {'name': 'Jack Patera', 'link': '/coaches/PateJa0.htm', 'super_bowls': 0, 'wins': 35, 'losses': 59}
# {'name': 'Tommy Prothro', 'link': '/coaches/ProtTo0.htm', 'super_bowls': 0, 'wins': 35, 'losses': 51}
# {'name': 'Dan Campbell', 'link': '/coaches/CampDa1.htm', 'wins': 34, 'losses': 34}
# {'name': 'Marion Campbell', 'link': '/coaches/CampMa0.htm', 'super_bowls': 0, 'wins': 34, 'losses': 80}
# {'name': 'Chan Gailey', 'link': '/coaches/GailCh0.htm', 'super_bowls': 0, 'wins': 34, 'losses': 46}
# {'name': 'Tommy Hughitt', 'link': '/coaches/HughTo0.htm', 'super_bowls': 0, 'wins': 34, 'losses': 15}
# {'name': 'Matt Nagy', 'link': '/coaches/NagyMa0.htm', 'super_bowls': 0, 'wins': 34, 'losses': 31}
# {'name': 'John Ralston', 'link': '/coaches/RalsJo0.htm', 'super_bowls': 0, 'wins': 34, 'losses': 33}
# {'name': 'Anthony Lynn', 'link': '/coaches/LynnAn0.htm', 'super_bowls': 0, 'wins': 33, 'losses': 32}
# {'name': 'Eric Mangini', 'link': '/coaches/MangEr0.htm', 'super_bowls': 0, 'wins': 33, 'losses': 47}
# {'name': 'Dick Rauch', 'link': '/coaches/RaucDi0.htm', 'super_bowls': 0, 'wins': 33, 'losses': 24}
# {'name': 'Romeo Crennel', 'link': '/coaches/CrenRo0.htm', 'super_bowls': 0, 'wins': 32, 'losses': 63}
# {'name': 'Adam Gase', 'link': '/coaches/GaseAd0.htm', 'super_bowls': 0, 'wins': 32, 'losses': 48}
# {'name': 'Pop Ivy', 'link': '/coaches/IvyxPo0.htm', 'super_bowls': 0, 'wins': 32, 'losses': 42}
# {'name': 'Tony Sparano', 'link': '/coaches/SparTo0.htm', 'super_bowls': 0, 'wins': 32, 'losses': 41}
# {'name': 'Mike Tice', 'link': '/coaches/TiceMi0.htm', 'wins': 32, 'losses': 33}
# {'name': 'Paddy Driscoll', 'link': '/coaches/DrisPa0.htm', 'super_bowls': 0, 'wins': 31, 'losses': 17}
# {'name': 'Jim Mora', 'link': '/coaches/MoraJi1.htm', 'super_bowls': 0, 'wins': 31, 'losses': 33}
# {'name': 'Neill Armstrong', 'link': '/coaches/ArmsNe0.htm', 'super_bowls': 0, 'wins': 30, 'losses': 34}
# {'name': 'Dutch Clark', 'link': '/coaches/ClarDu0.htm', 'super_bowls': 0, 'wins': 30, 'losses': 34}
# {'name': 'Walt Kiesling', 'link': '/coaches/KiesWa0.htm', 'super_bowls': 0, 'wins': 30, 'losses': 55}
# {'name': 'John Mackovic', 'link': '/coaches/MackJo0.htm', 'super_bowls': 0, 'wins': 30, 'losses': 34}
# {'name': 'Mike McCormack', 'link': '/coaches/McCoMi0.htm', 'super_bowls': 0, 'wins': 29, 'losses': 51}
# {'name': 'Jim Schwartz', 'link': '/coaches/SchwJi0.htm', 'super_bowls': 0, 'wins': 29, 'losses': 51}
# {'name': 'Alex Webster', 'link': '/coaches/WebsAl0.htm', 'wins': 29, 'losses': 40}
# {'name': 'Chip Kelly', 'link': '/coaches/KellCh0.htm', 'super_bowls': 0, 'wins': 28, 'losses': 35}
# {'name': 'Kliff Kingsbury', 'link': '/coaches/KingKl0.htm', 'super_bowls': 0, 'wins': 28, 'losses': 37}
# {'name': 'Don McCafferty', 'link': '/coaches/McCaDo0.htm', 'super_bowls': 1, 'wins': 28, 'losses': 17}
# {'name': 'Jock Sutherland', 'link': '/coaches/SuthJo0.htm', 'super_bowls': 0, 'wins': 28, 'losses': 16}
# {'name': 'Vince Tobin', 'link': '/coaches/TobiVi0.htm', 'super_bowls': 0, 'wins': 28, 'losses': 43}
# {'name': 'Red Hickey', 'link': '/coaches/HickHo0.htm', 'super_bowls': 0, 'wins': 27, 'losses': 27}
# {'name': 'Mike McCoy', 'link': '/coaches/McCoMi1.htm', 'super_bowls': 0, 'wins': 27, 'losses': 37}
# {'name': 'Dennis Allen', 'link': '/coaches/AlleDe0.htm', 'wins': 26, 'losses': 51}
# {'name': 'Jack Christiansen', 'link': '/coaches/ChriJa0.htm', 'super_bowls': 0, 'wins': 26, 'losses': 38}
# {'name': 'Dudley DeGroot', 'link': '/coaches/DeGrDu0.htm', 'super_bowls': 0, 'wins': 26, 'losses': 16}
# {'name': 'Joe Philbin', 'link': '/coaches/PhilJo0.htm', 'super_bowls': 0, 'wins': 26, 'losses': 30}
# {'name': 'Hampton Pool', 'link': '/coaches/PoolHa0.htm', 'super_bowls': 0, 'wins': 26, 'losses': 19}
# {'name': 'Dan Devine', 'link': '/coaches/DeviDa0.htm', 'super_bowls': 0, 'wins': 25, 'losses': 27}
# {'name': 'Raheem Morris', 'link': '/coaches/MorrRa0.htm', 'super_bowls': 0, 'wins': 25, 'losses': 41}
# {'name': "Kevin O'Connell", 'link': '/coaches/OConKe0.htm', 'wins': 25, 'losses': 15}
# {'name': 'Jim Trimble', 'link': '/coaches/TrimJi0.htm', 'super_bowls': 0, 'wins': 25, 'losses': 20}
# {'name': 'Joe Bugel', 'link': '/coaches/BugeJo0.htm', 'super_bowls': 0, 'wins': 24, 'losses': 56}
# {'name': 'Butch Davis', 'link': '/coaches/DaviBu0.htm', 'wins': 24, 'losses': 35}
# {'name': 'Brian Flores', 'link': '/coaches/FlorBr0.htm', 'super_bowls': 0, 'wins': 24, 'losses': 25}
# {'name': 'Ralph Jones', 'link': '/coaches/JoneRa0.htm', 'super_bowls': 0, 'wins': 24, 'losses': 10}
# {'name': 'Brandon Staley', 'link': '/coaches/StalBr0.htm', 'wins': 24, 'losses': 24}
# {'name': 'Red Strader', 'link': '/coaches/StraNo0.htm', 'super_bowls': 0, 'wins': 24, 'losses': 22}
# {'name': 'Hunk Anderson', 'link': '/coaches/AndeHu0.htm', 'super_bowls': 0, 'wins': 23, 'losses': 11}
# {'name': 'Al Davis', 'link': '/coaches/DaviAl0.htm', 'super_bowls': 0, 'wins': 23, 'losses': 16}
# {'name': 'Luke Johnsos', 'link': '/coaches/JohnLu0.htm', 'super_bowls': 0, 'wins': 23, 'losses': 11}
# {'name': 'Gene Stallings', 'link': '/coaches/StalGe0.htm', 'super_bowls': 0, 'wins': 23, 'losses': 34}
# {'name': 'June Jones', 'link': '/coaches/JoneJu0.htm', 'super_bowls': 0, 'wins': 22, 'losses': 36}
# {'name': 'Mike McDaniel', 'link': '/coaches/McDaMi0.htm', 'wins': 22, 'losses': 18}
# {'name': 'Mike Munchak', 'link': '/coaches/MuncMi0.htm', 'wins': 22, 'losses': 26}
# {'name': 'Gregg Williams', 'link': '/coaches/WillGr0.htm', 'super_bowls': 0, 'wins': 22, 'losses': 34}
# {'name': 'Joe Bach', 'link': '/coaches/BachJo0.htm', 'super_bowls': 0, 'wins': 21, 'losses': 27}
# {'name': 'Phil Bengtson', 'link': '/coaches/BengPh0.htm', 'super_bowls': 0, 'wins': 21, 'losses': 25}
# {'name': 'Ron Erhardt', 'link': '/coaches/ErhaRo0.htm', 'super_bowls': 0, 'wins': 21, 'losses': 28}
# {'name': 'Leslie Frazier', 'link': '/coaches/FrazLe0.htm', 'wins': 21, 'losses': 32}
# {'name': 'Bill McPeak', 'link': '/coaches/McPeBi0.htm', 'super_bowls': 0, 'wins': 21, 'losses': 46}
# {'name': 'Arthur Smith', 'link': '/coaches/SmitAr0.htm', 'wins': 21, 'losses': 30}
# {'name': 'Harland Svare', 'link': '/coaches/SvarHa0.htm', 'super_bowls': 0, 'wins': 21, 'losses': 48}
# {'name': 'Jim Dooley', 'link': '/coaches/DoolJi0.htm', 'super_bowls': 0, 'wins': 20, 'losses': 36}
# {'name': 'Gus Dorais', 'link': '/coaches/DoraGu0.htm', 'super_bowls': 0, 'wins': 20, 'losses': 31}
# {'name': 'Josh McDaniels', 'link': '/coaches/McDaJo0.htm', 'super_bowls': 0, 'wins': 20, 'losses': 33}
# {'name': 'John Michelosen', 'link': '/coaches/MichJo0.htm', 'super_bowls': 0, 'wins': 20, 'losses': 26}
# {'name': 'Robert Saleh', 'link': '/coaches/SaleRo0.htm', 'wins': 20, 'losses': 36}
# {'name': 'Joe Stydahar', 'link': '/coaches/StydJo0.htm', 'super_bowls': 0, 'wins': 20, 'losses': 28}
# {'name': 'Frankie Albert', 'link': '/coaches/AlbeFr0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 16}
# {'name': 'Red Dawson', 'link': '/coaches/DawsRe0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 25}
# {'name': 'Vic Fangio', 'link': '/coaches/FangVi0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 30}
# {'name': 'Todd Haley', 'link': '/coaches/HaleTo0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 26}
# {'name': 'Dirk Koetter', 'link': '/coaches/KoetDi0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 29}
# {'name': 'David Shula', 'link': '/coaches/ShulDa0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 52}
# {'name': 'Pat Shurmur', 'link': '/coaches/ShurPa0.htm', 'super_bowls': 0, 'wins': 19, 'losses': 46}
# {'name': 'Sammy Baugh', 'link': '/coaches/BaugSa0.htm', 'super_bowls': 0, 'wins': 18, 'losses': 24}
# {'name': 'Bill Callahan', 'link': '/coaches/CallBi0.htm', 'super_bowls': 0, 'wins': 18, 'losses': 25}
# {'name': 'Bill Johnson', 'link': '/coaches/JohnBi0.htm', 'super_bowls': 0, 'wins': 18, 'losses': 15}
# {'name': 'Mike Nolan', 'link': '/coaches/NolaMi0.htm', 'wins': 18, 'losses': 37}
# {'name': 'Darryl Rogers', 'link': '/coaches/RogeDa0.htm', 'super_bowls': 0, 'wins': 18, 'losses': 40}
# {'name': 'Mike Singletary', 'link': '/coaches/SingMi0.htm', 'super_bowls': 0, 'wins': 18, 'losses': 22}
# {'name': 'Bill Austin', 'link': '/coaches/AustBi0.htm', 'super_bowls': 0, 'wins': 17, 'losses': 36}
# {'name': 'Lisle Blackbourn', 'link': '/coaches/BlacLi0.htm', 'super_bowls': 0, 'wins': 17, 'losses': 31}
# {'name': 'Tom Cable', 'link': '/coaches/CablTo0.htm', 'wins': 17, 'losses': 27}
# {'name': 'Brian Daboll', 'link': '/coaches/DaboBr0.htm', 'wins': 17, 'losses': 23}
# {'name': 'Otto Graham', 'link': '/coaches/GrahOt0.htm', 'super_bowls': 0, 'wins': 17, 'losses': 22}
# {'name': 'Dave McGinnis', 'link': '/coaches/McGiDa0.htm', 'super_bowls': 0, 'wins': 17, 'losses': 40}
# {'name': 'Al Saunders', 'link': '/coaches/SaunAl0.htm', 'super_bowls': 0, 'wins': 17, 'losses': 22}
# {'name': 'Dewey Scanlon', 'link': '/coaches/ScanDe0.htm', 'super_bowls': 0, 'wins': 17, 'losses': 15}
# {'name': 'Norm Barry', 'link': '/coaches/BarrNo0.htm', 'super_bowls': 0, 'wins': 16, 'losses': 8}
# {'name': 'Milan Creighton', 'link': '/coaches/CreiMi0.htm', 'super_bowls': 0, 'wins': 16, 'losses': 26}
# {'name': 'Gunther Cunningham', 'link': '/coaches/CunnGu0.htm', 'super_bowls': 0, 'wins': 16, 'losses': 16}
# {'name': 'Turk Edwards', 'link': '/coaches/EdwaTu0.htm', 'super_bowls': 0, 'wins': 16, 'losses': 18}
# {'name': 'Elgie Tobin', 'link': '/coaches/TobiEl0.htm', 'super_bowls': 0, 'wins': 16, 'losses': 3}
# {'name': 'Dave Campo', 'link': '/coaches/CampDa0.htm', 'super_bowls': 0, 'wins': 15, 'losses': 33}
# {'name': 'Rick Forzano', 'link': '/coaches/ForzRi0.htm', 'super_bowls': 0, 'wins': 15, 'losses': 17}
# {'name': 'Earl Potteiger', 'link': '/coaches/PottEa0.htm', 'super_bowls': 0, 'wins': 15, 'losses': 12}
# {'name': 'DeMeco Ryans', 'link': '/coaches/RyanDe0.htm', 'wins': 15, 'losses': 9}
# {'name': 'Nick Saban', 'link': '/coaches/SabaNi0.htm', 'super_bowls': 0, 'wins': 15, 'losses': 17}
# {'name': 'Adam Walsh', 'link': '/coaches/WalsAd0.htm', 'super_bowls': 0, 'wins': 15, 'losses': 5}
# {'name': 'Ed Weir', 'link': '/coaches/WeirEd0.htm', 'super_bowls': 0, 'wins': 15, 'losses': 7}
# {'name': 'Mike White', 'link': '/coaches/WhitMi0.htm', 'wins': 15, 'losses': 17}
# {'name': 'Punk Berryman', 'link': '/coaches/BerrPu0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 10}
# {'name': 'Gus Bradley', 'link': '/coaches/BradGu0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 48}
# {'name': 'Matt Eberflus', 'link': '/coaches/EberMa0.htm', 'wins': 14, 'losses': 26}
# {'name': 'Ray Handley', 'link': '/coaches/HandRa0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 18}
# {'name': 'Bo McMillin', 'link': '/coaches/McMiAl0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 24}
# {'name': 'John McVay', 'link': '/coaches/McVaJo0.htm', 'wins': 14, 'losses': 23}
# {'name': 'Ray Richards', 'link': '/coaches/RichRa0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 21}
# {'name': 'Mike Riley', 'link': '/coaches/RileMi0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 34}
# {'name': 'Gene Ronzani', 'link': '/coaches/RonzGe0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 31}
# {'name': 'Babe Ruetz', 'link': '/coaches/RuetBa0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 11}
# {'name': 'Paul Schissler', 'link': '/coaches/SchiPa0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 29}
# {'name': 'Clark Shaughnessy', 'link': '/coaches/ShauCl0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 7}
# {'name': 'Jim Thorpe', 'link': '/coaches/ThorJi0.htm', 'super_bowls': 0, 'wins': 14, 'losses': 25}
# {'name': 'Bull Behman', 'link': '/coaches/BehmBu0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 20}
# {'name': 'Rich Brooks', 'link': '/coaches/BrooRi0.htm', 'wins': 13, 'losses': 19}
# {'name': 'Joe Collier', 'link': '/coaches/CollJo0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 16}
# {'name': 'Cap Edwards', 'link': '/coaches/EdwaCa0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 11}
# {'name': 'Tom Fears', 'link': '/coaches/FearTo0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 34}
# {'name': 'Arnie Horween', 'link': '/coaches/HorwAr0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 8}
# {'name': 'Ben McAdoo', 'link': '/coaches/McAdBe0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 15}
# {'name': 'Matt Patricia', 'link': '/coaches/PatrMa0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 29}
# {'name': 'Jimmy Phelan', 'link': '/coaches/PhelJi0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 35}
# {'name': 'Shane Steichen', 'link': '/coaches/SteiSh0.htm', 'wins': 13, 'losses': 11}
# {'name': 'Marc Trestman', 'link': '/coaches/TresMa0.htm', 'wins': 13, 'losses': 19}
# {'name': 'Lud Wray', 'link': '/coaches/WrayLu0.htm', 'super_bowls': 0, 'wins': 13, 'losses': 25}
# {'name': 'Jack Depler', 'link': '/coaches/DeplJa0.htm', 'super_bowls': 0, 'wins': 12, 'losses': 21}
# {'name': 'Dick LeBeau', 'link': '/coaches/LeBeDi0.htm', 'super_bowls': 0, 'wins': 12, 'losses': 33}
# {'name': 'Ernie Nevers', 'link': '/coaches/NeveEr0.htm', 'super_bowls': 0, 'wins': 12, 'losses': 27}
# {'name': 'Steve Spurrier', 'link': '/coaches/SpurSt0.htm', 'super_bowls': 0, 'wins': 12, 'losses': 20}
# {'name': 'Rube Ursella', 'link': '/coaches/UrseRu0.htm', 'super_bowls': 0, 'wins': 12, 'losses': 8}
# {'name': 'Jim Zorn', 'link': '/coaches/ZornJi0.htm', 'super_bowls': 0, 'wins': 12, 'losses': 20}
# {'name': 'Bud Carson', 'link': '/coaches/CarsBu0.htm', 'wins': 11, 'losses': 13}
# {'name': 'Lone Star Dietz', 'link': '/coaches/DietLo0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 11}
# {'name': 'Abe Gibron', 'link': '/coaches/GibrAb0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 30}
# {'name': 'Tommy Hudspeth', 'link': '/coaches/HudsTo0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 13}
# {'name': 'Hue Jackson', 'link': '/coaches/JackHu0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 44}
# {'name': 'Vance Joseph', 'link': '/coaches/JoseVa0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 21}
# {'name': 'Frank Kush', 'link': '/coaches/KushFr0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 28}
# {'name': 'Scott Linehan', 'link': '/coaches/LineSc0.htm', 'wins': 11, 'losses': 25}
# {'name': 'John North', 'link': '/coaches/NortJo0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 23}
# {'name': 'Buster Ramsey', 'link': '/coaches/RamsGa0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 16}
# {'name': 'Matt Rhule', 'link': '/coaches/RhulMa0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 27}
# {'name': 'Lou Rymkus', 'link': '/coaches/RymkLo0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 7}
# {'name': 'Greg Schiano', 'link': '/coaches/SchiGr0.htm', 'wins': 11, 'losses': 21}
# {'name': 'Steve Spagnuolo', 'link': '/coaches/SpagSt0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 41}
# {'name': 'Paul Wiggin', 'link': '/coaches/WiggPa0.htm', 'super_bowls': 0, 'wins': 11, 'losses': 24}
# {'name': 'Bert Bell', 'link': '/coaches/BellBe0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 46}
# {'name': 'Guil Falcon', 'link': '/coaches/FalcGu0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 10}
# {'name': 'Harry Gilmer', 'link': '/coaches/GilmHa0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 16}
# {'name': 'Cecil Isbell', 'link': '/coaches/IsbeCe0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 23}
# {'name': 'Joe Judge', 'link': '/coaches/JudgJo0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 23}
# {'name': 'Rod Marinelli', 'link': '/coaches/MariRo0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 38}
# {'name': 'Mike Pettine', 'link': '/coaches/PettMi0.htm', 'wins': 10, 'losses': 22}
# {'name': 'Kay Stephenson', 'link': '/coaches/StepKa0.htm', 'super_bowls': 0, 'wins': 10, 'losses': 26}
# {'name': 'Jack Faulkner', 'link': '/coaches/FaulJa0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 22}
# {'name': 'Al Groh', 'link': '/coaches/GrohAl0.htm', 'wins': 9, 'losses': 7}
# {'name': 'John Mazur', 'link': '/coaches/MazuJo0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 21}
# {'name': 'Cap McEwan', 'link': '/coaches/McEwCa0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 11}
# {'name': 'Nelson Talbot', 'link': '/coaches/TalbNe0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 6}
# {'name': 'Joe Vitt', 'link': '/coaches/VittJo0.htm', 'wins': 9, 'losses': 12}
# {'name': 'Charlie Waller', 'link': '/coaches/WallCh0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 7}
# {'name': 'Bob Waterfield', 'link': '/coaches/WateBo0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 24}
# {'name': 'Bud Wilkinson', 'link': '/coaches/WilkBu0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 20}
# {'name': 'Steve Wilks', 'link': '/coaches/WilkSt0.htm', 'super_bowls': 0, 'wins': 9, 'losses': 19}
# {'name': 'Doc Alexander', 'link': '/coaches/AlexDo0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 8}
# {'name': 'Ed Biles', 'link': '/coaches/BileEd0.htm', 'wins': 8, 'losses': 23}
# {'name': 'Hugh Campbell', 'link': '/coaches/CampHu0.htm', 'wins': 8, 'losses': 22}
# {'name': 'Bob Folwell', 'link': '/coaches/FolwBo0.htm', 'wins': 8, 'losses': 4}
# {'name': 'Jack Forsyth', 'link': '/coaches/ForsJa0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 6}
# {'name': 'Frank Gansz', 'link': '/coaches/GanzFr0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 22}
# {'name': 'Bob Hollway', 'link': '/coaches/HollBo0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 18}
# {'name': 'Ed Khayat', 'link': '/coaches/KhayEd0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 15}
# {'name': 'Dick MacPherson', 'link': '/coaches/McPhDi0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 24}
# {'name': 'Fritz Pollard', 'link': '/coaches/PollFr0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 4}
# {'name': 'Homer Rice', 'link': '/coaches/RiceHo0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 19}
# {'name': 'Carl Storck', 'link': '/coaches/StorCa0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 26}
# {'name': 'Doug Wycoff', 'link': '/coaches/WycoDo0.htm', 'super_bowls': 0, 'wins': 8, 'losses': 9}
# {'name': 'Bill Arnsparger', 'link': '/coaches/ArnsBi0.htm', 'wins': 7, 'losses': 28}
# {'name': 'Rich Bisaccia', 'link': '/coaches/BisaRi0.htm', 'wins': 7, 'losses': 5}
# {'name': 'Hugh Devore', 'link': '/coaches/DevoHu0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 18}
# {'name': 'Frank Filchock', 'link': '/coaches/FilcFr0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 20}
# {'name': 'Jonathan Gannon', 'link': '/coaches/GannJo0.htm', 'wins': 7, 'losses': 17}
# {'name': 'Herb Kopf', 'link': '/coaches/KopfHe0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 22}
# {'name': 'Antonio Pierce', 'link': '/coaches/PierAn0.htm', 'wins': 7, 'losses': 9}
# {'name': 'J.D. Roberts', 'link': '/coaches/RobeJ.0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 25}
# {'name': 'Ralph Scott', 'link': '/coaches/ScotRa0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 8}
# {'name': 'Clipper Smith', 'link': '/coaches/SmitCl0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 16}
# {'name': 'Jerry Williams', 'link': '/coaches/WillJe0.htm', 'super_bowls': 0, 'wins': 7, 'losses': 22}
# {'name': 'Dutch Bergman', 'link': '/coaches/BergDu0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 3}
# {'name': 'Johnny Blood', 'link': '/coaches/BlooJo0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 19}
# {'name': 'Eddie Erdelatz', 'link': '/coaches/ErdeEd0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 10}
# {'name': 'Kevin Gilbride', 'link': '/coaches/GilbKe0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 16}
# {'name': 'Archie Golembeski', 'link': '/coaches/GoleAr0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 5}
# {'name': 'Gus Henderson', 'link': '/coaches/HendGu0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 5}
# {'name': 'Tut Imlay', 'link': '/coaches/ImlaTu0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 3}
# {'name': 'Freddie Kitchens', 'link': '/coaches/KitcFr0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 10}
# {'name': 'Brick Muller', 'link': '/coaches/MullBr0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 3}
# {'name': 'Mike Nixon', 'link': '/coaches/NixoMi0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 30}
# {'name': 'Bob Snyder', 'link': '/coaches/SnydBo0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 6}
# {'name': 'Mac Speedie', 'link': '/coaches/SpeeMa0.htm', 'super_bowls': 0, 'wins': 6, 'losses': 19}
# {'name': 'Jim Tomsula', 'link': '/coaches/TomsJi0.htm', 'wins': 6, 'losses': 11}
# {'name': 'John Armstrong', 'link': '/coaches/ArmsJo0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 2}
# {'name': 'Clem Crowe', 'link': '/coaches/CrowCl0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 12}
# {'name': 'Rod Dowhower', 'link': '/coaches/DowhRo0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 24}
# {'name': 'Hal Erickson', 'link': '/coaches/EricHa0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 8}
# {'name': 'Benny Friedman', 'link': '/coaches/FrieBe0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 9}
# {'name': 'Hal Griffen', 'link': '/coaches/GrifHa0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 6}
# {'name': 'Lane Kiffin', 'link': '/coaches/KiffLa0.htm', 'wins': 5, 'losses': 15}
# {'name': 'Jim Laird', 'link': '/coaches/LairJi0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 7}
# {'name': 'Ken Meyer', 'link': '/coaches/MeyeKe0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 9}
# {'name': 'Marty Mornhinweg', 'link': '/coaches/MornMa0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 27}
# {'name': 'Chris Palmer', 'link': '/coaches/PalmCh0.htm', 'wins': 5, 'losses': 27}
# {'name': 'Harry Robb', 'link': '/coaches/RobbHa0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 13}
# {'name': 'Clive Rush', 'link': '/coaches/RushCl0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 16}
# {'name': 'Dick Todd', 'link': '/coaches/ToddDi0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 4}
# {'name': 'Bulldog Turner', 'link': '/coaches/TurnCl0.htm', 'super_bowls': 0, 'wins': 5, 'losses': 9}
# {'name': 'Herman Ball', 'link': '/coaches/BallHe0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 16}
# {'name': 'Cliff Battles', 'link': '/coaches/BattCl0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 16}
# {'name': 'Scotty Bierce', 'link': '/coaches/BierSc0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 2}
# {'name': 'Hank Bullough', 'link': '/coaches/BullHa0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 18}
# {'name': 'Rob Chudzinski', 'link': '/coaches/ChudRo0.htm', 'wins': 4, 'losses': 12}
# {'name': 'David Culley', 'link': '/coaches/CullDa0.htm', 'wins': 4, 'losses': 13}
# {'name': 'Russ Daugherty', 'link': '/coaches/DaugRu0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 4}
# {'name': 'Aldo Donelli', 'link': '/coaches/DoneAl0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 11}
# {'name': 'Bill Edwards', 'link': '/coaches/EdwaBi0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 9}
# {'name': 'Nathaniel Hackett', 'link': '/coaches/HackNa0.htm', 'wins': 4, 'losses': 11}
# {'name': 'Phil Handler', 'link': '/coaches/HandPh0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 34}
# {'name': 'Norb Hecker', 'link': '/coaches/HeckNo0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 26}
# {'name': 'Ed Hughes', 'link': '/coaches/HughEd0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 9}
# {'name': 'Jim Kendrick', 'link': '/coaches/KendJi0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 7}
# {'name': 'Art Lewis', 'link': '/coaches/LewiAr0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 4}
# {'name': 'Mike Macdonald', 'link': '/coaches/MacdMi0.htm', 'wins': 4, 'losses': 3}
# {'name': 'Gary Moeller', 'link': '/coaches/MoelGa0.htm', 'wins': 4, 'losses': 3}
# {'name': 'Richie Petitbon', 'link': '/coaches/PetiRi0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 12}
# {'name': 'Ed Robinson', 'link': '/coaches/RobiEd0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 4}
# {'name': 'Charley Rogers', 'link': '/coaches/RogeCh0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 4}
# {'name': 'John Sandusky', 'link': '/coaches/SandJo0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 5}
# {'name': 'Howard Schnellenberger', 'link': '/coaches/SchnHo0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 13}
# {'name': 'Joey Sternaman', 'link': '/coaches/SterJo0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 3}
# {'name': 'Hugh Taylor', 'link': '/coaches/TaylHu0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 10}
# {'name': 'Red Weaver', 'link': '/coaches/WeavRe0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 13}
# {'name': 'Richard Williamson', 'link': '/coaches/WillRi0.htm', 'wins': 4, 'losses': 15}
# {'name': 'Swede Youngstrom', 'link': '/coaches/YounSw0.htm', 'super_bowls': 0, 'wins': 4, 'losses': 4}
# {'name': 'Jim Bates', 'link': '/coaches/BateJi0.htm', 'wins': 3, 'losses': 4}
# {'name': 'Wayne Brenkert', 'link': '/coaches/BrenWa0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 7}
# {'name': 'Untz Brewer', 'link': '/coaches/BrewUn0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 5}
# {'name': 'Marty Brill', 'link': '/coaches/BrilMa0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 3}
# {'name': 'Forrest Douds', 'link': '/coaches/DoudJa0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 6}
# {'name': 'Frank Fausch', 'link': '/coaches/FausFr0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 5}
# {'name': 'Perry Fewell', 'link': '/coaches/FewePe0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 8}
# {'name': 'Mike Getto', 'link': '/coaches/GettMi0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 8}
# {'name': 'George Gibson', 'link': '/coaches/GibsGe0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 10}
# {'name': 'Pete Henry', 'link': '/coaches/HenrPe0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 17}
# {'name': 'Wally Hess', 'link': '/coaches/HessWa0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 12}
# {'name': 'Lou Holtz', 'link': '/coaches/HoltLo0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 10}
# {'name': 'Jack Keogh', 'link': '/coaches/KeogJa0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 7}
# {'name': 'Billy Marshall', 'link': '/coaches/MarsBi0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 8}
# {'name': 'Keith Molesworth', 'link': '/coaches/MoleKe0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 9}
# {'name': 'Ted Nesser', 'link': '/coaches/NessTe0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 14}
# {'name': 'Mike Palm', 'link': '/coaches/PalmMi0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 3}
# {'name': 'Pat Peppler', 'link': '/coaches/PeppPa0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 6}
# {'name': 'Bobby Petrino', 'link': '/coaches/PetrBo0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 10}
# {'name': 'Jim Ringo', 'link': '/coaches/RingJi0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 20}
# {'name': 'Les Steckel', 'link': '/coaches/StecLe0.htm', 'wins': 3, 'losses': 13}
# {'name': 'Pete Stinchcomb', 'link': '/coaches/StinPe0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 3}
# {'name': 'John Whelchel', 'link': '/coaches/WhelJo0.htm', 'super_bowls': 0, 'wins': 3, 'losses': 3}
# {'name': 'Darrell Bevell', 'link': '/coaches/BeveDa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 7}
# {'name': 'Pat Boland', 'link': '/coaches/BolaPa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 3}
# {'name': 'Johnny Bryan', 'link': '/coaches/BryaJo0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 13}
# {'name': 'Eddie Casey', 'link': '/coaches/CaseEd0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 8}
# {'name': 'Pete Cawthon', 'link': '/coaches/CawtPe0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 13}
# {'name': 'Jack Chevigny', 'link': '/coaches/ChevJa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 6}
# {'name': 'Al Cornsweet', 'link': '/coaches/CornAl0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 8}
# {'name': 'Luby DiMeolo', 'link': '/coaches/DiMeLu0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 10}
# {'name': 'Bob Dove', 'link': '/coaches/DoveBo0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 2}
# {'name': 'Chuck Drulis', 'link': '/coaches/DrulCh0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 0}
# {'name': 'Marty Feldman', 'link': '/coaches/FeldMa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 15}
# {'name': 'Budge Garrett', 'link': '/coaches/GarrBu0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 1}
# {'name': 'Hank Gillo', 'link': '/coaches/GillHa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 5}
# {'name': 'Hal Hanson', 'link': '/coaches/HansHa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 7}
# {'name': 'Mel Hein', 'link': '/coaches/HeinMe0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 1}
# {'name': 'Harvey Johnson', 'link': '/coaches/JohnHa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 23}
# {'name': 'Aaron Kromer', 'link': '/coaches/KromAa0.htm', 'wins': 2, 'losses': 4}
# {'name': 'Jim Leonard', 'link': '/coaches/LeonJi0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 8}
# {'name': 'Ned Mathews', 'link': '/coaches/MathNe0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 2}
# {'name': 'Harry Mehre', 'link': '/coaches/MehrHa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 5}
# {'name': 'Urban Meyer', 'link': '/coaches/MeyeUr0.htm', 'wins': 2, 'losses': 11}
# {'name': 'Wayne Millner', 'link': '/coaches/MillWa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 8}
# {'name': 'Charley Moran', 'link': '/coaches/MoraCh0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 5}
# {'name': 'Al Pierotti', 'link': '/coaches/PierAl0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 2}
# {'name': 'Ray Prochaska', 'link': '/coaches/ProcRa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 0}
# {'name': 'Terry Robiskie', 'link': '/coaches/RobiTe0.htm', 'wins': 2, 'losses': 6}
# {'name': 'Ted Shipkey', 'link': '/coaches/ShipTe0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 1}
# {'name': 'Herb Sies', 'link': '/coaches/SiesHe0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 3}
# {'name': 'Jerry Smith', 'link': '/coaches/SmitJe0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 3}
# {'name': 'Chuck Studley', 'link': '/coaches/StudCh0.htm', 'wins': 2, 'losses': 8}
# {'name': 'Gus Tebell', 'link': '/coaches/TebeGu0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 1}
# {'name': 'Joe Thomas', 'link': '/coaches/ThomJo0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 9}
# {'name': 'Mel Tucker', 'link': '/coaches/TuckMe0.htm', 'wins': 2, 'losses': 3}
# {'name': 'Rick Venturi', 'link': '/coaches/VentRi0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 17}
# {'name': 'Carl Voyles', 'link': '/coaches/VoylCa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 12}
# {'name': 'Willie Wilkin', 'link': '/coaches/WilkWi0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 2}
# {'name': 'Ray Willsey', 'link': '/coaches/WilsRa0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 0}
# {'name': 'Larry Wilson', 'link': '/coaches/WilsLa0.htm', 'wins': 2, 'losses': 1}
# {'name': 'Hoge Workman', 'link': '/coaches/WorkHo0.htm', 'super_bowls': 0, 'wins': 2, 'losses': 8}
# {'name': 'Shorty Barr', 'link': '/coaches/BarrSh0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 2}
# {'name': 'Tom Bettis', 'link': '/coaches/BettTo0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 6}
# {'name': 'Hugo Bezdek', 'link': '/coaches/BezdHu0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 13}
# {'name': 'Fred Bruney', 'link': '/coaches/BrunFr0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 0}
# {'name': 'Brian Callahan', 'link': '/coaches/CallBr0.htm', 'wins': 1, 'losses': 5}
# {'name': 'Cam Cameron', 'link': '/coaches/CameCa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 15}
# {'name': 'Dave Canales', 'link': '/coaches/CanaDa0.htm', 'wins': 1, 'losses': 6}
# {'name': 'Bill Conkright', 'link': '/coaches/ConkRe0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 8}
# {'name': 'Mel Doherty', 'link': '/coaches/DoheMe0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 3}
# {'name': 'Walt Driskill', 'link': '/coaches/DrisWa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 7}
# {'name': 'Charley Ewart', 'link': '/coaches/EwarCh0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 10}
# {'name': 'Jack Fish', 'link': '/coaches/FishJa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 7}
# {'name': 'Fred Gillies', 'link': '/coaches/GillFr0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 5}
# {'name': 'Hinkey Haines', 'link': '/coaches/HainHi0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 3}
# {'name': 'Dick Hanley', 'link': '/coaches/HanlDi0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 1}
# {'name': 'Ernie Hefferle', 'link': '/coaches/HeffEr0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 7}
# {'name': 'Jack Hegarty', 'link': '/coaches/HegaJa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 2}
# {'name': 'Jack Heldt', 'link': '/coaches/HeldJa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 6}
# {'name': 'Max Hicks', 'link': '/coaches/HickMa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 3}
# {'name': 'Herb Joesting', 'link': '/coaches/JoesHe0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 9}
# {'name': 'Al Jolley', 'link': '/coaches/JollAl0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 10}
# {'name': 'Walt Koppisch', 'link': '/coaches/KoppWa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 6}
# {'name': 'Ollie Kraehe', 'link': '/coaches/KraeOl0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 4}
# {'name': 'Lou Mahrt', 'link': '/coaches/MahrLo0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 6}
# {'name': 'Jerod Mayo', 'link': '/coaches/MayoJe0.htm', 'wins': 1, 'losses': 6}
# {'name': 'Pete McCulley', 'link': '/coaches/McCuPe0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 8}
# {'name': 'Ed McKeever', 'link': '/coaches/McKeEd0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 13}
# {'name': 'Ray McLean', 'link': '/coaches/McLeRa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 12}
# {'name': 'Jack Meagher', 'link': '/coaches/MeagJa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 5}
# {'name': 'Frank Nied', 'link': '/coaches/NiedFr0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 3}
# {'name': "Fred O'Connor", 'link': '/coaches/OConFr0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 6}
# {'name': 'Bill Peterson', 'link': '/coaches/PeteBi0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 18}
# {'name': 'Jerry Rosburg', 'link': '/coaches/RosbJe0.htm', 'wins': 1, 'losses': 1}
# {'name': 'Rod Rust', 'link': '/coaches/RustRo0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 15}
# {'name': 'Andy Salata', 'link': '/coaches/SalaAn0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 7}
# {'name': 'Jeff Saturday', 'link': '/coaches/SatuJe0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 7}
# {'name': 'Tom Scott', 'link': '/coaches/ScotTo0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 0}
# {'name': 'Ken Shipp', 'link': '/coaches/ShipKe0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 4}
# {'name': 'Jim Shofner', 'link': '/coaches/ShofJi0.htm', 'wins': 1, 'losses': 6}
# {'name': 'Dick Stanfel', 'link': '/coaches/StanDi0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 3}
# {'name': 'Mal Stevens', 'link': '/coaches/StevMa0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 4}
# {'name': 'Eric Studesville', 'link': '/coaches/StudEr0.htm', 'wins': 1, 'losses': 3}
# {'name': 'Chris Tabor', 'link': '/coaches/TaboCh0.htm', 'wins': 1, 'losses': 5}
# {'name': 'Emmitt Thomas', 'link': '/coaches/ThomEm0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 2}
# {'name': 'Russell Tollefson', 'link': '/coaches/TollRu0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 3}
# {'name': 'Ron Waller', 'link': '/coaches/WallRo0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 5}
# {'name': 'Chile Walsh', 'link': '/coaches/WalsCh0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 2}
# {'name': 'Hubert Wiggs', 'link': '/coaches/WiggHu0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 3}
# {'name': 'Doc Young', 'link': '/coaches/YounDo0.htm', 'super_bowls': 0, 'wins': 1, 'losses': 7}
# {'name': 'Fay Abbott', 'link': '/coaches/AbboFa0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 13}
# {'name': 'Dim Batterson', 'link': '/coaches/BattDi0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 5}
# {'name': 'Joe Brandy', 'link': '/coaches/BranJo0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 6}
# {'name': 'Charlie Brickley', 'link': '/coaches/BricCh0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 2}
# {'name': 'Frank Bridges', 'link': '/coaches/BridFr0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 5}
# {'name': 'Coonie Checkaye', 'link': '/coaches/ChecCo0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 2}
# {'name': 'Algy Clark', 'link': '/coaches/ClarAl0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 8}
# {'name': 'Stan Cofall', 'link': '/coaches/CofaSt0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 2}
# {'name': 'Frank Coughlin', 'link': '/coaches/CougFr0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 1}
# {'name': 'Jim Crowley', 'link': '/coaches/CrowJi0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 10}
# {'name': 'Herb Dell', 'link': '/coaches/DellHe0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 8}
# {'name': 'John Fassel', 'link': '/coaches/FassJo0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 3}
# {'name': 'Tex Grigg', 'link': '/coaches/GrigTe0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 6}
# {'name': 'Bo Hanley', 'link': '/coaches/HanlBo0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 4}
# {'name': 'Dutch Hendrian', 'link': '/coaches/HendDu0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 5}
# {'name': 'Austin Higgins', 'link': '/coaches/HiggAu0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 2}
# {'name': 'Ken Huffine', 'link': '/coaches/HuffKe0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 1}
# {'name': 'Hal Hunter', 'link': '/coaches/HuntHa0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 1}
# {'name': 'Bull Karcis', 'link': '/coaches/KarcBu0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 8}
# {'name': 'Ed Kubale', 'link': '/coaches/KubaEd0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 5}
# {'name': 'Hank Kuhlmann', 'link': '/coaches/KuhlHa0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 5}
# {'name': 'Leo Lyons', 'link': '/coaches/LyonLe0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 7}
# {'name': 'Alfred McGall', 'link': '/coaches/McGaAl0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 3}
# {'name': 'Wally McIlwain', 'link': '/coaches/McIlWa0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 2}
# {'name': 'Dick Modzelewski', 'link': '/coaches/ModzDi0.htm', 'wins': 0, 'losses': 1}
# {'name': 'Johnny Murphy', 'link': '/coaches/MurpJo0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 4}
# {'name': 'Al Nesser', 'link': '/coaches/NessAl0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 1}
# {'name': 'Tam Rose', 'link': '/coaches/RoseTa0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 1}
# {'name': 'Lenny Sachs', 'link': '/coaches/SachLe0.htm', 'super_bowls': 0, 'wins': 0, 'losses': 4}
# {'name': 'Giff Smith', 'link': '/coaches/SmitGi0.htm', 'wins': 0, 'losses': 3}
# {'name': 'Jeff Ulbrich', 'link': '/coaches/UlbrJe0.htm', 'wins': 0, 'losses': 2}

# %%
# !mkdir data/head_coaches_detailed

# %%
## Loop testing

import csv

# Read the CSV file containing coach URLs
df_url = pd.read_csv('./data/head_coaches.csv')

# Loop through each row in the DataFrame
for index, row in df_url.iterrows():
    coach_name = row['name']
    coach_name_with_underscore = coach_name.replace(' ', '_')
    url = row['url']

    try:
#        response = requests.get(url, headers=headers)
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for 4xx or 5xx status codes

        soup = BeautifulSoup(response.text, "html.parser")


        # Find the table body
        table_body = soup.find('tbody')

        # Prepare a CSV file to write to
        with open(f'./data/head_coaches_detailed/{coach_name_with_underscore}', 'w', newline='') as csvfile:
            fieldnames = ['year_id', 'team', 'league_id', 'wins', 'losses', 'ties', 'wins_playoffs', 'losses_playoffs']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            writer.writeheader()

            # Loop over each row
            for row in table_body.find_all('tr'):
                # Find each cell
                year_id = row.find('th', attrs={'data-stat': 'year_id'}).text
                team = row.find('td', attrs={'data-stat': 'team'}).text
                league_id = row.find('td', attrs={'data-stat': 'league_id'}).text
                wins = row.find('td', attrs={'data-stat': 'wins'}).text
                losses = row.find('td', attrs={'data-stat': 'losses'}).text
                ties = row.find('td', attrs={'data-stat': 'ties'}).text
                wins_playoffs = row.find('td', attrs={'data-stat': 'wins_playoffs'}).text
                losses_playoffs = row.find('td', attrs={'data-stat': 'losses_playoffs'}).text

                # Write to the CSV file
                writer.writerow({
                    'year_id': year_id,
                    'team': team,
                    'league_id': league_id,
                    'wins': wins,
                    'losses': losses,
                    'ties': ties,
                    'wins_playoffs': wins_playoffs if wins_playoffs else '0', # If no data present, write '0'
                    'losses_playoffs': losses_playoffs if losses_playoffs else '0', # If no data present, write '0'
                })
                
                print(f"CSV file '{coach_name_with_underscore}' saved successfully.")

                # Pause for a short duration to avoid overwhelming the server
                time.sleep(2.5)  # Adjust the duration (in seconds) as needed
                
                
    except (requests.exceptions.RequestException, AttributeError, ValueError) as e:
        print(f"Error occurred while processing '{coach_name}': {str(e)}")
# Out:
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'Don_Shula' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'George_Halas' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Bill_Belichick' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Andy_Reid' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Tom_Landry' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Curly_Lambeau' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Paul_Brown' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Marty_Schottenheimer' saved successfully.
# CSV file 'Chuck_Noll' saved successfully.
# CSV file 'Chuck_Noll' saved successfully.
# CSV file 'Chuck_Noll' saved successfully.
# CSV file 'Chuck_Noll' saved successfully.
# CSV file 'Chuck_Noll' saved successfully.
# CSV file 'Chuck_Noll' saved successfully.
# CSV file 'Chuck_Noll' saved successfully.
# CSV file 'Chuck_Noll' saved successfully.
# CSV file 'Chuck_Noll' saved successfully.
# CSV file 'Chuck_Noll' saved successfully.
# CSV file 'Chuck_Noll' saved successfully.
# CSV file 'Chuck_Noll' saved successfully.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 60
#      57             print(f"CSV file '{coach_name_with_underscore}' saved successfully.")
#      59             # Pause for a short duration to avoid overwhelming the server
# ---> 60             time.sleep(2.5)  # Adjust the duration (in seconds) as needed
#      63 except (requests.exceptions.RequestException, AttributeError, ValueError) as e:
#      64     print(f"Error occurred while processing '{coach_name}': {str(e)}")
#
# KeyboardInterrupt:

# %%
## Coaches since 2015

# Get the current year
current_year = datetime.now().year

# Create an empty list to store the names of the coaches
coaches = []

# Loop through all the files in the directory
for filename in os.listdir('./data/head_coaches_detailed/'):
    if filename.endswith(".csv"):  # Check if the file is a CSV file
        # Load the CSV file into a pandas DataFrame
        file_path = os.path.join('./data/head_coaches_detailed/', filename)
        df = pd.read_csv(file_path)

        # Check if the coach coached a team since 2015
        if df['year_id'].max() >= 2015 and df['year_id'].min() <= current_year:
            # Extract the name of the coach from the filename and append it to the list
            coach_name = filename.replace(".csv", "")
            coaches.append(coach_name)

# Display the list of coaches
print(coaches)
#print(coaches.unique())

# %%
## Coaches since 2015

# Get the current year
current_year = datetime.now().year

# Create an empty list to store the names of the coaches and their teams
coaches_teams = []

# Loop through all the files in the directory
for filename in os.listdir('./data/head_coaches_detailed/'):
    if filename.endswith(".csv"):  # Check if the file is a CSV file
        # Load the CSV file into a pandas DataFrame
        file_path = os.path.join('./data/head_coaches_detailed/', filename)
        df = pd.read_csv(file_path)

        # Check if the coach coached a team since 2015
        if df['year_id'].max() >= 2015 and df['year_id'].min() <= current_year:
            # Extract the name of the coach from the filename
            coach_name = filename.replace(".csv", "")

            # Get the unique teams the coach has coached since 2015
            teams = df[df['year_id'] >= 2015]['team'].unique()

            # Append the coach's name and team(s) to the list
            for team in teams:
                coaches_teams.append((coach_name, team))

# Display the list of coaches and their teams
for coach, team in coaches_teams:
    print(f'Coach: {coach}, Team: {team}')

# %%
## 1st year coaches test 2

# Get the current year
current_year = datetime.now().year

# Create an empty list to store the names of the first-year coaches and their teams
first_year_coaches_teams = []

# Loop through all the files in the directory
for filename in os.listdir('./data/head_coaches_detailed/'):
    if filename.endswith(".csv"):  # Check if the file is a CSV file
        # Load the CSV file into a pandas DataFrame
        file_path = os.path.join('./data/head_coaches_detailed/', filename)
        df = pd.read_csv(file_path)

        # Check if the coach coached a team since 2015
        if df['year_id'].max() >= 2015 and df['year_id'].min() <= current_year:
            # Extract the name of the coach from the filename
            coach_name = filename.replace(".csv", "")

            # Get the unique teams the coach has coached since 2015
            teams = df[df['year_id'] >= 2015]['team'].unique()

            # Check if the coach was a first-year coach for the team(s)
            for team in teams:
                first_year = df[df['team'] == team]['year_id'].min()
                if 2015 <= first_year <= current_year:
                    first_year_coaches_teams.append((coach_name, team))
                    
# Display the list of first-year coaches and their teams
for coach, team in first_year_coaches_teams:
    print(f'First-year Coach: {coach}, Team: {team}')

# %%
## 1st year coaches test 3

# Get the current year
current_year = datetime.now().year

# Create an empty list to store the names of the first-year coaches, their teams, and the year
first_year_coaches_teams_year = []

# Loop through all the files in the directory
for filename in os.listdir('./data/head_coaches_detailed/'):
    if filename.endswith(".csv"):  # Check if the file is a CSV file
        # Load the CSV file into a pandas DataFrame
        file_path = os.path.join('./data/head_coaches_detailed/', filename)
        df = pd.read_csv(file_path)

        # Check if the coach coached a team since 2015
        if df['year_id'].max() >= 2015 and df['year_id'].min() <= current_year:
            # Extract the name of the coach from the filename
            coach_name = filename.replace(".csv", "")

            # Get the unique teams the coach has coached since 2015
            teams = df[df['year_id'] >= 2015]['team'].unique()

            # Check if the coach was a first-year coach for the team(s)
            for team in teams:
                first_year = df[df['team'] == team]['year_id'].min()
                if 2015 <= first_year <= current_year:
                    first_year_coaches_teams_year.append((coach_name, team, first_year))

# Display the list of first-year coaches, their teams, and the year
for coach, team, year in first_year_coaches_teams_year:
    print(f'First-year Coach: {coach}, Team: {team}, Year: {year}')

# %%
## 1st year coaches test 4

# Get the current year
current_year = datetime.now().year

# Create an empty list to store the names of the first-year coaches, their teams, and the year
first_year_coaches_performance = []

# Loop through all the files in the directory
for filename in os.listdir('./data/head_coaches_detailed/'):
    if filename.endswith(".csv"):  # Check if the file is a CSV file
        # Load the CSV file into a pandas DataFrame
        file_path = os.path.join('./data/head_coaches_detailed/', filename)
        df = pd.read_csv(file_path)

        # Check if the coach coached a team since 2015
        if df['year_id'].max() >= 2015 and df['year_id'].min() <= current_year:
            # Extract the name of the coach from the filename
            coach_name = filename.replace(".csv", "")

            # Get the unique teams the coach has coached since 2015
            teams = df[df['year_id'] >= 2015]['team'].unique()

            # Check if the coach was a first-year coach for the team(s)
            for team in teams:
                first_year = df[df['team'] == team]['year_id'].min()
                if 2015 <= first_year <= current_year:
                    # Get the performance stats for the first year
                    performance = df[(df['year_id'] == first_year) & (df['team'] == team)].iloc[0]
                    wins = performance['wins']
                    losses = performance['losses']
                    ties = performance['ties']
                    playoff_wins = performance['wins_playoffs']
                    playoff_losses = performance['losses_playoffs']

                    first_year_coaches_performance.append((coach_name, team, first_year, wins, losses, ties, playoff_wins, playoff_losses))

# Display the list of first-year coaches, their teams, and the year
for coach, team, year, wins, losses, ties, playoff_wins, playoff_losses in first_year_coaches_performance:
    print(f'First-year Coach: {coach}, Team: {team}, Year: {year}, Wins: {wins}, Losses: {losses}, Ties: {ties}, Playoff Wins: {playoff_wins}, Playoff Losses: {playoff_losses}')

# %%
## Playoff coaches

# Print instances with combined playoff_wins and playoff_losses more than 0
print("\nFirst-year coaches with playoff wins or losses:")
for coach, team, year, wins, losses, ties, playoff_wins, playoff_losses in first_year_coaches_performance:
    combined_playoff_stats = playoff_wins + playoff_losses
    if combined_playoff_stats > 0:
        print(f'Coach: {coach}, Team: {team}, Year: {year}, Playoff Wins: {playoff_wins}, Playoff Losses: {playoff_losses}')

# %%
## Fired coaches chronologically
## Or retired/suspended/outliers

# Assuming you have already created the 'first_year_coaches_performance' list

# Sort the list based on the year in ascending order
sorted_coaches_performance = sorted(first_year_coaches_performance, key=lambda x: x[2], reverse=True)

# Initialize a counter for instances that do not add up to 16 or 17
count_mismatched_instances = 0

# Loop through each instance in the sorted list
for coach, team, year, wins, losses, ties, _, _ in sorted_coaches_performance:
    total_games = wins + losses + ties
    if total_games != 16 and total_games != 17:
        count_mismatched_instances += 1
        print(f"Coach: {coach}, Team: {team}, Year: {year}, Wins: {wins}, Losses: {losses}, Ties: {ties}")
        print(f"Total Games Coached: {total_games}\n")

# Display the count of instances where wins, losses, and ties do not add up to 16 or 17
print(f"Number of instances with wins, losses, and ties not adding up to 16 or 17: {count_mismatched_instances}")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a pivot table
pivot_table = pd.pivot_table(first_year_coaches_performance_df, values='Wins', index=['Coach'], columns='Losses')

plt.figure(figsize=(10, 10))
sns.heatmap(pivot_table, cmap="YlGnBu")
plt.title("Heatmap of Wins vs Losses for First-Year Coaches")
plt.show()

# %%
import plotly.express as px

fig = px.scatter_3d(first_year_coaches_performance_df, x='Wins', y='Losses', z='Ties', color='Coach')
fig.update_layout(title="3D Scatter Plot of Wins, Losses, and Ties for First-Year Coaches")
fig.show()

# %%
import plotly.express as px

fig = px.scatter_3d(first_year_coaches_performance_df, x='Wins', y='Losses', z='Ties', color='Coach')
fig.update_layout(title="3D Scatter Plot of Wins, Losses, and Ties for First-Year Coaches")
fig.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already created the 'first_year_coaches_performance' list

# Create a DataFrame from the 'first_year_coaches_performance' list
columns = ['Coach', 'Team', 'Year', 'Wins', 'Losses', 'Ties', 'Playoff Wins', 'Playoff Losses']
df = pd.DataFrame(first_year_coaches_performance, columns=columns)

# Calculate the average wins, losses, and ties for each coach
average_stats = df.groupby('Coach')[['Wins', 'Losses', 'Ties']].mean().reset_index()

# Display the average statistics
print("\nAverage Statistics:")
print(average_stats)

# Plot the average statistics as a bar chart
fig, ax = plt.subplots(figsize=(10, 6))
x = average_stats['Coach']
y_wins = average_stats['Wins']
y_losses = average_stats['Losses']
y_ties = average_stats['Ties']

ax.bar(x, y_wins, label='Average Wins', color='green', alpha=0.7)
ax.bar(x, y_losses, bottom=y_wins, label='Average Losses', color='red', alpha=0.7)
ax.bar(x, y_ties, bottom=y_wins + y_losses, label='Average Ties', color='blue', alpha=0.7)

ax.set_xlabel('Coach')
ax.set_ylabel('Average Statistics')
ax.set_title('Average Wins, Losses, and Ties for First-Year Coaches')
ax.legend()
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already created the 'first_year_coaches_performance' list

# Create a DataFrame from the 'first_year_coaches_performance' list
columns = ['Coach', 'Team', 'Year', 'Wins', 'Losses', 'Ties', 'Playoff Wins', 'Playoff Losses']
df = pd.DataFrame(first_year_coaches_performance, columns=columns)

# Calculate the average wins, losses, and ties across all coaches
average_stats = df[['Wins', 'Losses', 'Ties']].mean()

# Display the overall average statistics
print("\nOverall Average Statistics:")
print(average_stats)

# Plot the overall average statistics as a bar chart
fig, ax = plt.subplots(figsize=(8, 6))
x = average_stats.index
y = average_stats.values

ax.bar(x, y, color=['green', 'red', 'blue'], alpha=0.7)

ax.set_xlabel('Statistics')
ax.set_ylabel('Average')
ax.set_title('Overall Average Wins, Losses, and Ties for First-Year Coaches')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already created the 'first_year_coaches_performance' list

# Create a DataFrame from the 'first_year_coaches_performance' list
columns = ['Coach', 'Team', 'Year', 'Wins', 'Losses', 'Ties', 'Playoff Wins', 'Playoff Losses']
df = pd.DataFrame(first_year_coaches_performance, columns=columns)

# Filter out instances where the coach has less than 10 combined wins, losses, and ties
df = df[df['Wins'] + df['Losses'] + df['Ties'] >= 10]

# Calculate the average wins, losses, and ties across all coaches
average_stats = df[['Wins', 'Losses', 'Ties']].mean()

# Display the overall average statistics
print("\nOverall Average Statistics (for coaches with >= 10 combined wins, losses, and ties):")
print(average_stats)

# Plot the overall average statistics as a bar chart
fig, ax = plt.subplots(figsize=(8, 6))
x = average_stats.index
y = average_stats.values

ax.bar(x, y, color=['green', 'red', 'blue'], alpha=0.7)

ax.set_xlabel('Statistics')
ax.set_ylabel('Average')
ax.set_title('Overall Average Wins, Losses, and Ties for First-Year Coaches (with >= 10 combined wins, losses, and ties)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
### LOOP

# headers = {
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
# }

# Read the CSV file containing coach URLs
df_url = pd.read_csv('./data/head_coaches.csv')

# Loop through each row in the DataFrame
for index, row in df_url.iterrows():
    coach_name = row['name']
    coach_name_with_underscore = coach_name.replace(' ', '_')
    url = row['url']

    try:
#        response = requests.get(url, headers=headers)
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for 4xx or 5xx status codes

        soup = BeautifulSoup(response.text, "html.parser")

        # Find the div that contains the table
        div = soup.find("div", {"id": "all_coaching_history"})

        # The table is in a comment, so find the comment
        comment = div.find(string=lambda text: isinstance(text, Comment))

        # Parse the comment as HTML
        table = BeautifulSoup(comment, "html.parser").find("table", {"id": "coaching_history"})

        # Prepare list to store data
        data = []

        # Iterate through each row in the table (skipping the first header row)
        for row in table.find_all("tr")[1:]:
            year_id = row.find("th", {"data-stat": "year_id"}).text.strip() if row.find("th", {"data-stat": "year_id"}) else ""
            coach_age = row.find("td", {"data-stat": "coach_age"}).text.strip() if row.find("td", {"data-stat": "coach_age"}) else ""

            # Check if team name is a link or not
            employer_data = row.find("td", {"data-stat": "coach_employer"})
            if employer_data.a is not None:
                coach_employer = employer_data.a.text.strip()
            else:
                coach_employer = employer_data.text.strip()

            coach_role = row.find("td", {"data-stat": "coach_role"}).text.strip()
            
            ##### ADDING MORE MANUALLY

            #<tr ><th scope="row" class="left " data-stat="year_id" ><a href="/years/2016/">2016</a></th><td class="right " data-stat="age" >53</td><td class="left " data-stat="team" ><a href="/teams/gnb/2016.htm">GNB</a></td><td class="left " data-stat="league_id" >NFL</td><td class="right " data-stat="g" ><a href="/teams/gnb/2016_games.htm" title="Click for season gamelogs">16</a></td><td class="right " data-stat="wins" >10</td><td class="right " data-stat="losses" >6</td><td class="right iz" data-stat="ties" >0</td><td class="right " data-stat="win_loss_perc" >.625</td><td class="right " data-stat="srs_total" >2.8</td><td class="right " data-stat="srs_offense" >4.9</td><td class="right " data-stat="srs_defense" >-2.0</td><td class="right " data-stat="g_playoffs" >3</td><td class="right " data-stat="wins_playoffs" >2</td><td class="right " data-stat="losses_playoffs" >1</td><td class="right " data-stat="win_loss_playoffs_perc" >.667</td><td class="right " data-stat="rank_team" >1</td><td class="right " data-stat="chall_num" >5</td><td class="right " data-stat="chall_won" >3</td><td class="left " data-stat="coach_remarks" > </td></tr>
            # wins = row.find("td", {"data-stat": "wins"}).text
            # losses = row.find("td", {"data-stat": "losses"}).text
            # ties = row.find("td", {"data-stat": "ties"}).text
            # wins_playoffs = row.find("td", {"data-stat": "wins_playoffs"}).text
            # losses_playoffs = row.find("td", {"data-stat": "losses_playoffs"}).text
            wins = row.find("td", {"data-stat": "wins"}).text if row.find("td", {"data-stat": "wins"}) else ""
            losses = row.find("td", {"data-stat": "losses"}).text if row.find("td", {"data-stat": "losses"}) else ""
            ties = row.find("td", {"data-stat": "ties"}).text if row.find("td", {"data-stat": "ties"}) else ""
            wins_playoffs = row.find("td", {"data-stat": "wins_playoffs"}).text if row.find("td", {"data-stat": "wins_playoffs"}) else ""
            losses_playoffs = row.find("td", {"data-stat": "losses_playoffs"}).text if row.find("td", {"data-stat": "losses_playoffs"}) else ""



            ##### ADDING MORE MANUALLY END

            data.append([year_id, coach_age, coach_employer, coach_role, wins, losses, ties, wins_playoffs, losses_playoffs])

        # Convert list to DataFrame
        df = pd.DataFrame(data, columns=["Year", "Age", "Employer", "Role", "Wins", "Losses", "Ties", "Wins_Playoffs", "Losses_Playoffs"])

        # Write DataFrame to CSV with the modified coach's name as the file name
        file_name = f"./data/head_coaches_detailed/{coach_name_with_underscore}.csv"
        df.to_csv(file_name, index=False)

        print(f"CSV file '{file_name}' saved successfully.")

        # Pause for a short duration to avoid overwhelming the server
        time.sleep(1)  # Adjust the duration (in seconds) as needed

    except (requests.exceptions.RequestException, AttributeError, ValueError) as e:
        print(f"Error occurred while processing '{coach_name}': {str(e)}")
# Out:
# CSV file './data/head_coaches_detailed/Don_Shula.csv' saved successfully.
# CSV file './data/head_coaches_detailed/George_Halas.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Bill_Belichick.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Andy_Reid.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Tom_Landry.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Curly_Lambeau.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Paul_Brown.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Marty_Schottenheimer.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Chuck_Noll.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Dan_Reeves.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Chuck_Knox.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Mike_Tomlin.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Jeff_Fisher.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Bill_Parcells.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Pete_Carroll.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Tom_Coughlin.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Mike_McCarthy.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Mike_Shanahan.csv' saved successfully.
# CSV file './data/head_coaches_detailed/John_Harbaugh.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Sean_Payton.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Mike_Holmgren.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Bud_Grant.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Joe_Gibbs.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Steve_Owen.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Bill_Cowher.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Marv_Levy.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Tony_Dungy.csv' saved successfully.
# CSV file './data/head_coaches_detailed/John_Fox.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Marvin_Lewis.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Hank_Stram.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Weeb_Ewbank.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Jim_Mora.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Sid_Gillman.csv' saved successfully.
# CSV file './data/head_coaches_detailed/Mike_Ditka.csv' saved successfully.
# Error occurred while processing 'Dick Vermeil': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/VermDi0.htm
# Error occurred while processing 'Jon Gruden': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/GrudJo0.htm
# Error occurred while processing 'George Allen': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/AlleGe0.htm
# Error occurred while processing 'George Seifert': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/SeifGe0.htm
# Error occurred while processing 'Norv Turner': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/TurnNo0.htm
# Error occurred while processing 'Dennis Green': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/GreeDe0.htm
# Error occurred while processing 'Don Coryell': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/CoryDo0.htm
# Error occurred while processing 'Buddy Parker': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ParkRa0.htm
# Error occurred while processing 'John Madden': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MaddJo0.htm
# Error occurred while processing 'Ron Rivera': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/RiveRo0.htm
# Error occurred while processing 'Tom Flores': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/FlorTo0.htm
# Error occurred while processing 'Vince Lombardi': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/LombVi0.htm
# Error occurred while processing 'Lou Saban': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/SabaLo0.htm
# Error occurred while processing 'Jack Del Rio': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/DelRJa0.htm
# Error occurred while processing 'Lovie Smith': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/SmitLo0.htm
# Error occurred while processing 'Bill Walsh': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/WalsBi0.htm
# Error occurred while processing 'Buck Shaw': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ShawLa0.htm
# Error occurred while processing 'Jimmy Conzelman': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ConzJi0.htm
# Error occurred while processing 'Ted Marchibroda': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MarcTe0.htm
# Error occurred while processing 'Jack Pardee': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/PardJa0.htm
# Error occurred while processing 'Jason Garrett': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/GarrJa0.htm
# Error occurred while processing 'Sam Wyche': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/WychSa0.htm
# Error occurred while processing 'Gary Kubiak': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/KubiGa0.htm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 18
#      14     url = row['url']
#      16     try:
#      17 #        response = requests.get(url, headers=headers)
# ---> 18         response = requests.get(url)
#      19         response.raise_for_status()  # Raise an exception for 4xx or 5xx status codes
#      21         soup = BeautifulSoup(response.text, "html.parser")
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/urllib3/connectionpool.py:1096, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 # Force connect early to allow us to validate the connection.
#    1095 if conn.is_closed:
# -> 1096     conn.connect()
#    1098 if not conn.is_verified:
#    1099     warnings.warn(
#    1100         (
#    1101             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1106         InsecureRequestWarning,
#    1107     )
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/urllib3/connection.py:611, in HTTPSConnection.connect(self)
#     609 def connect(self) -> None:
#     610     sock: socket.socket | ssl.SSLSocket
# --> 611     self.sock = sock = self._new_conn()
#     612     server_hostname: str = self.host
#     613     tls_in_tls = False
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/urllib3/connection.py:203, in HTTPConnection._new_conn(self)
#     198 """Establish a socket connection and set nodelay settings on it.
#     199
#     200 :return: New socket connection.
#     201 """
#     202 try:
# --> 203     sock = connection.create_connection(
#     204         (self._dns_host, self.port),
#     205         self.timeout,
#     206         source_address=self.source_address,
#     207         socket_options=self.socket_options,
#     208     )
#     209 except socket.gaierror as e:
#     210     raise NameResolutionError(self.host, self, e) from e
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      57 except UnicodeError:
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#      62     sock = None
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/socket.py:963, in getaddrinfo(host, port, family, type, proto, flags)
#     960 # We override this function since we want to translate the numeric family
#     961 # and socket type values to enum constants.
#     962 addrlist = []
# --> 963 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     964     af, socktype, proto, canonname, sa = res
#     965     addrlist.append((_intenum_converter(af, AddressFamily),
#     966                      _intenum_converter(socktype, SocketKind),
#     967                      proto, canonname, sa))
#
# KeyboardInterrupt:

# %%
## Loop testing

# Read the CSV file containing coach URLs
df_url = pd.read_csv('./data/head_coaches.csv')

# Loop through each row in the DataFrame
for index, row in df_url.iterrows():
    coach_name = row['name']
    coach_name_with_underscore = coach_name.replace(' ', '_')
    url = row['url']

    try:
#        response = requests.get(url, headers=headers)
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for 4xx or 5xx status codes

        soup = BeautifulSoup(response.text, "html.parser")


        # Find the table body
        table_body = soup.find('tbody')

        # Prepare a CSV file to write to
        with open(f'./data/head_coaches_detailed/{coach_name_with_underscore}', 'w', newline='') as csvfile:
            fieldnames = ['year_id', 'team', 'league_id', 'wins', 'losses', 'ties', 'wins_playoffs', 'losses_playoffs']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

            writer.writeheader()

            # Loop over each row
            for row in table_body.find_all('tr'):
                # Find each cell
                year_id = row.find('th', attrs={'data-stat': 'year_id'}).text
                team = row.find('td', attrs={'data-stat': 'team'}).text
                league_id = row.find('td', attrs={'data-stat': 'league_id'}).text
                wins = row.find('td', attrs={'data-stat': 'wins'}).text
                losses = row.find('td', attrs={'data-stat': 'losses'}).text
                ties = row.find('td', attrs={'data-stat': 'ties'}).text
                wins_playoffs = row.find('td', attrs={'data-stat': 'wins_playoffs'}).text
                losses_playoffs = row.find('td', attrs={'data-stat': 'losses_playoffs'}).text

                # Write to the CSV file
                writer.writerow({
                    'year_id': year_id,
                    'team': team,
                    'league_id': league_id,
                    'wins': wins,
                    'losses': losses,
                    'ties': ties,
                    'wins_playoffs': wins_playoffs if wins_playoffs else '0', # If no data present, write '0'
                    'losses_playoffs': losses_playoffs if losses_playoffs else '0', # If no data present, write '0'
                })
                
                print(f"CSV file '{coach_name_with_underscore}' saved successfully.")

                # Pause for a short duration to avoid overwhelming the server
                time.sleep(1)  # Adjust the duration (in seconds) as needed
                
                
    except (requests.exceptions.RequestException, AttributeError, ValueError) as e:
        print(f"Error occurred while processing '{coach_name}': {str(e)}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 24
#      21 table_body = soup.find('tbody')
#      23 # Prepare a CSV file to write to
# ---> 24 with open(f'./data/head_coaches_detailed/{coach_name_with_underscore}', 'w', newline='') as csvfile:
#      25     fieldnames = ['year_id', 'team', 'league_id', 'wins', 'losses', 'ties', 'wins_playoffs', 'losses_playoffs']
#      26     writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/head_coaches_detailed/Don_Shula'

# %%
# ## Loop testing

# # Read the CSV file containing coach URLs
# df_url = pd.read_csv('./data/head_coaches.csv')

# # Loop through each row in the DataFrame
# for index, row in df_url.iterrows():
#     coach_name = row['name']
#     coach_name_with_underscore = coach_name.replace(' ', '_')
#     url = row['url']

#     try:
# #        response = requests.get(url, headers=headers)
#         response = requests.get(url)
#         response.raise_for_status()  # Raise an exception for 4xx or 5xx status codes

#         soup = BeautifulSoup(response.text, "html.parser")


#         # Find the table body
#         table_body = soup.find('tbody')

#         # Prepare a CSV file to write to
#         with open(f'./data/head_coaches_detailed/{coach_name_with_underscore}', 'w', newline='') as csvfile:
#             fieldnames = ['year_id', 'team', 'league_id', 'wins', 'losses', 'ties', 'wins_playoffs', 'losses_playoffs']
#             writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

#             writer.writeheader()

#             # Loop over each row
#             for row in table_body.find_all('tr'):
#                 # Find each cell
#                 year_id = row.find('th', attrs={'data-stat': 'year_id'}).text
#                 team = row.find('td', attrs={'data-stat': 'team'}).text
#                 league_id = row.find('td', attrs={'data-stat': 'league_id'}).text
#                 wins = row.find('td', attrs={'data-stat': 'wins'}).text
#                 losses = row.find('td', attrs={'data-stat': 'losses'}).text
#                 ties = row.find('td', attrs={'data-stat': 'ties'}).text
#                 wins_playoffs = row.find('td', attrs={'data-stat': 'wins_playoffs'}).text
#                 losses_playoffs = row.find('td', attrs={'data-stat': 'losses_playoffs'}).text

#                 # Write to the CSV file
#                 writer.writerow({
#                     'year_id': year_id,
#                     'team': team,
#                     'league_id': league_id,
#                     'wins': wins,
#                     'losses': losses,
#                     'ties': ties,
#                     'wins_playoffs': wins_playoffs if wins_playoffs else '0', # If no data present, write '0'
#                     'losses_playoffs': losses_playoffs if losses_playoffs else '0', # If no data present, write '0'
#                 })
                
#                 print(f"CSV file '{coach_name_with_underscore}' saved successfully.")

#                 # Pause for a short duration to avoid overwhelming the server
#                 time.sleep(5)  # Adjust the duration (in seconds) as needed
                
                
#     except (requests.exceptions.RequestException, AttributeError, ValueError) as e:
#         print(f"Error occurred while processing '{coach_name}': {str(e)}")

### LOOP

# headers = {
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
# }

# Read the CSV file containing coach URLs
df_url = pd.read_csv('./data/head_coaches.csv')

# Loop through each row in the DataFrame
for index, row in df_url.iterrows():
    coach_name = row['name']
    coach_name_with_underscore = coach_name.replace(' ', '_')
    url = row['url']

    try:
#        response = requests.get(url, headers=headers)
        response = requests.get(url)
        response.raise_for_status()  # Raise an exception for 4xx or 5xx status codes

        soup = BeautifulSoup(response.text, "html.parser")

        # Find the div that contains the table
        div = soup.find("div", {"id": "all_coaching_history"})

        # The table is in a comment, so find the comment
        comment = div.find(string=lambda text: isinstance(text, Comment))

        # Parse the comment as HTML
        table = BeautifulSoup(comment, "html.parser").find("table", {"id": "coaching_history"})

        # Prepare list to store data
        data = []

        # Iterate through each row in the table (skipping the first header row)
        for row in table.find_all("tr")[1:]:
            year_id = row.find("th", {"data-stat": "year_id"}).text.strip()
            coach_age = row.find("td", {"data-stat": "coach_age"}).text.strip()

            # Check if team name is a link or not
            employer_data = row.find("td", {"data-stat": "coach_employer"})
            if employer_data.a is not None:
                coach_employer = employer_data.a.text.strip()
            else:
                coach_employer = employer_data.text.strip()

            coach_role = row.find("td", {"data-stat": "coach_role"}).text.strip()
            
            ##### ADDING MORE MANUALLY

            #<tr ><th scope="row" class="left " data-stat="year_id" ><a href="/years/2016/">2016</a></th><td class="right " data-stat="age" >53</td><td class="left " data-stat="team" ><a href="/teams/gnb/2016.htm">GNB</a></td><td class="left " data-stat="league_id" >NFL</td><td class="right " data-stat="g" ><a href="/teams/gnb/2016_games.htm" title="Click for season gamelogs">16</a></td><td class="right " data-stat="wins" >10</td><td class="right " data-stat="losses" >6</td><td class="right iz" data-stat="ties" >0</td><td class="right " data-stat="win_loss_perc" >.625</td><td class="right " data-stat="srs_total" >2.8</td><td class="right " data-stat="srs_offense" >4.9</td><td class="right " data-stat="srs_defense" >-2.0</td><td class="right " data-stat="g_playoffs" >3</td><td class="right " data-stat="wins_playoffs" >2</td><td class="right " data-stat="losses_playoffs" >1</td><td class="right " data-stat="win_loss_playoffs_perc" >.667</td><td class="right " data-stat="rank_team" >1</td><td class="right " data-stat="chall_num" >5</td><td class="right " data-stat="chall_won" >3</td><td class="left " data-stat="coach_remarks" > </td></tr>
            wins = row.find("td", {"data-stat": "wins"}).text
            losses = row.find("td", {"data-stat": "losses"}).text
            ties = row.find("td", {"data-stat": "ties"}).text
            wins_playoffs = row.find("td", {"data-stat": "wins_playoffs"}).text
            losses_playoffs = row.find("td", {"data-stat": "losses_playoffs"}).text


            ##### ADDING MORE MANUALLY END

            data.append([year_id, coach_age, coach_employer, coach_role, wins, losses, ties, wins_playoffs, losses_playoffs])

        # Convert list to DataFrame
        df = pd.DataFrame(data, columns=["Year", "Age", "Employer", "Role", "Wins", "Losses", "Ties", "Wins_Playoffs", "Losses_Playoffs"])

        # Write DataFrame to CSV with the modified coach's name as the file name
        file_name = f"./data/head_coaches_detailed/{coach_name_with_underscore}.csv"
        df.to_csv(file_name, index=False)

        print(f"CSV file '{file_name}' saved successfully.")

        # Pause for a short duration to avoid overwhelming the server
        time.sleep(5)  # Adjust the duration (in seconds) as needed

    except (requests.exceptions.RequestException, AttributeError, ValueError) as e:
        print(f"Error occurred while processing '{coach_name}': {str(e)}")
# Out:
# Error occurred while processing 'Don Shula': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'George Halas': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Bill Belichick': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Andy Reid': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Tom Landry': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Curly Lambeau': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Paul Brown': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Marty Schottenheimer': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Chuck Noll': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Dan Reeves': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Chuck Knox': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Mike Tomlin': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Jeff Fisher': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Bill Parcells': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Pete Carroll': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Tom Coughlin': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Mike McCarthy': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Mike Shanahan': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'John Harbaugh': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Sean Payton': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Mike Holmgren': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Bud Grant': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Joe Gibbs': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Steve Owen': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Bill Cowher': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Marv Levy': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Tony Dungy': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'John Fox': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Marvin Lewis': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Hank Stram': 'NoneType' object has no attribute 'text'
# Error occurred while processing 'Weeb Ewbank': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/EwbaWe0.htm
# Error occurred while processing 'Jim Mora': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MoraJi0.htm
# Error occurred while processing 'Sid Gillman': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/GillSi0.htm
# Error occurred while processing 'Mike Ditka': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/DitkMi0.htm
# Error occurred while processing 'Dick Vermeil': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/VermDi0.htm
# Error occurred while processing 'Jon Gruden': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/GrudJo0.htm
# Error occurred while processing 'George Allen': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/AlleGe0.htm
# Error occurred while processing 'George Seifert': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/SeifGe0.htm
# Error occurred while processing 'Norv Turner': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/TurnNo0.htm
# Error occurred while processing 'Dennis Green': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/GreeDe0.htm
# Error occurred while processing 'Don Coryell': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/CoryDo0.htm
# Error occurred while processing 'Buddy Parker': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ParkRa0.htm
# Error occurred while processing 'John Madden': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MaddJo0.htm
# Error occurred while processing 'Ron Rivera': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/RiveRo0.htm
# Error occurred while processing 'Tom Flores': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/FlorTo0.htm
# Error occurred while processing 'Vince Lombardi': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/LombVi0.htm
# Error occurred while processing 'Lou Saban': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/SabaLo0.htm
# Error occurred while processing 'Jack Del Rio': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/DelRJa0.htm
# Error occurred while processing 'Lovie Smith': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/SmitLo0.htm
# Error occurred while processing 'Bill Walsh': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/WalsBi0.htm
# Error occurred while processing 'Buck Shaw': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ShawLa0.htm
# Error occurred while processing 'Jimmy Conzelman': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ConzJi0.htm
# Error occurred while processing 'Ted Marchibroda': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MarcTe0.htm
# Error occurred while processing 'Jack Pardee': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/PardJa0.htm
# Error occurred while processing 'Jason Garrett': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/GarrJa0.htm
# Error occurred while processing 'Sam Wyche': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/WychSa0.htm
# Error occurred while processing 'Gary Kubiak': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/KubiGa0.htm
# Error occurred while processing 'Bum Phillips': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/PhilBu0.htm
# Error occurred while processing 'Wade Phillips': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/PhilWa0.htm
# Error occurred while processing 'Dave Wannstedt': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/WannDa0.htm
# Error occurred while processing 'Bruce Arians': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/AriaBr0.htm
# Error occurred while processing 'Brian Billick': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/BillBr0.htm
# Error occurred while processing 'Ray Flaherty': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/FlahRa0.htm
# Error occurred while processing 'Jimmy Johnson': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/JohnJi0.htm
# Error occurred while processing 'Sean McDermott': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/McDeSe0.htm
# Error occurred while processing 'Blanton Collier': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/CollBl0.htm
# Error occurred while processing 'Forrest Gregg': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/GregFo0.htm
# Error occurred while processing 'John Robinson': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/RobiJo0.htm
# Error occurred while processing 'Bobby Ross': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/RossBo0.htm
# Error occurred while processing 'Steve Mariucci': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MariSt0.htm
# Error occurred while processing 'Sean McVay': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/McVaSe0.htm
# Error occurred while processing 'Mike Zimmer': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ZimmMi0.htm
# Error occurred while processing 'Dick Nolan': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/NolaDi0.htm
# Error occurred while processing 'George Wilson': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/WilsGe0.htm
# Error occurred while processing 'Kyle Shanahan': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ShanKy0.htm
# Error occurred while processing 'Wayne Fontes': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/FontWa0.htm
# Error occurred while processing 'Mike Smith': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/SmitMi0.htm
# Error occurred while processing 'Norm Van Brocklin': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/VanBNo0.htm
# Error occurred while processing 'Potsy Clark': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ClarPo0.htm
# Error occurred while processing 'Wally Lemm': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/LemmWa0.htm
# Error occurred while processing 'Greasy Neale': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/NealGr0.htm
# Error occurred while processing 'Jim Caldwell': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/CaldJi0.htm
# Error occurred while processing 'Doug Pederson': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/PedeDo0.htm
# Error occurred while processing 'Matt LaFleur': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/LaFlMa0.htm
# Error occurred while processing 'Rex Ryan': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/RyanRe0.htm
# Error occurred while processing 'Jerry Glanville': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/GlanJe0.htm
# Error occurred while processing 'Dick Jauron': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/JaurDi0.htm
# Error occurred while processing 'Guy Chamberlin': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ChamGu0.htm
# Error occurred while processing 'Jim Fassel': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/FassJi0.htm
# Error occurred while processing 'Joe Kuharich': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/KuhaJo0.htm
# Error occurred while processing 'Allie Sherman': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/SherAl0.htm
# Error occurred while processing 'Mike Sherman': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/SherMi0.htm
# Error occurred while processing 'Art Shell': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ShelAr0.htm
# Error occurred while processing 'Buddy Ryan': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/RyanBu0.htm
# Error occurred while processing 'Herm Edwards': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/EdwaHe0.htm
# Error occurred while processing 'Ron Meyer': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MeyeRo0.htm
# Error occurred while processing 'Mike Vrabel': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/VrabMi0.htm
# Error occurred while processing 'Jim Lee Howell': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/HoweJi0.htm
# Error occurred while processing 'Mike Martz': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MartMi0.htm
# Error occurred while processing 'Chuck Pagano': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/PagaCh0.htm
# Error occurred while processing 'Joe Walton': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/WaltJo0.htm
# Error occurred while processing 'Jerry Burns': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/BurnJe0.htm
# Error occurred while processing 'Mike Holovak': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/HoloMi0.htm
# Error occurred while processing 'Bill O'Brien': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/OBriBi0.htm
# Error occurred while processing 'Bart Starr': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/StarBa0.htm
# Error occurred while processing 'Roy Andrews': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/AndrRo0.htm
# Error occurred while processing 'Monte Clark': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ClarMo0.htm
# Error occurred while processing 'Leeman Bennett': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/BennLe0.htm
# Error occurred while processing 'Raymond Berry': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/BerrRa0.htm
# Error occurred while processing 'Dom Capers': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/CapeDo0.htm
# Error occurred while processing 'Dan Quinn': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/QuinDa0.htm
# Error occurred while processing 'Ken Whisenhunt': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/WhisKe0.htm
# Error occurred while processing 'Todd Bowles': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/BowlTo0.htm
# Error occurred while processing 'Bruce Coslet': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/CoslBr0.htm
# Error occurred while processing 'Jim Harbaugh': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/HarbJi0.htm
# Error occurred while processing 'Jim Haslett': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/HaslJi0.htm
# Error occurred while processing 'Sam Rutigliano': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/RutiSa0.htm
# Error occurred while processing 'Chuck Fairbanks': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/FairCh0.htm
# Error occurred while processing 'Nick Skorich': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/SkorNi0.htm
# Error occurred while processing 'Ray Malavasi': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MalaRa0.htm
# Error occurred while processing 'John McKay': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/McKaJo0.htm
# Error occurred while processing 'Charley Winner': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/WinnCh0.htm
# Error occurred while processing 'Joe Schmidt': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/SchmJo0.htm
# Error occurred while processing 'Ray Perkins': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/PerkRa0.htm
# Error occurred while processing 'Frank Reich': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ReicFr0.htm
# Error occurred while processing 'Dennis Erickson': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/EricDe0.htm
# Error occurred while processing 'Rich Kotite': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/KotiRi0.htm
# Error occurred while processing 'Red Miller': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MillRe0.htm
# Error occurred while processing 'John Rauch': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/RaucJo0.htm
# Error occurred while processing 'Barry Switzer': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/SwitBa0.htm
# Error occurred while processing 'Zac Taylor': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/TaylZa0.htm
# Error occurred while processing 'Brad Childress': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ChilBr0.htm
# Error occurred while processing 'Jim Hanifan': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/HaniJi0.htm
# Error occurred while processing 'Walt Michaels': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MichWa0.htm
# Error occurred while processing 'Dan Henning': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/HennDa0.htm
# Error occurred while processing 'Doug Marrone': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MarrDo0.htm
# Error occurred while processing 'Nick Sirianni': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/SiriNi0.htm
# Error occurred while processing 'Kevin Stefanski': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/StefKe0.htm
# Error occurred while processing 'Ray Rhodes': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/RhodRa0.htm
# Error occurred while processing 'Lindy Infante': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/InfaLi0.htm
# Error occurred while processing 'Mike Mularkey': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MulaMi0.htm
# Error occurred while processing 'Jay Gruden': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/GrudJa0.htm
# Error occurred while processing 'Jack Patera': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/PateJa0.htm
# Error occurred while processing 'Tommy Prothro': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/ProtTo0.htm
# Error occurred while processing 'Dan Campbell': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/CampDa1.htm
# Error occurred while processing 'Marion Campbell': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/CampMa0.htm
# Error occurred while processing 'Chan Gailey': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/GailCh0.htm
# Error occurred while processing 'Tommy Hughitt': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/HughTo0.htm
# Error occurred while processing 'Matt Nagy': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/NagyMa0.htm
# Error occurred while processing 'John Ralston': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/RalsJo0.htm
# Error occurred while processing 'Anthony Lynn': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/LynnAn0.htm
# Error occurred while processing 'Eric Mangini': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/MangEr0.htm
# Error occurred while processing 'Dick Rauch': 429 Client Error: Too Many Requests for url: https://www.pro-football-reference.com/coaches/RaucDi0.htm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 80
#      76     url = row['url']
#      78     try:
#      79 #        response = requests.get(url, headers=headers)
# ---> 80         response = requests.get(url)
#      81         response.raise_for_status()  # Raise an exception for 4xx or 5xx status codes
#      83         soup = BeautifulSoup(response.text, "html.parser")
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/urllib3/connectionpool.py:1096, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 # Force connect early to allow us to validate the connection.
#    1095 if conn.is_closed:
# -> 1096     conn.connect()
#    1098 if not conn.is_verified:
#    1099     warnings.warn(
#    1100         (
#    1101             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1106         InsecureRequestWarning,
#    1107     )
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/urllib3/connection.py:782, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     779     if is_ipaddress(normalized):
#     780         server_hostname = normalized
# --> 782 ssl_sock = ssl_wrap_socket(
#     783     sock=sock,
#     784     keyfile=key_file,
#     785     certfile=cert_file,
#     786     key_password=key_password,
#     787     ca_certs=ca_certs,
#     788     ca_cert_dir=ca_cert_dir,
#     789     ca_cert_data=ca_cert_data,
#     790     server_hostname=server_hostname,
#     791     ssl_context=context,
#     792     tls_in_tls=tls_in_tls,
#     793 )
#     795 try:
#     796     if assert_fingerprint:
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/urllib3/util/ssl_.py:470, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     467 except NotImplementedError:  # Defensive: in CI, we always have set_alpn_protocols
#     468     pass
# --> 470 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     471 return ssl_sock
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/site-packages/urllib3/util/ssl_.py:514, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     511     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     512     return SSLTransport(sock, ssl_context, server_hostname)
# --> 514 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/ssl.py:1046, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1043         if timeout == 0.0:
#    1044             # non-blocking
#    1045             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1046         self.do_handshake()
#    1047 except (OSError, ValueError):
#    1048     self.close()
#
# File ~/.pyenv/versions/3.12.0/lib/python3.12/ssl.py:1317, in SSLSocket.do_handshake(self, block)
#    1315     if timeout == 0.0 and block:
#    1316         self.settimeout(None)
# -> 1317     self._sslobj.do_handshake()
#    1318 finally:
#    1319     self.settimeout(timeout)
#
# KeyboardInterrupt:
